# %%
import deepxde as dde
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy.interpolate import griddata
import scipy.io
import tensorflow as tf
from PIL import Image
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import torch
# Out:
# Using backend: tensorflow.compat.v1
# WARNING:tensorflow:From /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/deepxde/nn/initializers.py:118: The name tf.keras.initializers.he_normal is deprecated. Please use tf.compat.v1.keras.initializers.he_normal instead.

# %%
def solution(x1,x2):
    y_f = 12.1
    A_0 = 43.6
    
    A_1 =131.2
    
    C = 56.1
    a=2100
    b=9.45
    y = y_f+(A_0+(A_1-A_0)*np.exp(-x2*x1/(a+b*x2)))*(np.arcsinh(x2/C))
    
    return y

# %%
def PDE(x,y):
    
    x1,x2=x[:,0:1],x[:,1:2]#, t,shear rate

    y_f = 12.1
    A_0 = 43.6
    
    A_1 =131.2
    
    C = 56.1
    a=2100
    b=9.45
   
    eq1 = y_f+(A_0+(A_1-A_0)*tf.exp(-x2*x1/(a+b*x2)))*(tf.math.asinh(x2/C))-y
  
    return eq1

def func(x):
    
    return solution(x[:,0:1],x[:,1:2])

geom = dde.geometry.Rectangle([0, 0], [200, 200])

#geom = dde.geometry.TimeDomain(0, 200)
data = dde.data.PDE(geom, PDE, [], 3500, 1000,train_distribution='pseudo',solution=func)

layer_size = [2] + [50] * 3 + [1]
activation = "tanh"
initializer = "Glorot uniform"
net = dde.maps.PFNN(layer_size, activation, initializer)

model = dde.Model(data, net)
model.compile("adam", lr=0.001)
model.train(iterations=50000)
# model.compile("L-BFGS")
# model.train()
# losshistory, train_state = model.train(epochs=1000)

# dde.saveplot(losshistory, train_state, issave=True, isplot=True)


X = geom.random_points(10000)
err = 1
# itr = 0

# for itr in range(5):
#     if err > 0.005:
new_points = []
for i in range(200):
    f = model.predict(X, operator=PDE)
    err_eq = np.absolute(f)
    err = np.mean(err_eq)
    print("Mean residual: %.3e" % (err))

    x_id = np.argmax(err_eq)
    print("Adding new point:", X[x_id], "\n")
    new_points.append(X[x_id])
    data.add_anchors(X[x_id])
    early_stopping = dde.callbacks.EarlyStopping(min_delta=1e-4, patience=2000)
    model.compile("adam", lr=1e-3)
    model.train(iterations=10000, disregard_previous_best=True, callbacks=[early_stopping])
    model.compile("L-BFGS")
    losshistory, train_state = model.train()
#     itr = itr+1
#     print('itr:',itr)
        
dde.saveplot(losshistory, train_state, issave=True, isplot=True)

# X, y_true = gen_testdata()
# y_pred = model.predict(X)
# print("L2 relative error:", dde.metrics.l2_relative_error(y_true, y_pred))
# np.savetxt("test.dat", np.hstack((X, y_true, y_pred)))
# Out:
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.054740 s
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/deepxde/nn/tensorflow_compat_v1/fnn.py:110: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   kernel_constraint=self.kernel_constraint,
# 2023-09-11 15:58:00.994255: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 'compile' took 0.228782 s
#
# Initializing variables...
# 2023-09-11 15:58:01.177927: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 0         [9.33e+03]    [9.33e+03]    []
# 1000      [3.05e+03]    [3.05e+03]    []
# 2000      [1.51e+03]    [1.51e+03]    []
# 3000      [9.27e+02]    [9.27e+02]    []
# 4000      [5.64e+02]    [5.64e+02]    []
# 5000      [3.22e+02]    [3.22e+02]    []
# 6000      [1.70e+02]    [1.70e+02]    []
# 7000      [8.12e+01]    [8.12e+01]    []
# 8000      [3.48e+01]    [3.48e+01]    []
# 9000      [1.32e+01]    [1.32e+01]    []
# 10000     [4.48e+00]    [4.48e+00]    []
# 11000     [1.36e+00]    [1.36e+00]    []
# 12000     [4.03e-01]    [4.03e-01]    []
# 13000     [1.31e-01]    [1.31e-01]    []
# 14000     [8.07e-02]    [8.07e-02]    []
# 15000     [2.83e-02]    [2.83e-02]    []
# 16000     [8.27e-01]    [8.27e-01]    []
# 17000     [1.41e-02]    [1.41e-02]    []
# 18000     [1.15e-02]    [1.15e-02]    []
# 19000     [1.01e-02]    [1.01e-02]    []
# 20000     [5.51e-02]    [5.51e-02]    []
# 21000     [8.28e-03]    [8.28e-03]    []
# 22000     [7.65e-03]    [7.65e-03]    []
# 23000     [7.03e-03]    [7.03e-03]    []
# 24000     [1.29e-02]    [1.29e-02]    []
# 25000     [5.93e-03]    [5.93e-03]    []
# 26000     [6.59e-03]    [6.59e-03]    []
# 27000     [3.42e-01]    [3.42e-01]    []
# 28000     [2.13e-02]    [2.13e-02]    []
# 29000     [1.27e-02]    [1.27e-02]    []
# 30000     [3.62e-03]    [3.62e-03]    []
# 31000     [1.03e-02]    [1.03e-02]    []
# 32000     [7.01e-03]    [7.01e-03]    []
# 33000     [1.34e-02]    [1.34e-02]    []
# 34000     [1.29e-01]    [1.29e-01]    []
# 35000     [2.92e-03]    [2.92e-03]    []
# 36000     [1.71e-01]    [1.71e-01]    []
# 37000     [2.58e-03]    [2.58e-03]    []
# 38000     [9.62e-02]    [9.62e-02]    []
# 39000     [1.39e-01]    [1.39e-01]    []
# 40000     [1.22e-02]    [1.22e-02]    []
# 41000     [2.85e-03]    [2.85e-03]    []
# 42000     [1.08e-01]    [1.08e-01]    []
# 43000     [2.21e-03]    [2.21e-03]    []
# 44000     [1.29e-01]    [1.29e-01]    []
# 45000     [5.82e-03]    [5.82e-03]    []
# 46000     [2.37e-03]    [2.37e-03]    []
# 47000     [1.88e-01]    [1.88e-01]    []
# 48000     [9.62e-02]    [9.62e-02]    []
# 49000     [9.74e-02]    [9.74e-02]    []
# 50000     [4.47e-02]    [4.47e-02]    []
#
# Best model at step 43000:
#   train loss: 2.21e-03
#   test loss: 2.21e-03
#   test metric: []
#
# 'train' took 179.535495 s
#
# Mean residual: 1.868e-01
# Adding new point: [  1.0155765 199.42726  ]
#
# Compiling model...
# 'compile' took 0.102888 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 50000     [4.49e-02]    [4.47e-02]    []
# 51000     [1.75e-03]    [1.70e-03]    []
# 52000     [2.22e-03]    [2.17e-03]    []
# 53000     [2.01e-02]    [2.01e-02]    []
# Epoch 53000: early stopping
#
# Best model at step 51000:
#   train loss: 1.75e-03
#   test loss: 1.70e-03
#   test metric: []
#
# 'train' took 10.988491 s
#
# Compiling model...
# 'compile' took 0.064915 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 53000     [2.01e-02]    [2.01e-02]    []
# 54000     [9.09e-04]    [9.09e-04]
# 55000     [5.32e-04]    [5.32e-04]
# 56000     [3.87e-04]    [3.87e-04]
# 57000     [3.01e-04]    [3.01e-04]
# 58000     [2.52e-04]    [2.52e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000231
#   Number of iterations: 5055
#   Number of functions evaluations: 5441
# 58441     [2.31e-04]    [2.26e-04]    []
#
# Best model at step 58441:
#   train loss: 2.31e-04
#   test loss: 2.26e-04
#   test metric: []
#
# 'train' took 41.644245 s
#
# Mean residual: 1.049e-02
# Adding new point: [  0.5319344 185.39426  ]
#
# Compiling model...
# 'compile' took 0.114637 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 58441     [2.39e-04]    [2.26e-04]    []
# 59000     [2.97e-04]    [2.86e-04]    []
# 60000     [3.83e-02]    [3.82e-02]    []
# Epoch 60442: early stopping
#
# Best model at step 58441:
#   train loss: 2.39e-04
#   test loss: 2.26e-04
#   test metric: []
#
# 'train' took 7.412917 s
#
# Compiling model...
# 'compile' took 0.065325 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 60442     [6.57e-04]    [6.43e-04]    []
# 61000     [2.70e-04]    [2.70e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000252
#   Number of iterations: 651
#   Number of functions evaluations: 705
# 61147     [2.52e-04]    [2.35e-04]    []
#
# Best model at step 58441:
#   train loss: 2.39e-04
#   test loss: 2.26e-04
#   test metric: []
#
# 'train' took 5.466802 s
#
# Mean residual: 1.075e-02
# Adding new point: [  1.0155765 199.42726  ]
#
# Compiling model...
# 'compile' took 0.112020 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 61147     [2.62e-04]    [2.35e-04]    []
# 62000     [3.48e-04]    [3.27e-04]    []
# 63000     [4.50e-04]    [4.32e-04]    []
# Epoch 63148: early stopping
#
# Best model at step 61147:
#   train loss: 2.62e-04
#   test loss: 2.35e-04
#   test metric: []
#
# 'train' took 7.357557 s
#
# Compiling model...
# 'compile' took 0.066991 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 63148     [4.09e-03]    [4.07e-03]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000285
#   Number of iterations: 543
#   Number of functions evaluations: 591
# 63739     [2.85e-04]    [2.68e-04]    []
#
# Best model at step 61147:
#   train loss: 2.62e-04
#   test loss: 2.35e-04
#   test metric: []
#
# 'train' took 4.537582 s
#
# Mean residual: 1.174e-02
# Adding new point: [  0.5319344 185.39426  ]
#
# Compiling model...
# 'compile' took 0.113213 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 63739     [2.92e-04]    [2.68e-04]    []
# 64000     [6.20e-04]    [6.03e-04]    []
# 65000     [5.23e-02]    [5.23e-02]    []
# Epoch 65740: early stopping
#
# Best model at step 63739:
#   train loss: 2.92e-04
#   test loss: 2.68e-04
#   test metric: []
#
# 'train' took 7.505343 s
#
# Compiling model...
# 'compile' took 0.069683 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 65740     [2.35e-02]    [2.35e-02]    []
# 66000     [5.14e-04]    [5.14e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000307
#   Number of iterations: 886
#   Number of functions evaluations: 956
# 66696     [3.07e-04]    [2.83e-04]    []
#
# Best model at step 63739:
#   train loss: 2.92e-04
#   test loss: 2.68e-04
#   test metric: []
#
# 'train' took 7.417219 s
#
# Mean residual: 1.260e-02
# Adding new point: [7.132157 2.735061]
#
# Compiling model...
# 'compile' took 0.115941 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 66696     [3.19e-04]    [2.83e-04]    []
# 67000     [3.67e-04]    [3.42e-04]    []
# 68000     [5.16e-03]    [5.12e-03]    []
# Epoch 68697: early stopping
#
# Best model at step 66696:
#   train loss: 3.19e-04
#   test loss: 2.83e-04
#   test metric: []
#
# 'train' took 7.401181 s
#
# Compiling model...
# 'compile' took 0.072663 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 68697     [5.62e-02]    [5.62e-02]    []
# 69000     [4.95e-04]    [4.95e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000336
#   Number of iterations: 916
#   Number of functions evaluations: 996
# 69693     [3.36e-04]    [3.12e-04]    []
#
# Best model at step 66696:
#   train loss: 3.19e-04
#   test loss: 2.83e-04
#   test metric: []
#
# 'train' took 7.827495 s
#
# Mean residual: 1.350e-02
# Adding new point: [194.61298     0.7902452]
#
# Compiling model...
# 'compile' took 0.117203 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 69693     [3.41e-04]    [3.12e-04]    []
# 70000     [7.86e-04]    [7.63e-04]    []
# 71000     [6.41e-04]    [6.20e-04]    []
# Epoch 71694: early stopping
#
# Best model at step 69693:
#   train loss: 3.41e-04
#   test loss: 3.12e-04
#   test metric: []
#
# 'train' took 7.624697 s
#
# Compiling model...
# 'compile' took 0.073275 s
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 71694     [2.58e-03]    [2.56e-03]    []
# 72000     [4.76e-04]    [4.76e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000349
#   Number of iterations: 852
#   Number of functions evaluations: 925
# 72619     [3.49e-04]    [3.20e-04]    []
#
# Best model at step 69693:
#   train loss: 3.41e-04
#   test loss: 3.12e-04
#   test metric: []
#
# 'train' took 7.406805 s
#
# Mean residual: 1.399e-02
# Adding new point: [ 3.3605247 16.258842 ]
#
# Compiling model...
# 'compile' took 0.120143 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 72619     [3.55e-04]    [3.20e-04]    []
# 73000     [5.25e-04]    [5.03e-04]    []
# 74000     [5.57e-03]    [5.55e-03]    []
# Epoch 74620: early stopping
#
# Best model at step 72619:
#   train loss: 3.55e-04
#   test loss: 3.20e-04
#   test metric: []
#
# 'train' took 7.580100 s
#
# Compiling model...
# 'compile' took 0.087691 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 74620     [9.50e-04]    [9.30e-04]    []
# 75000     [4.41e-04]    [4.41e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000332
#   Number of iterations: 1036
#   Number of functions evaluations: 1161
# 75781     [3.32e-04]    [3.06e-04]    []
#
# Best model at step 75781:
#   train loss: 3.32e-04
#   test loss: 3.06e-04
#   test metric: []
#
# 'train' took 8.997117 s
#
# Mean residual: 1.390e-02
# Adding new point: [  0.5319344 185.39426  ]
#
# Compiling model...
# 'compile' took 0.119528 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 75781     [3.36e-04]    [3.06e-04]    []
# 76000     [8.10e-04]    [7.78e-04]    []
# 77000     [4.40e-04]    [4.14e-04]    []
# Epoch 77782: early stopping
#
# Best model at step 75781:
#   train loss: 3.36e-04
#   test loss: 3.06e-04
#   test metric: []
#
# 'train' took 7.663482 s
#
# Compiling model...
# 'compile' took 0.078396 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 77782     [5.49e-04]    [5.26e-04]    []
# 78000     [4.28e-04]    [4.28e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000329
#   Number of iterations: 830
#   Number of functions evaluations: 884
# 78666     [3.29e-04]    [3.04e-04]    []
#
# Best model at step 78666:
#   train loss: 3.29e-04
#   test loss: 3.04e-04
#   test metric: []
#
# 'train' took 7.120592 s
#
# Mean residual: 1.397e-02
# Adding new point: [  1.0155765 199.42726  ]
#
# Compiling model...
# 'compile' took 0.116977 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 78666     [3.34e-04]    [3.04e-04]    []
# 79000     [6.89e-04]    [6.57e-04]    []
# 80000     [8.79e-04]    [8.55e-04]    []
# Epoch 80667: early stopping
#
# Best model at step 78666:
#   train loss: 3.34e-04
#   test loss: 3.04e-04
#   test metric: []
#
# 'train' took 7.736309 s
#
# Compiling model...
# 'compile' took 0.076663 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 80667     [1.53e-02]    [1.53e-02]    []
# 81000     [4.08e-04]    [4.08e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000377
#   Number of iterations: 488
#   Number of functions evaluations: 520
# 81187     [3.77e-04]    [3.57e-04]    []
#
# Best model at step 78666:
#   train loss: 3.34e-04
#   test loss: 3.04e-04
#   test metric: []
#
# 'train' took 4.416028 s
#
# Mean residual: 1.489e-02
# Adding new point: [  1.1131498 125.510895 ]
#
# Compiling model...
# 'compile' took 0.120465 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 81187     [3.81e-04]    [3.57e-04]    []
# 82000     [4.49e-04]    [4.25e-04]    []
# 83000     [7.99e-03]    [7.99e-03]    []
# Epoch 83188: early stopping
#
# Best model at step 81187:
#   train loss: 3.81e-04
#   test loss: 3.57e-04
#   test metric: []
#
# 'train' took 7.687451 s
#
# Compiling model...
# 'compile' took 0.084179 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 83188     [1.82e-01]    [1.81e-01]    []
# 84000     [3.36e-04]    [3.36e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000336
#   Number of iterations: 769
#   Number of functions evaluations: 861
# 84049     [3.36e-04]    [3.13e-04]    []
#
# Best model at step 84049:
#   train loss: 3.36e-04
#   test loss: 3.13e-04
#   test metric: []
#
# 'train' took 6.966382 s
#
# Mean residual: 1.407e-02
# Adding new point: [ 5.0351763 76.20372  ]
#
# Compiling model...
# 'compile' took 0.135892 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 84049     [3.39e-04]    [3.13e-04]    []
# 85000     [3.67e-04]    [3.42e-04]    []
# 86000     [7.01e-03]    [6.98e-03]    []
# Epoch 86050: early stopping
#
# Best model at step 84049:
#   train loss: 3.39e-04
#   test loss: 3.13e-04
#   test metric: []
#
# 'train' took 7.816927 s
#
# Compiling model...
# 'compile' took 0.085519 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 86050     [5.58e-04]    [5.36e-04]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000402
#   Number of iterations: 203
#   Number of functions evaluations: 223
# 86273     [4.02e-04]    [3.81e-04]    []
#
# Best model at step 84049:
#   train loss: 3.39e-04
#   test loss: 3.13e-04
#   test metric: []
#
# 'train' took 2.242302 s
#
# Mean residual: 1.533e-02
# Adding new point: [ 2.2525604 52.880276 ]
#
# Compiling model...
# 'compile' took 0.133074 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 86273     [4.05e-04]    [3.81e-04]    []
# 87000     [4.33e-04]    [4.09e-04]    []
# 88000     [1.46e-02]    [1.45e-02]    []
# Epoch 88274: early stopping
#
# Best model at step 86273:
#   train loss: 4.05e-04
#   test loss: 3.81e-04
#   test metric: []
#
# 'train' took 8.039179 s
#
# Compiling model...
# 'compile' took 0.083433 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 88274     [2.49e-02]    [2.48e-02]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000396
#   Number of iterations: 565
#   Number of functions evaluations: 622
# 88896     [3.96e-04]    [3.73e-04]    []
#
# Best model at step 88896:
#   train loss: 3.96e-04
#   test loss: 3.73e-04
#   test metric: []
#
# 'train' took 5.360428 s
#
# Mean residual: 1.513e-02
# Adding new point: [ 3.3605247 16.258842 ]
#
# Compiling model...
# 'compile' took 0.124463 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 88896     [4.00e-04]    [3.73e-04]    []
# 89000     [2.10e-03]    [2.08e-03]    []
# 90000     [7.07e-04]    [6.88e-04]    []
# Epoch 90897: early stopping
#
# Best model at step 88896:
#   train loss: 4.00e-04
#   test loss: 3.73e-04
#   test metric: []
#
# 'train' took 8.183969 s
#
# Compiling model...
# 'compile' took 0.085985 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 90897     [2.44e-01]    [2.43e-01]    []
# 91000     [5.55e-04]    [5.55e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000354
#   Number of iterations: 914
#   Number of functions evaluations: 1016
# 91913     [3.54e-04]    [3.33e-04]    []
#
# Best model at step 91913:
#   train loss: 3.54e-04
#   test loss: 3.33e-04
#   test metric: []
#
# 'train' took 8.332068 s
#
# Mean residual: 1.461e-02
# Adding new point: [  0.5319344 185.39426  ]
#
# Compiling model...
# 'compile' took 0.130475 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 91913     [3.57e-04]    [3.33e-04]    []
# 92000     [2.36e-03]    [2.32e-03]    []
# 93000     [5.68e-04]    [5.45e-04]    []
# Epoch 93914: early stopping
#
# Best model at step 91913:
#   train loss: 3.57e-04
#   test loss: 3.33e-04
#   test metric: []
#
# 'train' took 8.095237 s
#
# Compiling model...
# 'compile' took 0.089536 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 93914     [2.64e-02]    [2.62e-02]    []
# 94000     [5.76e-04]    [5.76e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000362
#   Number of iterations: 690
#   Number of functions evaluations: 743
# 94657     [3.62e-04]    [3.40e-04]    []
#
# Best model at step 91913:
#   train loss: 3.57e-04
#   test loss: 3.33e-04
#   test metric: []
#
# 'train' took 6.558178 s
#
# Mean residual: 1.474e-02
# Adding new point: [12.3259   95.664955]
#
# Compiling model...
# 'compile' took 0.127627 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 94657     [3.65e-04]    [3.40e-04]    []
# 95000     [1.46e-03]    [1.45e-03]    []
# 96000     [5.35e-04]    [5.13e-04]    []
# Epoch 96658: early stopping
#
# Best model at step 94657:
#   train loss: 3.65e-04
#   test loss: 3.40e-04
#   test metric: []
#
# 'train' took 8.269502 s
#
# Compiling model...
# 'compile' took 0.112271 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 96658     [2.71e-01]    [2.70e-01]    []
# 97000     [4.36e-04]    [4.36e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000391
#   Number of iterations: 542
#   Number of functions evaluations: 581
# 97239     [3.91e-04]    [3.69e-04]    []
#
# Best model at step 94657:
#   train loss: 3.65e-04
#   test loss: 3.40e-04
#   test metric: []
#
# 'train' took 5.882416 s
#
# Mean residual: 1.518e-02
# Adding new point: [9.543026  5.1701126]
#
# Compiling model...
# 'compile' took 0.157411 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 97239     [3.94e-04]    [3.69e-04]    []
# 98000     [4.45e-04]    [4.27e-04]    []
# 99000     [2.68e-03]    [2.64e-03]    []
# Epoch 99240: early stopping
#
# Best model at step 97239:
#   train loss: 3.94e-04
#   test loss: 3.69e-04
#   test metric: []
#
# 'train' took 8.705581 s
#
# Compiling model...
# 'compile' took 0.102640 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 99240     [1.81e-03]    [1.79e-03]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000374
#   Number of iterations: 629
#   Number of functions evaluations: 686
# 99926     [3.74e-04]    [3.56e-04]    []
#
# Best model at step 99926:
#   train loss: 3.74e-04
#   test loss: 3.56e-04
#   test metric: []
#
# 'train' took 6.634540 s
#
# Mean residual: 1.502e-02
# Adding new point: [13.039231 92.541145]
#
# Compiling model...
# 'compile' took 0.167565 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 99926     [3.77e-04]    [3.56e-04]    []
# 100000    [5.13e-03]    [4.96e-03]    []
# 101000    [5.11e-04]    [4.90e-04]    []
# Epoch 101927: early stopping
#
# Best model at step 99926:
#   train loss: 3.77e-04
#   test loss: 3.56e-04
#   test metric: []
#
# 'train' took 8.743179 s
#
# Compiling model...
# 'compile' took 0.091161 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 101927    [6.28e-04]    [6.08e-04]    []
# 102000    [5.41e-04]    [5.41e-04]
# 103000    [3.27e-04]    [3.27e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000320
#   Number of iterations: 1070
#   Number of functions evaluations: 1150
# 103077    [3.20e-04]    [3.02e-04]    []
#
# Best model at step 103077:
#   train loss: 3.20e-04
#   test loss: 3.02e-04
#   test metric: []
#
# 'train' took 9.953932 s
#
# Mean residual: 1.418e-02
# Adding new point: [1.3204972 3.781989 ]
#
# Compiling model...
# 'compile' took 0.136867 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 103077    [3.24e-04]    [3.02e-04]    []
# 104000    [3.37e-04]    [3.19e-04]    []
# 105000    [1.62e-03]    [1.59e-03]    []
# Epoch 105078: early stopping
#
# Best model at step 103077:
#   train loss: 3.24e-04
#   test loss: 3.02e-04
#   test metric: []
#
# 'train' took 8.527135 s
#
# Compiling model...
# 'compile' took 0.093795 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 105078    [2.08e-02]    [2.08e-02]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000329
#   Number of iterations: 625
#   Number of functions evaluations: 666
# 105744    [3.29e-04]    [3.11e-04]    []
#
# Best model at step 103077:
#   train loss: 3.24e-04
#   test loss: 3.02e-04
#   test metric: []
#
# 'train' took 6.687764 s
#
# Mean residual: 1.414e-02
# Adding new point: [  0.9090788 138.59148  ]
#
# Compiling model...
# 'compile' took 0.191610 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 105744    [3.31e-04]    [3.11e-04]    []
# 106000    [6.29e-04]    [6.11e-04]    []
# 107000    [6.61e-04]    [6.42e-04]    []
# Epoch 107745: early stopping
#
# Best model at step 105744:
#   train loss: 3.31e-04
#   test loss: 3.11e-04
#   test metric: []
#
# 'train' took 11.651326 s
#
# Compiling model...
# 'compile' took 0.110787 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 107745    [3.50e-03]    [3.47e-03]    []
# 108000    [4.09e-04]    [4.09e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000305
#   Number of iterations: 997
#   Number of functions evaluations: 1074
# 108819    [3.05e-04]    [2.87e-04]    []
#
# Best model at step 108819:
#   train loss: 3.05e-04
#   test loss: 2.87e-04
#   test metric: []
#
# 'train' took 10.384159 s
#
# Mean residual: 1.388e-02
# Adding new point: [  0.9090788 138.59148  ]
#
# Compiling model...
# 'compile' took 0.174470 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 108819    [3.08e-04]    [2.87e-04]    []
# 109000    [8.10e-04]    [7.94e-04]    []
# 110000    [9.53e-03]    [9.51e-03]    []
# Epoch 110820: early stopping
#
# Best model at step 108819:
#   train loss: 3.08e-04
#   test loss: 2.87e-04
#   test metric: []
#
# 'train' took 8.734791 s
#
# Compiling model...
# 'compile' took 0.096914 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 110820    [4.85e-03]    [4.81e-03]    []
# 111000    [4.32e-04]    [4.32e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000317
#   Number of iterations: 783
#   Number of functions evaluations: 837
# 111657    [3.17e-04]    [2.98e-04]    []
#
# Best model at step 108819:
#   train loss: 3.08e-04
#   test loss: 2.87e-04
#   test metric: []
#
# 'train' took 7.885602 s
#
# Mean residual: 1.411e-02
# Adding new point: [  8.837668 199.97916 ]
#
# Compiling model...
# 'compile' took 0.145117 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 111657    [3.20e-04]    [2.98e-04]    []
# 112000    [6.36e-04]    [6.17e-04]    []
# 113000    [5.00e-04]    [4.81e-04]    []
# Epoch 113658: early stopping
#
# Best model at step 111657:
#   train loss: 3.20e-04
#   test loss: 2.98e-04
#   test metric: []
#
# 'train' took 8.797682 s
#
# Compiling model...
# 'compile' took 0.097235 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 113658    [4.91e-04]    [4.72e-04]    []
# 114000    [3.67e-04]    [3.67e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000337
#   Number of iterations: 486
#   Number of functions evaluations: 528
# 114186    [3.37e-04]    [3.16e-04]    []
#
# Best model at step 111657:
#   train loss: 3.20e-04
#   test loss: 2.98e-04
#   test metric: []
#
# 'train' took 5.553981 s
#
# Mean residual: 1.459e-02
# Adding new point: [2.4073937 0.7002344]
#
# Compiling model...
# 'compile' took 0.169779 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 114186    [3.41e-04]    [3.16e-04]    []
# 115000    [1.81e-03]    [1.76e-03]    []
# 116000    [5.34e-03]    [5.33e-03]    []
# Epoch 116187: early stopping
#
# Best model at step 114186:
#   train loss: 3.41e-04
#   test loss: 3.16e-04
#   test metric: []
#
# 'train' took 8.925113 s
#
# Compiling model...
# 'compile' took 0.114001 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 116187    [1.81e-01]    [1.80e-01]    []
# 117000    [3.35e-04]    [3.35e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000302
#   Number of iterations: 1062
#   Number of functions evaluations: 1156
# 117343    [3.02e-04]    [2.84e-04]    []
#
# Best model at step 117343:
#   train loss: 3.02e-04
#   test loss: 2.84e-04
#   test metric: []
#
# 'train' took 10.689878 s
#
# Mean residual: 1.369e-02
# Adding new point: [ 8.654223 79.20591 ]
#
# Compiling model...
# 'compile' took 0.205708 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 117343    [3.04e-04]    [2.84e-04]    []
# 118000    [3.57e-04]    [3.39e-04]    []
# 119000    [9.95e-04]    [9.77e-04]    []
# Epoch 119344: early stopping
#
# Best model at step 117343:
#   train loss: 3.04e-04
#   test loss: 2.84e-04
#   test metric: []
#
# 'train' took 9.244891 s
#
# Compiling model...
# 'compile' took 0.131433 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 119344    [1.76e-03]    [1.74e-03]    []
# 120000    [3.23e-04]    [3.23e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000310
#   Number of iterations: 754
#   Number of functions evaluations: 832
# 120176    [3.10e-04]    [2.89e-04]    []
#
# Best model at step 117343:
#   train loss: 3.04e-04
#   test loss: 2.84e-04
#   test metric: []
#
# 'train' took 9.084435 s
#
# Mean residual: 1.382e-02
# Adding new point: [  8.837668 199.97916 ]
#
# Compiling model...
# 'compile' took 0.189227 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 120176    [3.12e-04]    [2.89e-04]    []
# 121000    [3.98e-04]    [3.82e-04]    []
# 122000    [7.44e-02]    [7.40e-02]    []
# Epoch 122177: early stopping
#
# Best model at step 120176:
#   train loss: 3.12e-04
#   test loss: 2.89e-04
#   test metric: []
#
# 'train' took 9.610206 s
#
# Compiling model...
# 'compile' took 0.130793 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 122177    [3.60e-03]    [3.57e-03]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000312
#   Number of iterations: 700
#   Number of functions evaluations: 758
# 122935    [3.12e-04]    [2.92e-04]    []
#
# Best model at step 120176:
#   train loss: 3.12e-04
#   test loss: 2.89e-04
#   test metric: []
#
# 'train' took 8.058410 s
#
# Mean residual: 1.404e-02
# Adding new point: [196.7791       0.30568886]
#
# Compiling model...
# 'compile' took 0.186972 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 122935    [3.14e-04]    [2.92e-04]    []
# 123000    [1.39e-02]    [1.35e-02]    []
# 124000    [1.22e-03]    [1.21e-03]    []
# Epoch 124936: early stopping
#
# Best model at step 122935:
#   train loss: 3.14e-04
#   test loss: 2.92e-04
#   test metric: []
#
# 'train' took 10.089063 s
#
# Compiling model...
# 'compile' took 0.137734 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 124936    [3.44e-02]    [3.42e-02]    []
# 125000    [4.32e-04]    [4.32e-04]
# 126000    [2.85e-04]    [2.85e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000279
#   Number of iterations: 1053
#   Number of functions evaluations: 1174
# 126110    [2.79e-04]    [2.63e-04]    []
#
# Best model at step 126110:
#   train loss: 2.79e-04
#   test loss: 2.63e-04
#   test metric: []
#
# 'train' took 11.668143 s
#
# Mean residual: 1.345e-02
# Adding new point: [ 8.532951 58.41958 ]
#
# Compiling model...
# 'compile' took 0.173908 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 126110    [2.81e-04]    [2.63e-04]    []
# 127000    [3.75e-04]    [3.58e-04]    []
# 128000    [4.70e-04]    [4.54e-04]    []
# Epoch 128111: early stopping
#
# Best model at step 126110:
#   train loss: 2.81e-04
#   test loss: 2.63e-04
#   test metric: []
#
# 'train' took 9.449962 s
#
# Compiling model...
# 'compile' took 0.141024 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 128111    [6.21e-02]    [6.19e-02]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000306
#   Number of iterations: 746
#   Number of functions evaluations: 816
# 128927    [3.06e-04]    [2.87e-04]    []
#
# Best model at step 126110:
#   train loss: 2.81e-04
#   test loss: 2.63e-04
#   test metric: []
#
# 'train' took 9.081321 s
#
# Mean residual: 1.401e-02
# Adding new point: [ 9.92913 79.75502]
#
# Compiling model...
# 'compile' took 0.148967 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 128927    [3.08e-04]    [2.87e-04]    []
# 129000    [3.41e-03]    [3.37e-03]    []
# 130000    [4.84e-04]    [4.67e-04]    []
# Epoch 130928: early stopping
#
# Best model at step 128927:
#   train loss: 3.08e-04
#   test loss: 2.87e-04
#   test metric: []
#
# 'train' took 9.657286 s
#
# Compiling model...
# 'compile' took 0.114483 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 130928    [1.26e-02]    [1.26e-02]    []
# 131000    [4.62e-04]    [4.62e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000301
#   Number of iterations: 787
#   Number of functions evaluations: 843
# 131771    [3.01e-04]    [2.81e-04]    []
#
# Best model at step 131771:
#   train loss: 3.01e-04
#   test loss: 2.81e-04
#   test metric: []
#
# 'train' took 9.033357 s
#
# Mean residual: 1.410e-02
# Adding new point: [194.07835     1.8592564]
#
# Compiling model...
# 'compile' took 0.154855 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 131771    [3.02e-04]    [2.81e-04]    []
# 132000    [4.56e-04]    [4.40e-04]    []
# 133000    [4.29e-04]    [4.14e-04]    []
# Epoch 133772: early stopping
#
# Best model at step 131771:
#   train loss: 3.02e-04
#   test loss: 2.81e-04
#   test metric: []
#
# 'train' took 9.512924 s
#
# Compiling model...
# 'compile' took 0.117427 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 133772    [8.11e-03]    [8.07e-03]    []
# 134000    [4.22e-04]    [4.22e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000279
#   Number of iterations: 1033
#   Number of functions evaluations: 1127
# 134899    [2.79e-04]    [2.61e-04]    []
#
# Best model at step 134899:
#   train loss: 2.79e-04
#   test loss: 2.61e-04
#   test metric: []
#
# 'train' took 11.439834 s
#
# Mean residual: 1.347e-02
# Adding new point: [ 8.532951 58.41958 ]
#
# Compiling model...
# 'compile' took 0.320850 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 134899    [2.80e-04]    [2.61e-04]    []
# 135000    [4.32e-03]    [4.30e-03]    []
# 136000    [4.00e-04]    [3.83e-04]    []
# Epoch 136900: early stopping
#
# Best model at step 134899:
#   train loss: 2.80e-04
#   test loss: 2.61e-04
#   test metric: []
#
# 'train' took 10.384833 s
#
# Compiling model...
# 'compile' took 0.117151 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 136900    [4.14e-02]    [4.12e-02]    []
# 137000    [4.67e-04]    [4.67e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000295
#   Number of iterations: 764
#   Number of functions evaluations: 827
# 137727    [2.95e-04]    [2.76e-04]    []
#
# Best model at step 134899:
#   train loss: 2.80e-04
#   test loss: 2.61e-04
#   test metric: []
#
# 'train' took 9.658982 s
#
# Mean residual: 1.387e-02
# Adding new point: [196.7791       0.30568886]
#
# Compiling model...
# 'compile' took 0.200289 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 137727    [2.97e-04]    [2.76e-04]    []
# 138000    [2.24e-03]    [2.22e-03]    []
# 139000    [4.21e-04]    [4.06e-04]    []
# Epoch 139728: early stopping
#
# Best model at step 137727:
#   train loss: 2.97e-04
#   test loss: 2.76e-04
#   test metric: []
#
# 'train' took 9.870097 s
#
# Compiling model...
# 'compile' took 0.119269 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 139728    [1.46e-03]    [1.45e-03]    []
# 140000    [3.86e-04]    [3.86e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000286
#   Number of iterations: 844
#   Number of functions evaluations: 951
# 140679    [2.86e-04]    [2.67e-04]    []
#
# Best model at step 140679:
#   train loss: 2.86e-04
#   test loss: 2.67e-04
#   test metric: []
#
# 'train' took 9.598661 s
#
# Mean residual: 1.369e-02
# Adding new point: [ 13.790353 121.96286 ]
#
# Compiling model...
# 'compile' took 0.156562 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 140679    [2.88e-04]    [2.67e-04]    []
# 141000    [4.48e-04]    [4.27e-04]    []
# 142000    [4.03e-04]    [3.87e-04]    []
# Epoch 142680: early stopping
#
# Best model at step 140679:
#   train loss: 2.88e-04
#   test loss: 2.67e-04
#   test metric: []
#
# 'train' took 9.606203 s
#
# Compiling model...
# 'compile' took 0.114080 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 142680    [1.04e-02]    [1.03e-02]    []
# 143000    [3.69e-04]    [3.69e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000319
#   Number of iterations: 544
#   Number of functions evaluations: 592
# 143272    [3.19e-04]    [3.00e-04]    []
#
# Best model at step 140679:
#   train loss: 2.88e-04
#   test loss: 2.67e-04
#   test metric: []
#
# 'train' took 7.127549 s
#
# Mean residual: 1.430e-02
# Adding new point: [ 0.99374866 24.13653   ]
#
# Compiling model...
# 'compile' took 0.161560 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 143272    [3.21e-04]    [3.00e-04]    []
# 144000    [3.58e-04]    [3.36e-04]    []
# 145000    [4.74e-04]    [4.57e-04]    []
# Epoch 145273: early stopping
#
# Best model at step 143272:
#   train loss: 3.21e-04
#   test loss: 3.00e-04
#   test metric: []
#
# 'train' took 9.973020 s
#
# Compiling model...
# 'compile' took 0.117950 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 145273    [4.82e-04]    [4.64e-04]    []
# 146000    [3.00e-04]    [3.00e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000290
#   Number of iterations: 799
#   Number of functions evaluations: 864
# 146137    [2.90e-04]    [2.71e-04]    []
#
# Best model at step 146137:
#   train loss: 2.90e-04
#   test loss: 2.71e-04
#   test metric: []
#
# 'train' took 9.524527 s
#
# Mean residual: 1.391e-02
# Adding new point: [9.543026  5.1701126]
#
# Compiling model...
# 'compile' took 0.198788 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 146137    [2.92e-04]    [2.71e-04]    []
# 147000    [4.21e-04]    [4.05e-04]    []
# 148000    [5.72e-04]    [5.56e-04]    []
# Epoch 148138: early stopping
#
# Best model at step 146137:
#   train loss: 2.92e-04
#   test loss: 2.71e-04
#   test metric: []
#
# 'train' took 10.396283 s
#
# Compiling model...
# 'compile' took 0.134555 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 148138    [1.19e-03]    [1.17e-03]    []
# 149000    [2.94e-04]    [2.94e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000294
#   Number of iterations: 812
#   Number of functions evaluations: 876
# 149014    [2.94e-04]    [2.76e-04]    []
#
# Best model at step 146137:
#   train loss: 2.92e-04
#   test loss: 2.71e-04
#   test metric: []
#
# 'train' took 9.855431 s
#
# Mean residual: 1.419e-02
# Adding new point: [ 1.7418919 63.473946 ]
#
# Compiling model...
# 'compile' took 0.161992 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 149014    [2.96e-04]    [2.76e-04]    []
# 150000    [5.34e-02]    [5.33e-02]    []
# 151000    [3.63e-02]    [3.61e-02]    []
# Epoch 151015: early stopping
#
# Best model at step 149014:
#   train loss: 2.96e-04
#   test loss: 2.76e-04
#   test metric: []
#
# 'train' took 9.908729 s
#
# Compiling model...
# 'compile' took 0.126654 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 151015    [1.00e-01]    [9.95e-02]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000295
#   Number of iterations: 693
#   Number of functions evaluations: 743
# 151758    [2.95e-04]    [2.77e-04]    []
#
# Best model at step 151758:
#   train loss: 2.95e-04
#   test loss: 2.77e-04
#   test metric: []
#
# 'train' took 8.708826 s
#
# Mean residual: 1.401e-02
# Adding new point: [ 1.6316729 11.35575  ]
#
# Compiling model...
# 'compile' took 0.161295 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 151758    [2.97e-04]    [2.77e-04]    []
# 152000    [5.12e-04]    [4.92e-04]    []
# 153000    [2.00e-02]    [2.00e-02]    []
# Epoch 153759: early stopping
#
# Best model at step 151758:
#   train loss: 2.97e-04
#   test loss: 2.77e-04
#   test metric: []
#
# 'train' took 10.222388 s
#
# Compiling model...
# 'compile' took 0.127194 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 153759    [3.19e-02]    [3.18e-02]    []
# 154000    [3.79e-04]    [3.79e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000278
#   Number of iterations: 860
#   Number of functions evaluations: 920
# 154679    [2.78e-04]    [2.60e-04]    []
#
# Best model at step 154679:
#   train loss: 2.78e-04
#   test loss: 2.60e-04
#   test metric: []
#
# 'train' took 10.172544 s
#
# Mean residual: 1.378e-02
# Adding new point: [16.425457   4.4624853]
#
# Compiling model...
# 'compile' took 0.168873 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 154679    [2.79e-04]    [2.60e-04]    []
# 155000    [4.35e-04]    [4.18e-04]    []
# 156000    [4.92e-04]    [4.77e-04]    []
# Epoch 156680: early stopping
#
# Best model at step 154679:
#   train loss: 2.79e-04
#   test loss: 2.60e-04
#   test metric: []
#
# 'train' took 10.140735 s
#
# Compiling model...
# 'compile' took 0.130346 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 156680    [5.99e-03]    [5.96e-03]    []
# 157000    [3.68e-04]    [3.68e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000289
#   Number of iterations: 787
#   Number of functions evaluations: 876
# 157556    [2.89e-04]    [2.72e-04]    []
#
# Best model at step 154679:
#   train loss: 2.79e-04
#   test loss: 2.60e-04
#   test metric: []
#
# 'train' took 9.979240 s
#
# Mean residual: 1.399e-02
# Adding new point: [ 9.262087 13.175191]
#
# Compiling model...
# 'compile' took 0.172032 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 157556    [2.91e-04]    [2.72e-04]    []
# 158000    [3.89e-02]    [3.87e-02]    []
# 159000    [1.31e-02]    [1.31e-02]    []
# Epoch 159557: early stopping
#
# Best model at step 157556:
#   train loss: 2.91e-04
#   test loss: 2.72e-04
#   test metric: []
#
# 'train' took 10.568288 s
#
# Compiling model...
# 'compile' took 0.126111 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 159557    [1.74e-01]    [1.73e-01]    []
# 160000    [3.43e-04]    [3.43e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000287
#   Number of iterations: 823
#   Number of functions evaluations: 896
# 160453    [2.87e-04]    [2.68e-04]    []
#
# Best model at step 160453:
#   train loss: 2.87e-04
#   test loss: 2.68e-04
#   test metric: []
#
# 'train' took 10.357346 s
#
# Mean residual: 1.408e-02
# Adding new point: [ 1.7418919 63.473946 ]
#
# Compiling model...
# 'compile' took 0.169291 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 160453    [2.88e-04]    [2.68e-04]    []
# 161000    [3.56e-04]    [3.37e-04]    []
# 162000    [1.25e-03]    [1.23e-03]    []
# Epoch 162454: early stopping
#
# Best model at step 160453:
#   train loss: 2.88e-04
#   test loss: 2.68e-04
#   test metric: []
#
# 'train' took 10.630262 s
#
# Compiling model...
# 'compile' took 0.130509 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 162454    [5.39e-02]    [5.38e-02]    []
# 163000    [2.99e-04]    [2.99e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000274
#   Number of iterations: 758
#   Number of functions evaluations: 805
# 163259    [2.74e-04]    [2.56e-04]    []
#
# Best model at step 163259:
#   train loss: 2.74e-04
#   test loss: 2.56e-04
#   test metric: []
#
# 'train' took 9.830239 s
#
# Mean residual: 1.353e-02
# Adding new point: [17.515757   1.1264863]
#
# Compiling model...
# 'compile' took 0.171263 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 163259    [2.76e-04]    [2.56e-04]    []
# 164000    [2.47e-03]    [2.44e-03]    []
# 165000    [6.38e-04]    [6.19e-04]    []
# Epoch 165260: early stopping
#
# Best model at step 163259:
#   train loss: 2.76e-04
#   test loss: 2.56e-04
#   test metric: []
#
# 'train' took 10.751303 s
#
# Compiling model...
# 'compile' took 0.137881 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 165260    [8.19e-04]    [8.00e-04]    []
# 166000    [2.71e-04]    [2.71e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000251
#   Number of iterations: 1022
#   Number of functions evaluations: 1112
# 166372    [2.51e-04]    [2.31e-04]    []
#
# Best model at step 166372:
#   train loss: 2.51e-04
#   test loss: 2.31e-04
#   test metric: []
#
# 'train' took 12.395224 s
#
# Mean residual: 1.298e-02
# Adding new point: [ 3.593403 48.65602 ]
#
# Compiling model...
# 'compile' took 0.170570 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 166372    [2.53e-04]    [2.31e-04]    []
# 167000    [3.20e-04]    [3.00e-04]    []
# 168000    [5.71e-04]    [5.52e-04]    []
# Epoch 168373: early stopping
#
# Best model at step 166372:
#   train loss: 2.53e-04
#   test loss: 2.31e-04
#   test metric: []
#
# 'train' took 10.753697 s
#
# Compiling model...
# 'compile' took 0.133812 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 168373    [2.32e-03]    [2.29e-03]    []
# 169000    [2.79e-04]    [2.79e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000278
#   Number of iterations: 610
#   Number of functions evaluations: 659
# 169032    [2.78e-04]    [2.59e-04]    []
#
# Best model at step 166372:
#   train loss: 2.53e-04
#   test loss: 2.31e-04
#   test metric: []
#
# 'train' took 9.048255 s
#
# Mean residual: 1.335e-02
# Adding new point: [17.515757   1.1264863]
#
# Compiling model...
# 'compile' took 0.170416 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 169032    [2.79e-04]    [2.59e-04]    []
# 170000    [2.91e-04]    [2.72e-04]    []
# 171000    [1.40e-03]    [1.37e-03]    []
# Epoch 171033: early stopping
#
# Best model at step 169032:
#   train loss: 2.79e-04
#   test loss: 2.59e-04
#   test metric: []
#
# 'train' took 10.980251 s
#
# Compiling model...
# 'compile' took 0.145093 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 171033    [3.46e-02]    [3.44e-02]    []
# 172000    [2.55e-04]    [2.55e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000252
#   Number of iterations: 956
#   Number of functions evaluations: 1027
# 172060    [2.52e-04]    [2.33e-04]    []
#
# Best model at step 172060:
#   train loss: 2.52e-04
#   test loss: 2.33e-04
#   test metric: []
#
# 'train' took 12.143515 s
#
# Mean residual: 1.288e-02
# Adding new point: [42.027676  1.207613]
#
# Compiling model...
# 'compile' took 0.199300 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 172060    [2.53e-04]    [2.33e-04]    []
# 173000    [3.07e-04]    [2.86e-04]    []
# 174000    [3.40e-04]    [3.21e-04]    []
# Epoch 174061: early stopping
#
# Best model at step 172060:
#   train loss: 2.53e-04
#   test loss: 2.33e-04
#   test metric: []
#
# 'train' took 11.111570 s
#
# Compiling model...
# 'compile' took 0.138549 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 174061    [1.25e-01]    [1.24e-01]    []
# 175000    [2.60e-04]    [2.60e-04]
# 176000    [2.09e-04]    [2.09e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000174
#   Number of iterations: 2700
#   Number of functions evaluations: 2938
# 176999    [1.74e-04]    [1.59e-04]    []
#
# Best model at step 176999:
#   train loss: 1.74e-04
#   test loss: 1.59e-04
#   test metric: []
#
# 'train' took 26.738121 s
#
# Mean residual: 1.027e-02
# Adding new point: [  3.1678443 199.68407  ]
#
# Compiling model...
# 'compile' took 0.178254 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 176999    [1.76e-04]    [1.59e-04]    []
# 177000    [8.69e+00]    [8.49e+00]    []
# 178000    [2.44e-04]    [2.29e-04]    []
# 179000    [5.22e-03]    [5.19e-03]    []
# 180000    [2.86e-03]    [2.84e-03]    []
# Epoch 180000: early stopping
#
# Best model at step 176999:
#   train loss: 1.76e-04
#   test loss: 1.59e-04
#   test metric: []
#
# 'train' took 14.935678 s
#
# Compiling model...
# 'compile' took 0.140686 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 180000    [2.86e-03]    [2.84e-03]    []
# 181000    [1.96e-04]    [1.96e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000188
#   Number of iterations: 1083
#   Number of functions evaluations: 1173
# 181173    [1.88e-04]    [1.71e-04]    []
#
# Best model at step 176999:
#   train loss: 1.76e-04
#   test loss: 1.59e-04
#   test metric: []
#
# 'train' took 13.458187 s
#
# Mean residual: 1.075e-02
# Adding new point: [  2.4734862 183.71416  ]
#
# Compiling model...
# 'compile' took 0.181900 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 181173    [1.90e-04]    [1.71e-04]    []
# 182000    [3.40e-02]    [3.41e-02]    []
# 183000    [6.19e-03]    [6.18e-03]    []
# Epoch 183174: early stopping
#
# Best model at step 181173:
# ...
# 566576    [2.36e-04]    [2.21e-04]    []
# 567000    [2.05e-04]    [2.05e-04]
# 568000    [1.69e-04]    [1.69e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000159
#   Number of iterations: 1755
#   Number of functions evaluations: 1897
# 568473    [1.59e-04]    [1.47e-04]    []
#
# Best model at step 568473:
#   train loss: 1.59e-04
#   test loss: 1.47e-04
#   test metric: []
#
# 'train' took 120.587601 s
#
# Mean residual: 1.069e-02
# Adding new point: [  0.44679734 155.64586   ]
#
# Compiling model...
# 'compile' took 3.031653 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 568473    [1.59e-04]    [1.47e-04]    []
# 569000    [2.18e-04]    [2.01e-04]    []
# 570000    [7.89e-04]    [7.59e-04]    []
# Epoch 570474: early stopping
#
# Best model at step 568473:
#   train loss: 1.59e-04
#   test loss: 1.47e-04
#   test metric: []
#
# 'train' took 109.657635 s
#
# Compiling model...
# 'compile' took 3.301707 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 570474    [4.82e-03]    [4.72e-03]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000183
#   Number of iterations: 103
#   Number of functions evaluations: 124
# 570598    [1.83e-04]    [1.68e-04]    []
#
# Best model at step 568473:
#   train loss: 1.59e-04
#   test loss: 1.47e-04
#   test metric: []
#
# 'train' took 122.355310 s
#
# Mean residual: 1.081e-02
# Adding new point: [114.62061     2.9339507]
#
# Compiling model...
# 'compile' took 4.419033 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 570598    [1.83e-04]    [1.68e-04]    []
# 571000    [2.24e-04]    [2.06e-04]    []
# 572000    [2.05e-04]    [1.90e-04]    []
# Epoch 572599: early stopping
#
# Best model at step 570598:
#   train loss: 1.83e-04
#   test loss: 1.68e-04
#   test metric: []
#
# 'train' took 112.064698 s
#
# Compiling model...
# 'compile' took 1.536921 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 572599    [2.33e-03]    [2.30e-03]    []
# 573000    [1.87e-04]    [1.87e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000183
#   Number of iterations: 471
#   Number of functions evaluations: 504
# 573103    [1.83e-04]    [1.66e-04]    []
#
# Best model at step 573103:
#   train loss: 1.83e-04
#   test loss: 1.66e-04
#   test metric: []
#
# 'train' took 117.251682 s
#
# Mean residual: 1.083e-02
# Adding new point: [11.783615 25.60189 ]
#
# Compiling model...
# 'compile' took 5.018408 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 573103    [1.83e-04]    [1.66e-04]    []
# 574000    [5.40e-03]    [5.34e-03]    []
# 575000    [1.19e-02]    [1.20e-02]    []
# Epoch 575104: early stopping
#
# Best model at step 573103:
#   train loss: 1.83e-04
#   test loss: 1.66e-04
#   test metric: []
#
# 'train' took 110.076131 s
#
# Compiling model...
# 'compile' took 2.070548 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 575104    [1.24e-01]    [1.23e-01]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000196
#   Number of iterations: 252
#   Number of functions evaluations: 284
# 575388    [1.96e-04]    [1.79e-04]    []
#
# Best model at step 573103:
#   train loss: 1.83e-04
#   test loss: 1.66e-04
#   test metric: []
#
# 'train' took 115.972456 s
#
# Mean residual: 1.098e-02
# Adding new point: [ 28.452364 197.89888 ]
#
# Compiling model...
# 'compile' took 4.237932 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 575388    [1.97e-04]    [1.79e-04]    []
# 576000    [8.40e-02]    [8.49e-02]    []
# 577000    [2.68e-04]    [2.46e-04]    []
# Epoch 577389: early stopping
#
# Best model at step 575388:
#   train loss: 1.97e-04
#   test loss: 1.79e-04
#   test metric: []
#
# 'train' took 138.600188 s
#
# Compiling model...
# 'compile' took 3.238865 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 577389    [2.69e-04]    [2.54e-04]    []
# 578000    [1.82e-04]    [1.82e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000171
#   Number of iterations: 937
#   Number of functions evaluations: 1036
# 578425    [1.71e-04]    [1.55e-04]    []
#
# Best model at step 578425:
#   train loss: 1.71e-04
#   test loss: 1.55e-04
#   test metric: []
#
# 'train' took 137.617523 s
#
# Mean residual: 1.087e-02
# Adding new point: [  0.44679734 155.64586   ]
#
# Compiling model...
# 'compile' took 5.698502 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 578425    [1.71e-04]    [1.55e-04]    []
# 579000    [1.83e-04]    [1.65e-04]    []
# 580000    [8.35e-04]    [8.24e-04]    []
# Epoch 580426: early stopping
#
# Best model at step 578425:
#   train loss: 1.71e-04
#   test loss: 1.55e-04
#   test metric: []
#
# 'train' took 118.129303 s
#
# Compiling model...
# 'compile' took 1.648860 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 580426    [7.36e-03]    [7.29e-03]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000181
#   Number of iterations: 381
#   Number of functions evaluations: 406
# 580832    [1.81e-04]    [1.65e-04]    []
#
# Best model at step 578425:
#   train loss: 1.71e-04
#   test loss: 1.55e-04
#   test metric: []
#
# 'train' took 120.562421 s
#
# Mean residual: 1.089e-02
# Adding new point: [0.2144504 8.161018 ]
#
# Compiling model...
# 'compile' took 2.311152 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 580832    [1.82e-04]    [1.65e-04]    []
# 581000    [3.23e-04]    [2.92e-04]    []
# 582000    [2.13e-02]    [2.15e-02]    []
# Epoch 582833: early stopping
#
# Best model at step 580832:
#   train loss: 1.82e-04
#   test loss: 1.65e-04
#   test metric: []
#
# 'train' took 123.610948 s
#
# Compiling model...
# 'compile' took 2.979374 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 582833    [1.73e-03]    [1.74e-03]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000207
#   Number of iterations: 112
#   Number of functions evaluations: 130
# 582963    [2.07e-04]    [1.89e-04]    []
#
# Best model at step 580832:
#   train loss: 1.82e-04
#   test loss: 1.65e-04
#   test metric: []
#
# 'train' took 124.287539 s
#
# Mean residual: 1.108e-02
# Adding new point: [  6.814333 160.57275 ]
#
# Compiling model...
# 'compile' took 4.027701 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 582963    [2.07e-04]    [1.89e-04]    []
# 583000    [5.09e-02]    [5.21e-02]    []
# 584000    [2.09e-04]    [1.92e-04]    []
# Epoch 584964: early stopping
#
# Best model at step 582963:
#   train loss: 2.07e-04
#   test loss: 1.89e-04
#   test metric: []
#
# 'train' took 120.816511 s
#
# Compiling model...
# 'compile' took 1.783864 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 584964    [4.76e-02]    [4.73e-02]    []
# 585000    [2.48e-04]    [2.48e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000198
#   Number of iterations: 433
#   Number of functions evaluations: 464
# 585428    [1.98e-04]    [1.80e-04]    []
#
# Best model at step 585428:
#   train loss: 1.98e-04
#   test loss: 1.80e-04
#   test metric: []
#
# 'train' took 129.090178 s
#
# Mean residual: 1.130e-02
# Adding new point: [14.5950985 20.499468 ]
#
# Compiling model...
# 'compile' took 4.595225 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 585428    [1.98e-04]    [1.80e-04]    []
# 586000    [9.88e-04]    [9.72e-04]    []
# 587000    [2.94e-04]    [2.79e-04]    []
# Epoch 587429: early stopping
#
# Best model at step 585428:
#   train loss: 1.98e-04
#   test loss: 1.80e-04
#   test metric: []
#
# 'train' took 113.690543 s
#
# Compiling model...
# 'compile' took 2.111097 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 587429    [8.72e-04]    [8.62e-04]    []
# 588000    [1.86e-04]    [1.86e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000179
#   Number of iterations: 733
#   Number of functions evaluations: 784
# 588213    [1.79e-04]    [1.63e-04]    []
#
# Best model at step 588213:
#   train loss: 1.79e-04
#   test loss: 1.63e-04
#   test metric: []
#
# 'train' took 162.737009 s
#
# Mean residual: 1.099e-02
# Adding new point: [  2.0586333 163.89992  ]
#
# Compiling model...
# 'compile' took 6.173074 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 588213    [1.79e-04]    [1.63e-04]    []
# 589000    [1.84e-04]    [1.67e-04]    []
# 590000    [1.80e-04]    [1.64e-04]    []
# Epoch 590214: early stopping
#
# Best model at step 588213:
#   train loss: 1.79e-04
#   test loss: 1.63e-04
#   test metric: []
#
# 'train' took 132.760382 s
#
# Compiling model...
# 'compile' took 4.663996 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 590214    [1.85e-04]    [1.69e-04]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000185
#   Number of iterations: 2
#   Number of functions evaluations: 16
# 590230    [1.85e-04]    [1.69e-04]    []
#
# Best model at step 588213:
#   train loss: 1.79e-04
#   test loss: 1.63e-04
#   test metric: []
#
# 'train' took 126.106169 s
#
# Mean residual: 1.098e-02
# Adding new point: [  1.0727661 161.67989  ]
#
# Compiling model...
# 'compile' took 2.768430 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 590230    [1.85e-04]    [1.69e-04]    []
# 591000    [1.81e-04]    [1.67e-04]    []
# 592000    [3.96e-02]    [3.95e-02]    []
# Epoch 592231: early stopping
#
# Best model at step 591000:
#   train loss: 1.81e-04
#   test loss: 1.67e-04
#   test metric: []
#
# 'train' took 126.103085 s
#
# Compiling model...
# 'compile' took 1.530696 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 592231    [1.78e-03]    [1.78e-03]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000179
#   Number of iterations: 440
#   Number of functions evaluations: 473
# 592704    [1.79e-04]    [1.63e-04]    []
#
# Best model at step 592704:
#   train loss: 1.79e-04
#   test loss: 1.63e-04
#   test metric: []
#
# 'train' took 135.914472 s
#
# Mean residual: 1.089e-02
# Adding new point: [  0.54772526 142.91737   ]
#
# Compiling model...
# 'compile' took 9.648314 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 592704    [1.80e-04]    [1.63e-04]    []
# 593000    [2.44e-04]    [2.23e-04]    []
# 594000    [1.64e-03]    [1.59e-03]    []
# Epoch 594705: early stopping
#
# Best model at step 592704:
#   train loss: 1.80e-04
#   test loss: 1.63e-04
#   test metric: []
#
# 'train' took 126.479120 s
#
# Compiling model...
# 'compile' took 3.747129 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 594705    [4.29e-02]    [4.22e-02]    []
# 595000    [2.08e-04]    [2.08e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000177
#   Number of iterations: 823
#   Number of functions evaluations: 880
# 595585    [1.77e-04]    [1.61e-04]    []
#
# Best model at step 595585:
#   train loss: 1.77e-04
#   test loss: 1.61e-04
#   test metric: []
#
# 'train' took 169.129685 s
#
# Mean residual: 1.103e-02
# Adding new point: [7.0777683 5.9866915]
#
# Compiling model...
# 'compile' took 6.382095 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 595585    [1.77e-04]    [1.61e-04]    []
# 596000    [2.14e-04]    [1.96e-04]    []
# 597000    [1.75e-04]    [1.60e-04]    []
# Epoch 597586: early stopping
#
# Best model at step 597000:
#   train loss: 1.75e-04
#   test loss: 1.60e-04
#   test metric: []
#
# 'train' took 168.940929 s
#
# Compiling model...
# 'compile' took 6.219950 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 597586    [1.82e-04]    [1.67e-04]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000182
#   Number of iterations: 3
#   Number of functions evaluations: 28
# 597614    [1.82e-04]    [1.67e-04]    []
#
# Best model at step 597000:
#   train loss: 1.75e-04
#   test loss: 1.60e-04
#   test metric: []
#
# 'train' took 151.615277 s
#
# Mean residual: 1.094e-02
# Adding new point: [  9.921028 110.68406 ]
#
# Compiling model...
# 'compile' took 129.730605 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 597614    [1.83e-04]    [1.67e-04]    []
# 598000    [2.23e-04]    [2.01e-04]    []
# 599000    [1.22e-03]    [1.20e-03]    []
# Epoch 599615: early stopping
#
# Best model at step 597614:
#   train loss: 1.83e-04
#   test loss: 1.67e-04
#   test metric: []
#
# 'train' took 339.700596 s
#
# Compiling model...
# 'compile' took 7.627590 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 599615    [2.10e-04]    [1.93e-04]    []
# 600000    [1.76e-04]    [1.76e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000168
#   Number of iterations: 619
#   Number of functions evaluations: 699
# 600314    [1.68e-04]    [1.53e-04]    []
#
# Best model at step 600314:
#   train loss: 1.68e-04
#   test loss: 1.53e-04
#   test metric: []
#
# 'train' took 192.266856 s
#
# Mean residual: 1.080e-02
# Adding new point: [ 8.3494005 48.828102 ]
#
# Compiling model...
# 'compile' took 7.904076 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 600314    [1.68e-04]    [1.53e-04]    []
# 601000    [1.79e-04]    [1.63e-04]    []
# 602000    [6.05e-02]    [6.03e-02]    []
# Epoch 602315: early stopping
#
# Best model at step 600314:
#   train loss: 1.68e-04
#   test loss: 1.53e-04
#   test metric: []
#
# 'train' took 158.265527 s
#
# Compiling model...
# 'compile' took 4.008525 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 602315    [5.93e-03]    [6.04e-03]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000178
#   Number of iterations: 446
#   Number of functions evaluations: 498
# 602813    [1.78e-04]    [1.62e-04]    []
#
# Best model at step 600314:
#   train loss: 1.68e-04
#   test loss: 1.53e-04
#   test metric: []
#
# 'train' took 136.413818 s
# Mean residual: 1.080e-02
# Adding new point: [  3.8402154 187.75739  ]
#
# Compiling model...
# 'compile' took 9.947185 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 602813    [1.78e-04]    [1.62e-04]    []
# 603000    [3.69e-04]    [3.45e-04]    []
# 604000    [9.40e-04]    [9.04e-04]    []
# Epoch 604814: early stopping
#
# Best model at step 602813:
#   train loss: 1.78e-04
#   test loss: 1.62e-04
#   test metric: []
#
# 'train' took 193.098668 s
#
# Compiling model...
# 'compile' took 5.134551 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 604814    [6.98e-02]    [6.84e-02]    []
# 605000    [2.08e-04]    [2.08e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000188
#   Number of iterations: 351
#   Number of functions evaluations: 384
# 605198    [1.88e-04]    [1.71e-04]    []
#
# Best model at step 602813:
#   train loss: 1.78e-04
#   test loss: 1.62e-04
#   test metric: []
#
# 'train' took 141.228773 s
#
# Saving loss history to /Users/zhangtianjie/Documents/GitHub/P-rheologynet/first-try/RAR/loss.dat ...
# Saving training data to /Users/zhangtianjie/Documents/GitHub/P-rheologynet/first-try/RAR/train.dat ...
# Saving test data to /Users/zhangtianjie/Documents/GitHub/P-rheologynet/first-try/RAR/test.dat ...

# %% [markdown]
# # FNN training

# %%
import pandas as pd
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_absolute_error

train=np.loadtxt('train.dat', unpack = True)

x_train = train[[0,1]].T
y_train = train[2]

clf = MLPRegressor(hidden_layer_sizes=(50,50,50),max_iter=50000)

clf.fit(x_train, y_train)
# Out:
# MLPRegressor(hidden_layer_sizes=(50, 50, 50), max_iter=50000)

# %%
train1=np.loadtxt('train.dat', unpack = True)
pd.DataFrame(train1.T,columns=['x','t','shear stress'])
# Out:
#                x           t  shear stress
# 0       3.840215  187.757385    235.764755
# 1       8.349401   48.828102    105.172897
# 2       9.921028  110.684059    162.963257
# 3       7.077768    5.986691     25.892986
# 4       0.547725  142.917374    227.243622
# ...          ...         ...           ...
# 4695    2.596431  105.316566    183.847534
# 4696  117.335678  133.616562     83.290253
# 4697  144.232864   48.394085     50.608208
# 4698  151.223511   85.497261     66.009888
# 4699   32.168850  161.697510    126.920052
#
# [4700 rows x 3 columns]

# %%
x = np.linspace(0, 200, 200)
t = np.linspace(0, 200, 200)
X, T = np.meshgrid(x, t)

X_star = np.hstack((X.flatten()[:, None], T.flatten()[:, None]))

# %% [markdown]
# # solution

# %%
new_points = pd.DataFrame(new_points, columns=['x', 'y'])
new_points
# Out:
#             x           y
# 0    1.015576  199.427261
# 1    0.531934  185.394257
# 2    1.015576  199.427261
# 3    0.531934  185.394257
# 4    7.132157    2.735061
# ..        ...         ...
# 195  0.547725  142.917374
# 196  7.077768    5.986691
# 197  9.921028  110.684059
# 198  8.349401   48.828102
# 199  3.840215  187.757385
#
# [200 rows x 2 columns]

# %%
# tau
import pandas as pd
train_lambda=np.loadtxt('train.dat', unpack = True)
train_lambda = pd.DataFrame(train_lambda.T)

ext = griddata(X_star, solution(X_star[:,0],X_star[:,1]), (X, T), method="cubic")
fig, ax = plt.subplots()
h=ax.contourf(X,T, ext,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title(r'$\mathbf{\tau_{P-RheologyNet+R} }$',fontproperties = 'Times New Roman', size = 14)
# plt.yticks(fontproperties = 'Times New Roman', size = 14)
# plt.xticks(fontproperties = 'Times New Roman', size = 14)

plt.scatter(train_lambda[0],train_lambda[1],c='black',s=1)

# plt.scatter(train_lambda[4499:-1][0],train_lambda[4499:-1][1],c='red',s=1)

plt.scatter(new_points['x'],new_points['y'],c='red',s=1,marker='+')

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('tau-solution.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:8: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'

# %%
train_lambda=np.loadtxt('train.dat', unpack = True)
train_lambda = pd.DataFrame(train_lambda.T)
ext = griddata(X_star, solution(X_star[:,0],X_star[:,1]), (X, T), method="cubic")
fig, ax = plt.subplots()
h=ax.contourf(X,T, ext/T,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title(r'$\mathbf{\eta _{FEA}}$',fontproperties = 'Times New Roman', size = 14)
plt.scatter(train_lambda[0],train_lambda[1],c='black',s=1)
# plt.yticks(fontproperties = 'Times New Roman', size = 14)
# plt.xticks(fontproperties = 'Times New Roman', size = 14)

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)

plt.savefig('viscosity-solution.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
#   """

# %% [markdown]
# # pinn prediction part: tau, lambda, eta, error.

# %%
x = np.linspace(0, 200, 200)
t = np.linspace(0, 200, 200)
X, T = np.meshgrid(x, t)

X_star = np.hstack((X.flatten()[:, None], T.flatten()[:, None]))

import time
start=time.time()
prediction = model.predict(X_star, operator=None)
end=time.time()
time_pinn = end-start
print(time_pinn)

pinn_pre = griddata(X_star, prediction[:, 0], (X, T), method="cubic")

fig, ax = plt.subplots()
h=ax.contourf(X,T, pinn_pre,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title(r'$\mathbf{\tau _{P-RheologyNet+R} }$',fontproperties = 'Times New Roman', size = 14)
# plt.yticks(fontproperties = 'Times New Roman', size = 14)
# plt.xticks(fontproperties = 'Times New Roman', size = 14)


from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('tau-pinn.png',dpi=600,bbox_inches = 'tight')
# Out:
# 4.713123083114624
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'

# %% [markdown]
# # eta

# %%
from matplotlib import ticker, cm
x = np.linspace(0, 200, 200)
t = np.linspace(0, 200, 200)
X, T = np.meshgrid(x, t)

X_star = np.hstack((X.flatten()[:, None], T.flatten()[:, None]))
prediction = model.predict(X_star, operator=None)

pinn_pre = griddata(X_star, prediction[:, 0], (X, T), method="cubic")

fig, ax = plt.subplots()
# norm = matplotlib.colors.Normalize(vmin=0, vmax=100)
h=ax.contourf(X,T, pinn_pre/T,cmap="viridis",origin='lower',aspect='auto',interpolation='nearest')
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title(r'$\mathbf{\eta _{P-RheologyNet+R} }$',fontproperties = 'Times New Roman', size = 14)


from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('eta-pinn.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in true_divide
#   del sys.path[0]
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
#   del sys.path[0]

# %% [markdown]
# # nn pre

# %%
x = np.linspace(0, 200, 200)
t = np.linspace(0, 200, 200)
X, T = np.meshgrid(x, t)

X_star = np.hstack((X.flatten()[:, None], T.flatten()[:, None]))

start_fnn=time.time()
prediction = clf.predict(X_star)
end_fnn=time.time()
time_fnn = end_fnn-start_fnn
print(time_fnn)

pre_nn = griddata(X_star, prediction, (X, T), method="cubic")

fig, ax = plt.subplots()
h=ax.contourf(X,T, pre_nn,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title(r'$\mathbf{\tau _{FNN} }$ ',fontproperties = 'Times New Roman', size = 14)

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('tau-FNN.png',dpi=600,bbox_inches = 'tight')
# Out:
# 0.023235082626342773
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
#   app.launch_new_instance()

# %%
x = np.linspace(0, 200, 200)
t = np.linspace(0, 200, 200)
X, T = np.meshgrid(x, t)

X_star = np.hstack((X.flatten()[:, None], T.flatten()[:, None]))

prediction = clf.predict(X_star)

pre_nn = griddata(X_star, prediction, (X, T), method="cubic")

fig, ax = plt.subplots()
h=ax.contourf(X,T, pre_nn/T,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title(r'$\mathbf{\eta _{FNN} }$ ',fontproperties = 'Times New Roman', size = 14)

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('FNN_pre.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in true_divide
#   if sys.path[0] == '':
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
#   if sys.path[0] == '':

# %% [markdown]
# # nn err

# %%
err_nn = abs(pre_nn-ext)
fig, ax = plt.subplots()
h=ax.contourf(X,T, err_nn,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title(r'$\mathbf{\varepsilon _{\tau ,FNN}   } $ ',fontproperties = 'Times New Roman', size = 14)

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('err_tau-FNN.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
err_nn = abs(pre_nn/T-ext/T)
fig, ax = plt.subplots()
h=ax.contourf(X,T, err_nn,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest',locator=ticker.LogLocator())
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title(r'$\mathbf{\varepsilon _{\eta ,FNN}   } $ ',fontproperties = 'Times New Roman', size = 14)

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('err-FNN-eta.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in subtract
#   """Entry point for launching an IPython kernel.
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # pinn error

# %%
from matplotlib import ticker, cm
err_pinn_tau = abs(pinn_pre-ext)
fig, ax = plt.subplots()
h=ax.contourf(X,T, err_pinn_tau,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title(r'$\mathbf{\varepsilon _{\tau ,P-RheologyNet+R}  } $ ',fontproperties = 'Times New Roman', size = 14)

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('err-rn-tau.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
#   after removing the cwd from sys.path.

# %%
err_pinn_eta = abs(pinn_pre/T-ext/T)
fig, ax = plt.subplots()
h=ax.contourf(X,T, err_pinn_eta,cmap="viridis",origin='lower',aspect='auto',interpolation='nearest',locator=ticker.LogLocator())
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title(r'$\mathbf{\varepsilon _{\eta ,P-RheologyNet+R}  } $ ',fontproperties = 'Times New Roman', size = 14)

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('err-rn-eta.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in subtract
#   """Entry point for launching an IPython kernel.
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # PINN MSE

# %%
from sklearn.metrics import mean_squared_error
eta_pre= pinn_pre/T
eta_pre[eta_pre>1e308]=0

eta_ext=ext/T
eta_ext[eta_ext>1e308]=0
eta_nn = pre_nn/T

eta_nn[eta_nn>1e308]=0

print('tau-mse-pinn',mean_squared_error(pinn_pre,ext))
print('eta-mse-pinn',mean_squared_error(eta_pre,eta_ext))
print('tau-mse-fnn',mean_squared_error(pre_nn,ext))
print('eta-mse-fnn',mean_squared_error(eta_nn,eta_ext))

print('pinn_time',time_pinn)
print('fnn_time',time_fnn)
# Out:
# tau-mse-pinn 0.00020016934299833567
# eta-mse-pinn 2.908792139897443e-06
# tau-mse-fnn 0.6873418107383117
# eta-mse-fnn 0.0024503145188848412
# pinn_time 4.713123083114624
# fnn_time 0.023235082626342773
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
#
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in true_divide
#   import sys
