# %%
import deepxde as dde
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy.interpolate import griddata
import scipy.io
import tensorflow as tf
# Out:
# Using backend: tensorflow.compat.v1
# WARNING:tensorflow:From /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/deepxde/nn/initializers.py:118: The name tf.keras.initializers.he_normal is deprecated. Please use tf.compat.v1.keras.initializers.he_normal instead.

# %%
def PDE(x,y):
    
    # x[0]=x,x[1]=t
    a = 688
    b = 40.1
    
    dy_t = dde.grad.jacobian(y, x,i=0,j=1)
    
    k2 = x[:,0:1]/(a+b*x[:,0:1])
    
    eq1 =  k2*y + dy_t
 
    return eq1

def solution1(x,t):
    a = 688
    b = 40.1
    
    y= np.exp(-x*t/(a+b*x))
    
    return y



geom = dde.geometry.Interval(0, 200)
timedomain = dde.geometry.TimeDomain(0, 200)
geomtime = dde.geometry.GeometryXTime(geom, timedomain)

def boundary(x, on_boundary):
    return on_boundary and np.isclose(x[0], 0)

def func(x):
    return 1


bc = dde.icbc.DirichletBC(geomtime, func, boundary)

ic = dde.icbc.IC(
    geomtime,
    lambda x: 1,
    lambda _, on_initial: on_initial,
)


def func1(x):
    
    return solution1(x[:,0:1],x[:,1:2])

data = dde.data.TimePDE(geomtime, PDE, [bc,ic] , 3500, 100,train_distribution='pseudo',solution=func1, num_initial=600, num_test=None)

layer_size = [2] + [50] * 3 + [1]
activation = "tanh"
initializer = "Glorot uniform"
net = dde.maps.FNN(layer_size, activation, initializer)

model = dde.Model(data, net)
model.compile("adam", lr=0.001)
losshistory, train_state = model.train(epochs=50000)

X = geomtime.random_points(10000)
err = 1
# itr = 0

# for itr in range(5):
#     if err > 0.005:
new_points = []
for i in range(200):
    f = model.predict(X, operator=PDE)
    err_eq = np.absolute(f)
    err = np.mean(err_eq)
    print("Mean residual: %.3e" % (err))

    x_id = np.argmax(err_eq)
    print("Adding new point:", X[x_id], "\n")
    new_points.append(X[x_id])
    data.add_anchors(X[x_id])
    early_stopping = dde.callbacks.EarlyStopping(min_delta=1e-4, patience=2000)
    model.compile("adam", lr=1e-3)
    model.train(iterations=10000, disregard_previous_best=True, callbacks=[early_stopping])
    model.compile("L-BFGS")
    losshistory, train_state = model.train()
#     itr = itr+1
#     print('itr:',itr)
        
dde.saveplot(losshistory, train_state, issave=True, isplot=True)

# X, y_true = gen_testdata()
# y_pred = model.predict(X)
# print("L2 relative error:", dde.metrics.l2_relative_error(y_true, y_pred))
# np.savetxt("test.dat", np.hstack((X, y_true, y_pred)))

# dde.saveplot(losshistory, train_state, issave=True, isplot=True)
# Out:
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.064229 s
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/deepxde/nn/tensorflow_compat_v1/fnn.py:110: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   kernel_constraint=self.kernel_constraint,
# 2023-09-14 17:04:58.651449: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 'compile' took 0.278239 s
#
# Warning: epochs is deprecated and will be removed in a future version. Use iterations instead.
# Initializing variables...
# Training model...
# 2023-09-14 17:04:58.875387: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# Step      Train loss                        Test loss                         Test metric
# 0         [1.13e-04, 9.22e-01, 1.65e+00]    [1.13e-04, 9.22e-01, 1.65e+00]    []
# 1000      [1.27e-04, 3.19e-06, 1.80e-05]    [1.27e-04, 3.19e-06, 1.80e-05]    []
# 2000      [5.90e-05, 7.63e-07, 3.13e-06]    [5.90e-05, 7.63e-07, 3.13e-06]    []
# 3000      [3.61e-05, 5.35e-06, 4.78e-06]    [3.61e-05, 5.35e-06, 4.78e-06]    []
# 4000      [2.57e-05, 1.41e-05, 1.52e-05]    [2.57e-05, 1.41e-05, 1.52e-05]    []
# 5000      [1.70e-05, 2.37e-07, 2.34e-07]    [1.70e-05, 2.37e-07, 2.34e-07]    []
# 6000      [1.56e-05, 3.10e-04, 1.19e-06]    [1.56e-05, 3.10e-04, 1.19e-06]    []
# 7000      [1.22e-05, 2.58e-06, 8.85e-08]    [1.22e-05, 2.58e-06, 8.85e-08]    []
# 8000      [8.38e-06, 3.25e-08, 5.44e-08]    [8.38e-06, 3.25e-08, 5.44e-08]    []
# 9000      [6.22e-06, 2.07e-08, 4.72e-08]    [6.22e-06, 2.07e-08, 4.72e-08]    []
# 10000     [4.66e-06, 1.76e-05, 2.38e-06]    [4.66e-06, 1.76e-05, 2.38e-06]    []
# 11000     [3.65e-06, 7.33e-07, 1.27e-05]    [3.65e-06, 7.33e-07, 1.27e-05]    []
# 12000     [2.31e-06, 6.13e-08, 2.16e-06]    [2.31e-06, 6.13e-08, 2.16e-06]    []
# 13000     [1.46e-06, 1.39e-04, 2.21e-05]    [1.46e-06, 1.39e-04, 2.21e-05]    []
# 14000     [1.11e-06, 8.68e-07, 5.31e-07]    [1.11e-06, 8.68e-07, 5.31e-07]    []
# 15000     [8.65e-07, 3.63e-07, 4.42e-07]    [8.65e-07, 3.63e-07, 4.42e-07]    []
# 16000     [6.34e-07, 9.07e-08, 5.38e-07]    [6.34e-07, 9.07e-08, 5.38e-07]    []
# 17000     [5.52e-07, 8.60e-06, 7.26e-05]    [5.52e-07, 8.60e-06, 7.26e-05]    []
# 18000     [4.26e-07, 1.20e-07, 4.28e-05]    [4.26e-07, 1.20e-07, 4.28e-05]    []
# 19000     [3.57e-07, 1.38e-06, 1.84e-07]    [3.57e-07, 1.38e-06, 1.84e-07]    []
# 20000     [3.38e-07, 2.57e-06, 3.62e-08]    [3.38e-07, 2.57e-06, 3.62e-08]    []
# 21000     [4.98e-06, 1.08e-07, 1.97e-08]    [4.98e-06, 1.08e-07, 1.97e-08]    []
# 22000     [1.26e-06, 2.84e-08, 2.15e-08]    [1.26e-06, 2.84e-08, 2.15e-08]    []
# 23000     [1.12e-06, 1.93e-04, 1.62e-04]    [1.12e-06, 1.93e-04, 1.62e-04]    []
# 24000     [4.61e-07, 7.32e-07, 1.02e-06]    [4.61e-07, 7.32e-07, 1.02e-06]    []
# 25000     [2.51e-06, 6.05e-06, 5.28e-05]    [2.51e-06, 6.05e-06, 5.28e-05]    []
# 26000     [2.77e-07, 4.12e-08, 7.17e-07]    [2.77e-07, 4.12e-08, 7.17e-07]    []
# 27000     [2.22e-07, 7.54e-07, 1.13e-06]    [2.22e-07, 7.54e-07, 1.13e-06]    []
# 28000     [2.06e-07, 4.10e-06, 9.93e-07]    [2.06e-07, 4.10e-06, 9.93e-07]    []
# 29000     [1.50e-07, 5.04e-08, 2.74e-08]    [1.50e-07, 5.04e-08, 2.74e-08]    []
# 30000     [1.39e-07, 1.10e-06, 1.79e-06]    [1.39e-07, 1.10e-06, 1.79e-06]    []
# 31000     [2.30e-07, 3.12e-05, 2.65e-06]    [2.30e-07, 3.12e-05, 2.65e-06]    []
# 32000     [9.82e-08, 6.11e-09, 1.21e-07]    [9.82e-08, 6.11e-09, 1.21e-07]    []
# 33000     [2.90e-07, 3.39e-06, 4.28e-07]    [2.90e-07, 3.39e-06, 4.28e-07]    []
# 34000     [7.65e-08, 7.04e-09, 4.60e-07]    [7.65e-08, 7.04e-09, 4.60e-07]    []
# 35000     [6.28e-08, 4.87e-08, 2.10e-08]    [6.28e-08, 4.87e-08, 2.10e-08]    []
# 36000     [6.89e-08, 5.29e-07, 7.60e-09]    [6.89e-08, 5.29e-07, 7.60e-09]    []
# 37000     [5.36e-08, 8.31e-08, 4.20e-07]    [5.36e-08, 8.31e-08, 4.20e-07]    []
# 38000     [4.92e-08, 2.72e-07, 2.01e-07]    [4.92e-08, 2.72e-07, 2.01e-07]    []
# 39000     [4.39e-08, 6.39e-07, 8.93e-07]    [4.39e-08, 6.39e-07, 8.93e-07]    []
# 40000     [1.04e-07, 2.25e-06, 1.18e-05]    [1.04e-07, 2.25e-06, 1.18e-05]    []
# 41000     [3.99e-08, 6.75e-08, 2.06e-07]    [3.99e-08, 6.75e-08, 2.06e-07]    []
# 42000     [5.07e-08, 3.84e-10, 5.90e-10]    [5.07e-08, 3.84e-10, 5.90e-10]    []
# 43000     [4.58e-08, 2.50e-06, 2.34e-08]    [4.58e-08, 2.50e-06, 2.34e-08]    []
# 44000     [3.75e-08, 1.15e-06, 1.60e-06]    [3.75e-08, 1.15e-06, 1.60e-06]    []
# 45000     [3.48e-08, 2.87e-07, 2.98e-07]    [3.48e-08, 2.87e-07, 2.98e-07]    []
# 46000     [3.22e-08, 4.43e-09, 2.19e-07]    [3.22e-08, 4.43e-09, 2.19e-07]    []
# 47000     [5.97e-08, 2.81e-06, 6.39e-09]    [5.97e-08, 2.81e-06, 6.39e-09]    []
# 48000     [7.84e-08, 2.48e-10, 9.20e-10]    [7.84e-08, 2.48e-10, 9.20e-10]    []
# 49000     [3.41e-08, 9.17e-10, 1.26e-08]    [3.41e-08, 9.17e-10, 1.26e-08]    []
# 50000     [2.82e-08, 8.30e-09, 4.73e-10]    [2.82e-08, 8.30e-09, 4.73e-10]    []
#
# Best model at step 50000:
#   train loss: 3.70e-08
#   test loss: 3.70e-08
#   test metric: []
#
# 'train' took 430.226300 s
#
# Mean residual: 1.097e-04
# Adding new point: [2.5961013 4.359893 ]
#
# Compiling model...
# 'compile' took 0.210333 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 50000     [4.04e-08, 8.30e-09, 4.73e-10]    [2.82e-08, 8.30e-09, 4.73e-10]    []
# 51000     [2.61e-08, 2.31e-10, 3.02e-10]    [2.61e-08, 2.31e-10, 3.02e-10]    []
# 52000     [3.16e-08, 4.58e-10, 2.61e-07]    [3.16e-08, 4.58e-10, 2.61e-07]    []
# Epoch 52001: early stopping
#
# Best model at step 51000:
#   train loss: 2.67e-08
#   test loss: 2.66e-08
#   test metric: []
#
# 'train' took 16.681237 s
#
# Compiling model...
# 'compile' took 0.126060 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 52001     [2.64e-08, 2.92e-10, 1.64e-07]    [2.63e-08, 2.92e-10, 1.64e-07]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 122
#   Number of functions evaluations: 164
# 52165     [2.38e-08, 9.49e-11, 2.06e-10]    [2.38e-08, 9.49e-11, 2.06e-10]    []
#
# Best model at step 52165:
#   train loss: 2.41e-08
#   test loss: 2.41e-08
#   test metric: []
#
# 'train' took 1.960221 s
#
# Mean residual: 9.284e-05
# Adding new point: [  1.9073834 171.90921  ]
#
# Compiling model...
# 'compile' took 0.217272 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 52165     [3.33e-08, 9.49e-11, 2.06e-10]    [2.38e-08, 9.49e-11, 2.06e-10]    []
# 53000     [2.97e-08, 1.01e-10, 1.98e-10]    [2.62e-08, 1.01e-10, 1.98e-10]    []
# 54000     [1.03e-07, 6.29e-06, 8.68e-06]    [9.95e-08, 6.29e-06, 8.68e-06]    []
# Epoch 54166: early stopping
#
# Best model at step 53000:
#   train loss: 3.00e-08
#   test loss: 2.65e-08
#   test metric: []
#
# 'train' took 16.749908 s
#
# Compiling model...
# 'compile' took 0.134057 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 54166     [3.69e-08, 4.52e-07, 1.78e-06]    [3.40e-08, 4.52e-07, 1.78e-06]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 125
#   Number of functions evaluations: 141
# 54307     [2.70e-08, 1.06e-10, 1.85e-10]    [2.36e-08, 1.06e-10, 1.85e-10]    []
#
# Best model at step 54307:
#   train loss: 2.73e-08
#   test loss: 2.39e-08
#   test metric: []
#
# 'train' took 1.867254 s
#
# Mean residual: 8.548e-05
# Adding new point: [  1.7186848 175.51282  ]
#
# Compiling model...
# 'compile' took 0.244084 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 54307     [3.63e-08, 1.06e-10, 1.85e-10]    [2.36e-08, 1.06e-10, 1.85e-10]    []
# 55000     [2.23e-08, 5.41e-10, 1.91e-10]    [1.64e-08, 5.41e-10, 1.91e-10]    []
# 56000     [2.57e-08, 5.19e-08, 2.06e-06]    [2.27e-08, 5.19e-08, 2.06e-06]    []
# Epoch 56308: early stopping
#
# Best model at step 55000:
#   train loss: 2.31e-08
#   test loss: 1.72e-08
#   test metric: []
#
# 'train' took 17.006425 s
#
# Compiling model...
# 'compile' took 0.133834 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 56308     [1.42e-08, 2.30e-07, 1.50e-06]    [1.22e-08, 2.30e-07, 1.50e-06]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 55
#   Number of functions evaluations: 98
# 56406     [1.22e-08, 2.20e-10, 1.62e-10]    [1.01e-08, 2.20e-10, 1.62e-10]    []
#
# Best model at step 56406:
#   train loss: 1.25e-08
#   test loss: 1.05e-08
#   test metric: []
#
# 'train' took 1.269447 s
# Mean residual: 8.281e-05
# Adding new point: [  1.9073834 171.90921  ]
#
# Compiling model...
# 'compile' took 0.194049 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 56406     [1.35e-08, 2.20e-10, 1.62e-10]    [1.01e-08, 2.20e-10, 1.62e-10]    []
# 57000     [1.07e-08, 1.69e-10, 1.77e-10]    [9.83e-09, 1.69e-10, 1.77e-10]    []
# 58000     [1.94e-08, 1.05e-06, 3.48e-08]    [1.91e-08, 1.05e-06, 3.48e-08]    []
# Epoch 58407: early stopping
#
# Best model at step 57000:
#   train loss: 1.10e-08
#   test loss: 1.02e-08
#   test metric: []
#
# 'train' took 17.073308 s
#
# Compiling model...
# 'compile' took 0.130237 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 58407     [7.56e-09, 9.19e-11, 2.33e-09]    [7.22e-09, 9.19e-11, 2.33e-09]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 3
#   Number of functions evaluations: 24
# 58431     [7.55e-09, 8.48e-11, 1.34e-10]    [7.21e-09, 8.48e-11, 1.34e-10]    []
#
# Best model at step 58431:
#   train loss: 7.77e-09
#   test loss: 7.43e-09
#   test metric: []
#
# 'train' took 0.699560 s
#
# Mean residual: 7.452e-05
# Adding new point: [5.606766  3.3734243]
#
# Compiling model...
# 'compile' took 0.196498 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 58431     [8.44e-09, 8.48e-11, 1.34e-10]    [7.21e-09, 8.48e-11, 1.34e-10]    []
# 59000     [8.11e-09, 1.51e-10, 1.12e-10]    [7.72e-09, 1.51e-10, 1.12e-10]    []
# 60000     [7.44e-09, 8.55e-10, 8.62e-09]    [7.27e-09, 8.55e-10, 8.62e-09]    []
# Epoch 60432: early stopping
#
# Best model at step 59000:
#   train loss: 8.37e-09
#   test loss: 7.99e-09
#   test metric: []
#
# 'train' took 17.465733 s
#
# Compiling model...
# 'compile' took 0.153316 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 60432     [9.89e-09, 2.57e-08, 7.34e-08]    [9.82e-09, 2.57e-08, 7.34e-08]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 82
#   Number of functions evaluations: 107
# 60539     [6.86e-09, 8.08e-11, 7.07e-11]    [6.75e-09, 8.08e-11, 7.07e-11]    []
#
# Best model at step 60539:
#   train loss: 7.01e-09
#   test loss: 6.90e-09
#   test metric: []
#
# 'train' took 1.783526 s
#
# Mean residual: 7.053e-05
# Adding new point: [2.554278  1.8622324]
#
# Compiling model...
# 'compile' took 0.246650 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 60539     [7.77e-09, 8.08e-11, 7.07e-11]    [6.75e-09, 8.08e-11, 7.07e-11]    []
# 61000     [6.75e-09, 8.26e-11, 8.31e-11]    [6.69e-09, 8.26e-11, 8.31e-11]    []
# 62000     [8.10e-09, 7.51e-08, 1.75e-07]    [7.94e-09, 7.51e-08, 1.75e-07]    []
# Epoch 62540: early stopping
#
# Best model at step 61000:
#   train loss: 6.92e-09
#   test loss: 6.85e-09
#   test metric: []
#
# 'train' took 17.282841 s
#
# Compiling model...
# 'compile' took 0.137459 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 62540     [6.12e-09, 8.74e-11, 9.92e-11]    [6.06e-09, 8.74e-11, 9.92e-11]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 3
#   Number of functions evaluations: 24
# 62564     [6.12e-09, 7.09e-11, 8.24e-11]    [6.06e-09, 7.09e-11, 8.24e-11]    []
#
# Best model at step 62564:
#   train loss: 6.27e-09
#   test loss: 6.21e-09
#   test metric: []
#
# 'train' took 0.849247 s
#
# Mean residual: 6.655e-05
# Adding new point: [1.9712906 1.315768 ]
#
# Compiling model...
# 'compile' took 0.202997 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 62564     [1.66e-08, 7.09e-11, 8.24e-11]    [6.06e-09, 7.09e-11, 8.24e-11]    []
# 63000     [8.31e-09, 6.45e-11, 1.05e-10]    [7.78e-09, 6.45e-11, 1.05e-10]    []
# 64000     [5.80e-09, 1.94e-10, 2.75e-10]    [5.61e-09, 1.94e-10, 2.75e-10]    []
# Epoch 64565: early stopping
#
# Best model at step 64000:
#   train loss: 6.27e-09
#   test loss: 6.08e-09
#   test metric: []
#
# 'train' took 17.253617 s
#
# Compiling model...
# 'compile' took 0.153676 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 64565     [1.23e-08, 1.17e-07, 4.39e-07]    [1.17e-08, 1.17e-07, 4.39e-07]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 93
#   Number of functions evaluations: 108
# 64673     [5.78e-09, 5.86e-11, 1.26e-10]    [5.68e-09, 5.86e-11, 1.26e-10]    []
#
# Best model at step 64673:
#   train loss: 5.97e-09
#   test loss: 5.87e-09
#   test metric: []
#
# 'train' took 1.895394 s
#
# Mean residual: 6.273e-05
# Adding new point: [12.846072   0.4387709]
#
# Compiling model...
# 'compile' took 0.229404 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 64673     [7.27e-09, 5.86e-11, 1.26e-10]    [5.68e-09, 5.86e-11, 1.26e-10]    []
# 65000     [7.82e-09, 6.75e-11, 9.62e-11]    [7.18e-09, 6.75e-11, 9.62e-11]    []
# 66000     [7.97e-09, 4.18e-09, 8.92e-08]    [7.57e-09, 4.18e-09, 8.92e-08]    []
# Epoch 66674: early stopping
#
# Best model at step 64673:
#   train loss: 7.45e-09
#   test loss: 5.87e-09
#   test metric: []
#
# 'train' took 17.752528 s
#
# Compiling model...
# 'compile' took 0.163814 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 66674     [4.45e-08, 6.79e-07, 6.42e-06]    [4.22e-08, 6.79e-07, 6.42e-06]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 124
#   Number of functions evaluations: 155
# 66829     [5.31e-09, 3.04e-11, 8.15e-11]    [5.12e-09, 3.04e-11, 8.15e-11]    []
#
# Best model at step 66829:
#   train loss: 5.43e-09
#   test loss: 5.23e-09
#   test metric: []
#
# 'train' took 2.479445 s
#
# Mean residual: 5.737e-05
# Adding new point: [1.2664033  0.13001426]
#
# Compiling model...
# 'compile' took 0.213721 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 66829     [5.86e-09, 3.04e-11, 8.15e-11]    [5.12e-09, 3.04e-11, 8.15e-11]    []
# 67000     [1.41e-08, 2.24e-10, 2.44e-09]    [1.30e-08, 2.24e-10, 2.44e-09]    []
# 68000     [4.55e-09, 4.81e-11, 1.01e-10]    [4.46e-09, 4.81e-11, 1.01e-10]    []
# Epoch 68830: early stopping
#
# Best model at step 68000:
#   train loss: 4.70e-09
#   test loss: 4.61e-09
#   test metric: []
#
# 'train' took 18.828898 s
#
# Compiling model...
# 'compile' took 0.169894 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 68830     [4.80e-09, 5.67e-10, 3.91e-09]    [4.65e-09, 5.67e-10, 3.91e-09]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 14
#   Number of functions evaluations: 78
# 68908     [4.77e-09, 4.27e-11, 1.54e-10]    [4.63e-09, 4.27e-11, 1.54e-10]    []
#
# Best model at step 68000:
#   train loss: 4.70e-09
#   test loss: 4.61e-09
#   test metric: []
#
# 'train' took 1.751777 s
#
# Mean residual: 5.481e-05
# Adding new point: [1.7704824 5.76218  ]
#
# Compiling model...
# 'compile' took 0.283377 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 68908     [5.40e-09, 4.27e-11, 1.54e-10]    [4.63e-09, 4.27e-11, 1.54e-10]    []
# 69000     [1.98e-08, 5.55e-10, 2.35e-08]    [1.88e-08, 5.55e-10, 2.35e-08]    []
# 70000     [6.14e-09, 1.16e-07, 2.95e-07]    [5.95e-09, 1.16e-07, 2.95e-07]    []
# Epoch 70909: early stopping
#
# Best model at step 68908:
#   train loss: 5.59e-09
#   test loss: 4.83e-09
#   test metric: []
#
# 'train' took 17.828308 s
#
# Compiling model...
# 'compile' took 0.162440 s
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 70909     [5.39e-09, 8.55e-07, 9.41e-07]    [5.27e-09, 8.55e-07, 9.41e-07]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 35
#   Number of functions evaluations: 64
# 70973     [4.44e-09, 1.13e-10, 1.99e-10]    [4.34e-09, 1.13e-10, 1.99e-10]    []
#
# Best model at step 70973:
#   train loss: 4.75e-09
#   test loss: 4.65e-09
#   test metric: []
#
# 'train' took 1.739752 s
#
# Mean residual: 5.279e-05
# Adding new point: [  0.7265577 196.37077  ]
#
# Compiling model...
# 'compile' took 0.232528 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 70973     [4.93e-09, 1.13e-10, 1.99e-10]    [4.34e-09, 1.13e-10, 1.99e-10]    []
# 71000     [2.91e-07, 9.43e-07, 1.09e-07]    [2.57e-07, 9.43e-07, 1.09e-07]    []
# 72000     [9.31e-08, 5.25e-09, 1.76e-05]    [9.04e-08, 5.25e-09, 1.76e-05]    []
# Epoch 72974: early stopping
#
# Best model at step 70973:
#   train loss: 5.24e-09
#   test loss: 4.65e-09
#   test metric: []
#
# 'train' took 17.850754 s
#
# Compiling model...
# 'compile' took 0.189946 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 72974     [3.97e-09, 7.40e-11, 2.24e-09]    [3.72e-09, 7.40e-11, 2.24e-09]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 5
#   Number of functions evaluations: 24
# 72998     [3.96e-09, 2.21e-11, 1.48e-10]    [3.71e-09, 2.21e-11, 1.48e-10]    []
#
# Best model at step 72998:
#   train loss: 4.13e-09
#   test loss: 3.88e-09
#   test metric: []
#
# 'train' took 1.415156 s
#
# Mean residual: 4.951e-05
# Adding new point: [39.2466      0.28233343]
#
# Compiling model...
# 'compile' took 0.268775 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 72998     [4.21e-09, 2.21e-11, 1.48e-10]    [3.71e-09, 2.21e-11, 1.48e-10]    []
# 73000     [3.08e-06, 7.43e-07, 1.78e-05]    [2.90e-06, 7.43e-07, 1.78e-05]    []
# 74000     [6.66e-09, 3.88e-11, 2.90e-10]    [6.26e-09, 3.88e-11, 2.90e-10]    []
# Epoch 74999: early stopping
#
# Best model at step 72998:
#   train loss: 4.38e-09
#   test loss: 3.88e-09
#   test metric: []
#
# 'train' took 18.699148 s
#
# Compiling model...
# 'compile' took 0.195726 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 74999     [6.10e-09, 4.10e-08, 5.14e-08]    [5.61e-09, 4.10e-08, 5.14e-08]    []
# 75000     [6.10e-09, 4.10e-08, 5.14e-08]    [6.10e-09, 4.10e-08, 5.14e-08]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 40
#   Number of functions evaluations: 59
# 75058     [5.24e-09, 2.57e-11, 1.86e-10]    [4.79e-09, 2.57e-11, 1.86e-10]    []
#
# Best model at step 72998:
#   train loss: 4.38e-09
#   test loss: 3.88e-09
#   test metric: []
#
# 'train' took 1.890910 s
#
# Mean residual: 5.438e-05
# Adding new point: [4.4105005 5.3013906]
#
# Compiling model...
# 'compile' took 0.385175 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 75058     [5.83e-09, 2.57e-11, 1.86e-10]    [4.79e-09, 2.57e-11, 1.86e-10]    []
# 76000     [6.76e-09, 1.64e-07, 2.44e-08]    [6.07e-09, 1.64e-07, 2.44e-08]    []
# 77000     [4.65e-09, 2.98e-07, 3.82e-07]    [4.38e-09, 2.98e-07, 3.82e-07]    []
# Epoch 77059: early stopping
#
# Best model at step 75058:
#   train loss: 6.05e-09
#   test loss: 5.00e-09
#   test metric: []
#
# 'train' took 18.515913 s
#
# Compiling model...
# 'compile' took 0.184738 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 77059     [4.15e-09, 5.35e-08, 7.09e-08]    [3.88e-09, 5.35e-08, 7.09e-08]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 26
#   Number of functions evaluations: 56
# 77115     [4.05e-09, 2.17e-11, 1.47e-10]    [3.78e-09, 2.17e-11, 1.47e-10]    []
#
# Best model at step 77115:
#   train loss: 4.22e-09
#   test loss: 3.95e-09
#   test metric: []
#
# 'train' took 1.837921 s
#
# Mean residual: 4.814e-05
# Adding new point: [4.0338326 7.404857 ]
#
# Compiling model...
# 'compile' took 0.266115 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 77115     [4.47e-09, 2.17e-11, 1.47e-10]    [3.78e-09, 2.17e-11, 1.47e-10]    []
# 78000     [4.01e-09, 2.97e-11, 1.61e-10]    [3.66e-09, 2.97e-11, 1.61e-10]    []
# 79000     [4.17e-09, 2.76e-08, 2.68e-08]    [3.98e-09, 2.76e-08, 2.68e-08]    []
# Epoch 79116: early stopping
#
# Best model at step 78000:
#   train loss: 4.20e-09
#   test loss: 3.85e-09
#   test metric: []
#
# 'train' took 19.229901 s
#
# Compiling model...
# 'compile' took 0.210402 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 79116     [3.73e-09, 2.64e-09, 2.91e-10]    [3.52e-09, 2.64e-09, 2.91e-10]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 16
#   Number of functions evaluations: 38
# 79154     [3.66e-09, 2.95e-11, 1.93e-10]    [3.45e-09, 2.95e-11, 1.93e-10]    []
#
# Best model at step 79154:
#   train loss: 3.88e-09
#   test loss: 3.67e-09
#   test metric: []
#
# 'train' took 1.986470 s
#
# Mean residual: 4.551e-05
# Adding new point: [  0.5675379 198.35747  ]
#
# Compiling model...
# 'compile' took 0.349014 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 79154     [3.86e-09, 2.95e-11, 1.93e-10]    [3.45e-09, 2.95e-11, 1.93e-10]    []
# 80000     [3.68e-09, 2.08e-11, 2.10e-10]    [3.43e-09, 2.08e-11, 2.10e-10]    []
# 81000     [3.68e-09, 2.47e-10, 4.55e-09]    [3.28e-09, 2.47e-10, 4.55e-09]    []
# Epoch 81155: early stopping
#
# Best model at step 80000:
#   train loss: 3.91e-09
#   test loss: 3.66e-09
#   test metric: []
#
# 'train' took 19.462654 s
#
# Compiling model...
# 'compile' took 0.232262 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 81155     [5.86e-09, 6.08e-08, 1.67e-07]    [5.51e-09, 6.08e-08, 1.67e-07]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 44
#   Number of functions evaluations: 70
# 81225     [3.29e-09, 3.32e-11, 1.56e-10]    [3.06e-09, 3.32e-11, 1.56e-10]    []
#
# Best model at step 81225:
#   train loss: 3.48e-09
#   test loss: 3.25e-09
#   test metric: []
#
# 'train' took 2.427996 s
#
# Mean residual: 4.228e-05
# Adding new point: [16.933603   0.2149589]
#
# Compiling model...
# 'compile' took 0.318781 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 81225     [3.46e-09, 3.32e-11, 1.56e-10]    [3.06e-09, 3.32e-11, 1.56e-10]    []
# 82000     [3.17e-09, 5.74e-11, 1.20e-10]    [2.92e-09, 5.74e-11, 1.20e-10]    []
# 83000     [1.15e-08, 1.07e-07, 1.94e-09]    [1.09e-08, 1.07e-07, 1.94e-09]    []
# Epoch 83226: early stopping
#
# Best model at step 82000:
#   train loss: 3.35e-09
#   test loss: 3.10e-09
#   test metric: []
#
# 'train' took 19.090854 s
#
# Compiling model...
# 'compile' took 0.239544 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 83226     [6.51e-08, 3.92e-07, 2.63e-08]    [6.31e-08, 3.92e-07, 2.63e-08]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 113
#   Number of functions evaluations: 143
# 83369     [3.74e-09, 3.85e-11, 1.29e-10]    [3.38e-09, 3.85e-11, 1.29e-10]    []
#
# Best model at step 82000:
#   train loss: 3.35e-09
#   test loss: 3.10e-09
#   test metric: []
#
# 'train' took 3.494079 s
# Mean residual: 4.509e-05
# Adding new point: [12.829659   0.1485487]
#
# Compiling model...
# 'compile' took 0.339242 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 83369     [3.88e-09, 3.85e-11, 1.29e-10]    [3.38e-09, 3.85e-11, 1.29e-10]    []
# 84000     [3.46e-09, 6.14e-11, 8.27e-11]    [3.22e-09, 6.14e-11, 8.27e-11]    []
# 85000     [2.69e-08, 1.13e-07, 5.73e-06]    [2.52e-08, 1.13e-07, 5.73e-06]    []
# Epoch 85370: early stopping
#
# Best model at step 84000:
#   train loss: 3.60e-09
#   test loss: 3.36e-09
#   test metric: []
#
# 'train' took 19.928033 s
#
# Compiling model...
# 'compile' took 0.233571 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 85370     [3.37e-09, 1.29e-08, 1.49e-08]    [2.89e-09, 1.29e-08, 1.49e-08]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 32
#   Number of functions evaluations: 63
# 85433     [3.14e-09, 2.56e-11, 1.30e-10]    [2.67e-09, 2.56e-11, 1.30e-10]    []
#
# Best model at step 85433:
#   train loss: 3.29e-09
#   test loss: 2.82e-09
#   test metric: []
#
# 'train' took 2.526764 s
#
# Mean residual: 3.911e-05
# Adding new point: [  0.5675379 198.35747  ]
#
# Compiling model...
# 'compile' took 0.303576 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 85433     [3.29e-09, 2.56e-11, 1.30e-10]    [2.67e-09, 2.56e-11, 1.30e-10]    []
# 86000     [4.32e-09, 2.51e-11, 1.06e-10]    [3.23e-09, 2.51e-11, 1.06e-10]    []
# 87000     [3.24e-09, 2.97e-10, 1.77e-10]    [2.57e-09, 2.97e-10, 1.77e-10]    []
# Epoch 87434: early stopping
#
# Best model at step 85433:
#   train loss: 3.44e-09
#   test loss: 2.82e-09
#   test metric: []
#
# 'train' took 19.232901 s
#
# Compiling model...
# 'compile' took 0.200501 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 87434     [3.55e-09, 4.56e-09, 2.45e-09]    [2.98e-09, 4.56e-09, 2.45e-09]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 30
#   Number of functions evaluations: 45
# 87479     [3.33e-09, 1.44e-11, 1.08e-10]    [2.78e-09, 1.44e-11, 1.08e-10]    []
#
# Best model at step 85433:
#   train loss: 3.44e-09
#   test loss: 2.82e-09
#   test metric: []
#
# 'train' took 2.424218 s
#
# Mean residual: 4.032e-05
# Adding new point: [  0.5675379 198.35747  ]
#
# Compiling model...
# 'compile' took 0.435652 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 87479     [3.46e-09, 1.44e-11, 1.08e-10]    [2.78e-09, 1.44e-11, 1.08e-10]    []
# 88000     [4.33e-09, 3.72e-11, 1.41e-10]    [3.22e-09, 3.72e-11, 1.41e-10]    []
# 89000     [2.73e-08, 3.75e-07, 2.27e-06]    [2.68e-08, 3.75e-07, 2.27e-06]    []
# Epoch 89480: early stopping
#
# Best model at step 87479:
#   train loss: 3.58e-09
#   test loss: 2.91e-09
#   test metric: []
#
# 'train' took 20.133349 s
#
# Compiling model...
# 'compile' took 0.247685 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 89480     [1.47e-07, 4.43e-08, 1.33e-05]    [1.44e-07, 4.43e-08, 1.33e-05]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 76
#   Number of functions evaluations: 111
# 89591     [2.86e-09, 7.69e-11, 9.87e-11]    [2.62e-09, 7.69e-11, 9.87e-11]    []
#
# Best model at step 89591:
#   train loss: 3.03e-09
#   test loss: 2.79e-09
#   test metric: []
#
# 'train' took 3.432538 s
#
# Mean residual: 3.787e-05
# Adding new point: [ 1.2023766 12.367429 ]
#
# Compiling model...
# 'compile' took 0.274291 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 89591     [2.95e-09, 7.69e-11, 9.87e-11]    [2.62e-09, 7.69e-11, 9.87e-11]    []
# 90000     [4.77e-09, 1.69e-11, 1.47e-10]    [3.72e-09, 1.69e-11, 1.47e-10]    []
# 91000     [2.42e-09, 4.08e-11, 9.80e-11]    [2.14e-09, 4.08e-11, 9.80e-11]    []
# Epoch 91592: early stopping
#
# Best model at step 91000:
#   train loss: 2.56e-09
#   test loss: 2.28e-09
#   test metric: []
#
# 'train' took 18.590817 s
#
# Compiling model...
# 'compile' took 0.227228 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 91592     [2.39e-09, 7.47e-11, 3.55e-10]    [2.15e-09, 7.47e-11, 3.55e-10]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 14
#   Number of functions evaluations: 85
# 91677     [2.38e-09, 3.62e-11, 8.88e-11]    [2.15e-09, 3.62e-11, 8.88e-11]    []
#
# Best model at step 91677:
#   train loss: 2.51e-09
#   test loss: 2.27e-09
#   test metric: []
#
# 'train' took 2.967738 s
#
# Mean residual: 3.538e-05
# Adding new point: [1.935596  1.4824789]
#
# Compiling model...
# 'compile' took 0.390476 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 91677     [2.47e-09, 3.62e-11, 8.88e-11]    [2.15e-09, 3.62e-11, 8.88e-11]    []
# 92000     [3.89e-09, 1.81e-11, 3.67e-10]    [3.48e-09, 1.81e-11, 3.67e-10]    []
# 93000     [2.89e-09, 2.34e-09, 1.17e-08]    [2.57e-09, 2.34e-09, 1.17e-08]    []
# Epoch 93678: early stopping
#
# Best model at step 91677:
#   train loss: 2.60e-09
#   test loss: 2.27e-09
#   test metric: []
#
# 'train' took 20.147643 s
#
# Compiling model...
# 'compile' took 0.221815 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 93678     [2.79e-09, 1.70e-08, 6.79e-08]    [2.53e-09, 1.70e-08, 6.79e-08]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 33
#   Number of functions evaluations: 54
# 93732     [2.63e-09, 2.17e-11, 9.90e-11]    [2.37e-09, 2.17e-11, 9.90e-11]    []
#
# Best model at step 91677:
#   train loss: 2.60e-09
#   test loss: 2.27e-09
#   test metric: []
#
# 'train' took 2.993194 s
#
# Mean residual: 3.488e-05
# Adding new point: [58.895756    0.09511776]
#
# Compiling model...
# 'compile' took 0.289089 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 93732     [2.71e-09, 2.17e-11, 9.90e-11]    [2.37e-09, 2.17e-11, 9.90e-11]    []
# 94000     [5.31e-09, 2.53e-10, 1.63e-10]    [4.03e-09, 2.53e-10, 1.63e-10]    []
# 95000     [2.93e-09, 5.59e-08, 7.21e-09]    [2.53e-09, 5.59e-08, 7.21e-09]    []
# Epoch 95733: early stopping
#
# Best model at step 93732:
#   train loss: 2.83e-09
#   test loss: 2.49e-09
#   test metric: []
#
# 'train' took 19.050118 s
#
# Compiling model...
# 'compile' took 0.236821 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 95733     [2.27e-09, 5.07e-11, 2.04e-09]    [2.00e-09, 5.07e-11, 2.04e-09]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 16
#   Number of functions evaluations: 58
# 95791     [2.26e-09, 4.09e-11, 7.48e-11]    [1.99e-09, 4.09e-11, 7.48e-11]    []
#
# Best model at step 95791:
#   train loss: 2.38e-09
#   test loss: 2.11e-09
#   test metric: []
#
# 'train' took 3.399181 s
#
# Mean residual: 3.238e-05
# Adding new point: [12.829659   0.1485487]
#
# Compiling model...
# 'compile' took 0.278609 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 95791     [2.35e-09, 4.09e-11, 7.48e-11]    [1.99e-09, 4.09e-11, 7.48e-11]    []
# 96000     [3.93e-09, 3.28e-11, 1.16e-10]    [2.87e-09, 3.28e-11, 1.16e-10]    []
# 97000     [3.03e-09, 6.62e-11, 1.25e-09]    [2.70e-09, 6.62e-11, 1.25e-09]    []
# Epoch 97792: early stopping
#
# Best model at step 95791:
#   train loss: 2.46e-09
#   test loss: 2.11e-09
#   test metric: []
#
# 'train' took 19.438961 s
# Compiling model...
# 'compile' took 0.224731 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 97792     [1.06e-07, 5.86e-09, 9.79e-07]    [1.06e-07, 5.86e-09, 9.79e-07]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 118
#   Number of functions evaluations: 149
# 97941     [2.47e-09, 5.15e-11, 5.91e-11]    [2.19e-09, 5.15e-11, 5.91e-11]    []
#
# Best model at step 95791:
#   train loss: 2.46e-09
#   test loss: 2.11e-09
#   test metric: []
#
# 'train' took 4.039521 s
#
# Mean residual: 3.550e-05
# Adding new point: [12.846072   0.4387709]
#
# Compiling model...
# 'compile' took 0.277333 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 97941     [2.54e-09, 5.15e-11, 5.91e-11]    [2.19e-09, 5.15e-11, 5.91e-11]    []
# 98000     [4.58e-08, 4.86e-07, 1.47e-07]    [4.20e-08, 4.86e-07, 1.47e-07]    []
# 99000     [3.46e-09, 1.56e-09, 7.15e-11]    [2.33e-09, 1.56e-09, 7.15e-11]    []
# Epoch 99942: early stopping
#
# Best model at step 97941:
#   train loss: 2.66e-09
#   test loss: 2.30e-09
#   test metric: []
#
# 'train' took 18.573183 s
#
# Compiling model...
# 'compile' took 0.223904 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 99942     [2.03e-09, 3.87e-11, 5.82e-11]    [1.74e-09, 3.87e-11, 5.82e-11]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 4
#   Number of functions evaluations: 27
# 99969     [2.03e-09, 2.93e-11, 5.18e-11]    [1.74e-09, 2.93e-11, 5.18e-11]    []
#
# Best model at step 99969:
#   train loss: 2.11e-09
#   test loss: 1.82e-09
#   test metric: []
#
# 'train' took 2.907360 s
#
# Mean residual: 3.066e-05
# Adding new point: [12.829659   0.1485487]
#
# Compiling model...
# 'compile' took 0.282926 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 99969     [2.08e-09, 2.93e-11, 5.18e-11]    [1.74e-09, 2.93e-11, 5.18e-11]    []
# 100000    [2.77e-07, 2.03e-05, 6.64e-07]    [2.66e-07, 2.03e-05, 6.64e-07]    []
# 101000    [1.97e-09, 2.81e-11, 4.01e-11]    [1.66e-09, 2.81e-11, 4.01e-11]    []
# Epoch 101970: early stopping
#
# Best model at step 101000:
#   train loss: 2.04e-09
#   test loss: 1.72e-09
#   test metric: []
#
# 'train' took 19.220522 s
#
# Compiling model...
# 'compile' took 0.228443 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 101970    [1.77e-09, 1.12e-10, 3.08e-10]    [1.53e-09, 1.12e-10, 3.08e-10]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 3
#   Number of functions evaluations: 19
# 101989    [1.77e-09, 3.32e-11, 5.52e-11]    [1.53e-09, 3.32e-11, 5.52e-11]    []
#
# Best model at step 101989:
#   train loss: 1.86e-09
#   test loss: 1.62e-09
#   test metric: []
#
# 'train' took 2.947586 s
#
# Mean residual: 2.858e-05
# Adding new point: [15.742713   0.9812456]
#
# Compiling model...
# 'compile' took 0.283161 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 101989    [1.82e-09, 3.32e-11, 5.52e-11]    [1.53e-09, 3.32e-11, 5.52e-11]    []
# 102000    [1.21e-06, 3.30e-06, 2.23e-05]    [1.16e-06, 3.30e-06, 2.23e-05]    []
# 103000    [2.29e-09, 2.06e-08, 1.63e-08]    [2.05e-09, 2.06e-08, 1.63e-08]    []
# Epoch 103990: early stopping
#
# Best model at step 101989:
#   train loss: 1.91e-09
#   test loss: 1.62e-09
#   test metric: []
#
# 'train' took 18.663768 s
#
# Compiling model...
# 'compile' took 0.242655 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 103990    [8.88e-09, 3.48e-07, 9.33e-07]    [8.20e-09, 3.48e-07, 9.33e-07]    []
# 104000    [7.99e-09, 9.98e-11, 5.86e-10]    [7.99e-09, 9.98e-11, 5.86e-10]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 109
#   Number of functions evaluations: 140
# 104130    [2.10e-09, 2.16e-11, 6.84e-11]    [1.81e-09, 2.16e-11, 6.84e-11]    []
#
# Best model at step 101989:
#   train loss: 1.91e-09
#   test loss: 1.62e-09
#   test metric: []
#
# 'train' took 4.248013 s
#
# Mean residual: 2.904e-05
# Adding new point: [58.895756    0.09511776]
#
# Compiling model...
# 'compile' took 0.283159 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 104130    [2.17e-09, 2.16e-11, 6.84e-11]    [1.81e-09, 2.16e-11, 6.84e-11]    []
# 105000    [2.19e-09, 1.68e-11, 5.27e-11]    [1.75e-09, 1.68e-11, 5.27e-11]    []
# 106000    [1.87e-09, 7.48e-09, 1.02e-10]    [1.58e-09, 7.48e-09, 1.02e-10]    []
# Epoch 106131: early stopping
#
# Best model at step 105000:
#   train loss: 2.26e-09
#   test loss: 1.82e-09
#   test metric: []
#
# 'train' took 18.880124 s
#
# Compiling model...
# 'compile' took 0.234447 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 106131    [1.95e-09, 3.53e-08, 1.78e-07]    [1.67e-09, 3.53e-08, 1.78e-07]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 34
#   Number of functions evaluations: 53
# 106184    [1.65e-09, 2.62e-11, 4.63e-11]    [1.38e-09, 2.62e-11, 4.63e-11]    []
#
# Best model at step 106184:
#   train loss: 1.72e-09
#   test loss: 1.45e-09
#   test metric: []
#
# 'train' took 3.504189 s
#
# Mean residual: 2.668e-05
# Adding new point: [ 0.36930937 87.92968   ]
#
# Compiling model...
# 'compile' took 0.296830 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 106184    [1.69e-09, 2.62e-11, 4.63e-11]    [1.38e-09, 2.62e-11, 4.63e-11]    []
# 107000    [1.93e-09, 2.56e-11, 5.36e-11]    [1.63e-09, 2.56e-11, 5.36e-11]    []
# 108000    [1.61e-09, 6.40e-10, 7.97e-10]    [1.35e-09, 6.40e-10, 7.97e-10]    []
# Epoch 108185: early stopping
#
# Best model at step 106184:
#   train loss: 1.77e-09
#   test loss: 1.45e-09
#   test metric: []
#
# 'train' took 19.229043 s
#
# Compiling model...
# 'compile' took 0.234252 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 108185    [1.56e-09, 7.18e-11, 3.95e-10]    [1.30e-09, 7.18e-11, 3.95e-10]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 7
#   Number of functions evaluations: 62
# 108247    [1.56e-09, 2.34e-11, 4.02e-11]    [1.30e-09, 2.34e-11, 4.02e-11]    []
#
# Best model at step 108247:
#   train loss: 1.63e-09
#   test loss: 1.36e-09
#   test metric: []
#
# 'train' took 3.805814 s
#
# Mean residual: 2.579e-05
# Adding new point: [ 0.36930937 87.92968   ]
#
# Compiling model...
# 'compile' took 0.299882 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 108247    [1.60e-09, 2.34e-11, 4.02e-11]    [1.30e-09, 2.34e-11, 4.02e-11]    []
# 109000    [2.20e-09, 9.94e-10, 1.14e-07]    [1.87e-09, 9.94e-10, 1.14e-07]    []
# 110000    [2.02e-08, 8.62e-08, 1.12e-06]    [1.93e-08, 8.62e-08, 1.12e-06]    []
# Epoch 110248: early stopping
#
# Best model at step 108247:
#   train loss: 1.67e-09
#   test loss: 1.36e-09
#   test metric: []
#
# 'train' took 19.284856 s
#
# Compiling model...
# 'compile' took 0.238426 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 110248    [1.58e-07, 3.58e-08, 2.46e-08]    [1.57e-07, 3.58e-08, 2.46e-08]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 106
#   Number of functions evaluations: 140
# 110388    [1.72e-09, 3.20e-11, 4.41e-11]    [1.45e-09, 3.20e-11, 4.41e-11]    []
# Best model at step 108247:
#   train loss: 1.67e-09
#   test loss: 1.36e-09
#   test metric: []
#
# 'train' took 4.737695 s
#
# Mean residual: 2.610e-05
# Adding new point: [1.8057843e+02 1.2874027e-01]
#
# Compiling model...
# 'compile' took 0.305466 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 110388    [1.78e-09, 3.20e-11, 4.41e-11]    [1.45e-09, 3.20e-11, 4.41e-11]    []
# 111000    [1.60e-09, 3.03e-11, 2.85e-11]    [1.32e-09, 3.03e-11, 2.85e-11]    []
# 112000    [2.66e-09, 6.25e-07, 5.83e-07]    [2.27e-09, 6.25e-07, 5.83e-07]    []
# Epoch 112389: early stopping
#
# Best model at step 111000:
#   train loss: 1.66e-09
#   test loss: 1.37e-09
#   test metric: []
#
# 'train' took 19.355956 s
#
# Compiling model...
# 'compile' took 0.247358 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 112389    [1.64e-09, 5.45e-10, 1.05e-10]    [1.36e-09, 5.45e-10, 1.05e-10]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 24
#   Number of functions evaluations: 56
# 112445    [1.52e-09, 3.05e-11, 3.11e-11]    [1.24e-09, 3.05e-11, 3.11e-11]    []
#
# Best model at step 112445:
#   train loss: 1.58e-09
#   test loss: 1.30e-09
#   test metric: []
#
# 'train' took 3.958544 s
#
# Mean residual: 2.492e-05
# Adding new point: [184.0176       0.28538764]
#
# Compiling model...
# 'compile' took 0.316317 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 112445    [1.57e-09, 3.05e-11, 3.11e-11]    [1.24e-09, 3.05e-11, 3.11e-11]    []
# 113000    [2.88e-09, 5.88e-11, 5.11e-11]    [1.65e-09, 5.88e-11, 5.11e-11]    []
# 114000    [4.97e-08, 5.18e-08, 1.00e-05]    [4.81e-08, 5.18e-08, 1.00e-05]    []
# Epoch 114446: early stopping
#
# Best model at step 112445:
#   train loss: 1.63e-09
#   test loss: 1.30e-09
#   test metric: []
#
# 'train' took 19.577002 s
#
# Compiling model...
# 'compile' took 0.246830 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 114446    [1.32e-09, 4.76e-11, 6.92e-10]    [1.05e-09, 4.76e-11, 6.92e-10]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 10
#   Number of functions evaluations: 34
# 114480    [1.32e-09, 2.34e-11, 2.62e-11]    [1.05e-09, 2.34e-11, 2.62e-11]    []
#
# Best model at step 114480:
#   train loss: 1.36e-09
#   test loss: 1.10e-09
#   test metric: []
#
# 'train' took 3.838467 s
#
# Mean residual: 2.299e-05
# Adding new point: [ 1.7006347 13.112378 ]
#
# Compiling model...
# 'compile' took 0.311494 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 114480    [1.35e-09, 2.34e-11, 2.62e-11]    [1.05e-09, 2.34e-11, 2.62e-11]    []
# 115000    [2.67e-09, 7.53e-12, 2.71e-11]    [1.50e-09, 7.53e-12, 2.71e-11]    []
# 116000    [1.26e-09, 3.61e-11, 2.06e-11]    [1.03e-09, 3.61e-11, 2.06e-11]    []
# Epoch 116481: early stopping
#
# Best model at step 116000:
#   train loss: 1.32e-09
#   test loss: 1.08e-09
#   test metric: []
#
# 'train' took 19.505343 s
#
# Compiling model...
# 'compile' took 0.254551 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 116481    [1.53e-09, 2.08e-08, 1.00e-08]    [1.23e-09, 2.08e-08, 1.00e-08]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 38
#   Number of functions evaluations: 57
# 116538    [1.47e-09, 1.60e-11, 2.29e-11]    [1.18e-09, 1.60e-11, 2.29e-11]    []
#
# Best model at step 116000:
#   train loss: 1.32e-09
#   test loss: 1.08e-09
#   test metric: []
#
# 'train' took 4.241615 s
#
# Mean residual: 2.458e-05
# Adding new point: [ 0.36930937 87.92968   ]
#
# Compiling model...
# 'compile' took 0.307962 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 116538    [1.52e-09, 1.60e-11, 2.29e-11]    [1.18e-09, 1.60e-11, 2.29e-11]    []
# 117000    [2.96e-09, 1.48e-11, 4.19e-11]    [1.66e-09, 1.48e-11, 4.19e-11]    []
# 118000    [4.03e-09, 3.37e-08, 2.28e-10]    [3.74e-09, 3.37e-08, 2.28e-10]    []
# Epoch 118539: early stopping
#
# Best model at step 116538:
#   train loss: 1.55e-09
#   test loss: 1.22e-09
#   test metric: []
#
# 'train' took 19.474012 s
#
# Compiling model...
# 'compile' took 0.252902 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 118539    [7.14e-08, 4.14e-07, 1.65e-06]    [6.97e-08, 4.14e-07, 1.65e-06]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 99
#   Number of functions evaluations: 118
# 118657    [1.45e-09, 2.76e-11, 3.86e-11]    [1.13e-09, 2.76e-11, 3.86e-11]    []
#
# Best model at step 118657:
#   train loss: 1.52e-09
#   test loss: 1.19e-09
#   test metric: []
#
# 'train' took 5.089221 s
#
# Mean residual: 2.295e-05
# Adding new point: [ 0.3174977 80.71525  ]
#
# Compiling model...
# 'compile' took 0.311635 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 118657    [1.49e-09, 2.76e-11, 3.86e-11]    [1.13e-09, 2.76e-11, 3.86e-11]    []
# 119000    [3.04e-09, 4.96e-11, 2.98e-11]    [1.64e-09, 4.96e-11, 2.98e-11]    []
# 120000    [1.15e-09, 3.46e-11, 1.17e-11]    [8.96e-10, 3.46e-11, 1.17e-11]    []
# Epoch 120658: early stopping
#
# Best model at step 120000:
#   train loss: 1.20e-09
#   test loss: 9.42e-10
#   test metric: []
#
# 'train' took 21.568351 s
#
# Compiling model...
# 'compile' took 0.366128 s
#
# ...
#   Objective function value: 0.000000
#   Number of iterations: 52
#   Number of functions evaluations: 81
# 437051    [4.59e-10, 1.83e-12, 2.93e-12]    [1.72e-10, 1.83e-12, 2.93e-12]    []
#
# Best model at step 437051:
#   train loss: 4.63e-10
#   test loss: 1.77e-10
#   test metric: []
#
# 'train' took 118.278376 s
#
# Mean residual: 9.272e-06
# Adding new point: [  0.14623931 110.351135  ]
#
# Compiling model...
# 'compile' took 9.431837 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 437051    [4.67e-10, 1.83e-12, 2.93e-12]    [1.72e-10, 1.83e-12, 2.93e-12]    []
# 438000    [8.38e-10, 2.18e-08, 4.19e-09]    [3.60e-10, 2.18e-08, 4.19e-09]    []
# 439000    [1.62e-08, 1.78e-07, 7.91e-06]    [1.61e-08, 1.78e-07, 7.91e-06]    []
# Epoch 439052: early stopping
#
# Best model at step 437051:
#   train loss: 4.72e-10
#   test loss: 1.77e-10
#   test metric: []
#
# 'train' took 139.840993 s
#
# Compiling model...
# 'compile' took 3.977141 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 439052    [4.57e-10, 6.35e-10, 6.44e-09]    [1.62e-10, 6.35e-10, 6.44e-09]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 4
#   Number of functions evaluations: 34
# 439086    [4.49e-10, 5.37e-13, 5.48e-12]    [1.55e-10, 5.37e-13, 5.48e-12]    []
#
# Best model at step 439086:
#   train loss: 4.55e-10
#   test loss: 1.61e-10
#   test metric: []
#
# 'train' took 237.406780 s
#
# Mean residual: 9.089e-06
# Adding new point: [  0.14623931 110.351135  ]
#
# Compiling model...
# 'compile' took 10.986712 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 439086    [4.57e-10, 5.37e-13, 5.48e-12]    [1.55e-10, 5.37e-13, 5.48e-12]    []
# 440000    [1.68e-09, 7.83e-11, 4.68e-11]    [2.68e-10, 7.83e-11, 4.68e-11]    []
# 441000    [6.63e-10, 7.94e-08, 8.28e-11]    [3.30e-10, 7.94e-08, 8.28e-11]    []
# Epoch 441087: early stopping
#
# Best model at step 439086:
#   train loss: 4.63e-10
#   test loss: 1.61e-10
#   test metric: []
#
# 'train' took 124.711576 s
#
# Compiling model...
# 'compile' took 3.449557 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 441087    [3.23e-09, 7.62e-08, 3.38e-07]    [2.58e-09, 7.62e-08, 3.38e-07]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 46
#   Number of functions evaluations: 67
# 441154    [5.13e-10, 1.91e-12, 4.89e-12]    [1.82e-10, 1.91e-12, 4.89e-12]    []
#
# Best model at step 439086:
#   train loss: 4.63e-10
#   test loss: 1.61e-10
#   test metric: []
#
# 'train' took 114.632648 s
#
# Mean residual: 9.306e-06
# Adding new point: [  0.14623931 110.351135  ]
#
# Compiling model...
# 'compile' took 4.986742 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 441154    [5.22e-10, 1.91e-12, 4.89e-12]    [1.82e-10, 1.91e-12, 4.89e-12]    []
# 442000    [6.35e-10, 2.80e-11, 7.46e-12]    [2.03e-10, 2.80e-11, 7.46e-12]    []
# 443000    [4.79e-10, 3.53e-10, 1.78e-10]    [1.64e-10, 3.53e-10, 1.78e-10]    []
# Epoch 443155: early stopping
#
# Best model at step 441154:
#   train loss: 5.29e-10
#   test loss: 1.89e-10
#   test metric: []
#
# 'train' took 169.262033 s
#
# Compiling model...
# 'compile' took 10.912754 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 443155    [1.43e-09, 2.14e-06, 7.49e-07]    [1.09e-09, 2.14e-06, 7.49e-07]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 13
#   Number of functions evaluations: 38
# 443193    [5.15e-10, 6.36e-12, 9.18e-12]    [1.94e-10, 6.36e-12, 9.18e-12]    []
#
# Best model at step 441154:
#   train loss: 5.29e-10
#   test loss: 1.89e-10
#   test metric: []
#
# 'train' took 129.027121 s
#
# Mean residual: 1.009e-05
# Adding new point: [  0.14623931 110.351135  ]
#
# Compiling model...
# 'compile' took 5.969605 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 443193    [5.25e-10, 6.36e-12, 9.18e-12]    [1.94e-10, 6.36e-12, 9.18e-12]    []
# 444000    [6.54e-10, 1.68e-11, 1.19e-11]    [2.20e-10, 1.68e-11, 1.19e-11]    []
# 445000    [4.99e-10, 1.23e-08, 1.44e-08]    [1.88e-10, 1.23e-08, 1.44e-08]    []
# Epoch 445194: early stopping
#
# Best model at step 443193:
#   train loss: 5.40e-10
#   test loss: 2.10e-10
#   test metric: []
#
# 'train' took 145.583312 s
#
# Compiling model...
# 'compile' took 3.387531 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 445194    [7.84e-10, 9.77e-08, 1.31e-07]    [4.32e-10, 9.77e-08, 1.31e-07]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 25
#   Number of functions evaluations: 43
# 445237    [4.63e-10, 1.90e-13, 2.27e-12]    [1.65e-10, 1.90e-13, 2.27e-12]    []
#
# Best model at step 445237:
#   train loss: 4.65e-10
#   test loss: 1.67e-10
#   test metric: []
#
# 'train' took 123.409828 s
#
# Mean residual: 9.185e-06
# Adding new point: [  0.14623931 110.351135  ]
#
# Compiling model...
# 'compile' took 4.194147 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 445237    [4.71e-10, 1.90e-13, 2.27e-12]    [1.65e-10, 1.90e-13, 2.27e-12]    []
# 446000    [1.21e-09, 2.44e-12, 1.81e-12]    [2.43e-10, 2.44e-12, 1.81e-12]    []
# 447000    [2.34e-09, 7.61e-07, 1.42e-07]    [1.89e-09, 7.61e-07, 1.42e-07]    []
# Epoch 447238: early stopping
#
# Best model at step 445237:
#   train loss: 4.73e-10
#   test loss: 1.67e-10
#   test metric: []
#
# 'train' took 130.331592 s
#
# Compiling model...
# 'compile' took 6.948449 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 447238    [5.04e-10, 3.41e-08, 4.89e-08]    [1.88e-10, 3.41e-08, 4.89e-08]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 12
#   Number of functions evaluations: 27
# 447265    [4.79e-10, 7.73e-13, 5.51e-12]    [1.60e-10, 7.73e-13, 5.51e-12]    []
#
# Best model at step 445237:
#   train loss: 4.73e-10
#   test loss: 1.67e-10
#   test metric: []
#
# 'train' took 130.288517 s
#
# Mean residual: 9.210e-06
# Adding new point: [  0.14623931 110.351135  ]
#
# Compiling model...
# 'compile' took 8.162862 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 447265    [4.88e-10, 7.73e-13, 5.51e-12]    [1.60e-10, 7.73e-13, 5.51e-12]    []
# 448000    [5.06e-10, 1.91e-11, 1.31e-11]    [1.73e-10, 1.91e-11, 1.31e-11]    []
# 449000    [1.04e-09, 2.40e-09, 2.45e-08]    [7.15e-10, 2.40e-09, 2.45e-08]    []
# Epoch 449266: early stopping
#
# Best model at step 447265:
#   train loss: 4.94e-10
#   test loss: 1.66e-10
#   test metric: []
#
# 'train' took 150.949415 s
#
# Compiling model...
# 'compile' took 5.653218 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 449266    [2.85e-09, 2.67e-08, 4.27e-06]    [2.57e-09, 2.67e-08, 4.27e-06]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 28
#   Number of functions evaluations: 44
# 449310    [4.97e-10, 1.25e-12, 4.07e-12]    [1.98e-10, 1.25e-12, 4.07e-12]    []
#
# Best model at step 447265:
#   train loss: 4.94e-10
#   test loss: 1.66e-10
#   test metric: []
#
# 'train' took 133.797049 s
#
# Mean residual: 9.977e-06
# Adding new point: [9.6753326e+01 3.4723792e-03]
#
# Compiling model...
# 'compile' took 9.909168 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 449310    [5.05e-10, 1.25e-12, 4.07e-12]    [1.98e-10, 1.25e-12, 4.07e-12]    []
# 450000    [2.23e-09, 4.37e-11, 8.82e-11]    [4.81e-10, 4.37e-11, 8.82e-11]    []
# 451000    [5.37e-10, 8.81e-11, 3.76e-11]    [1.90e-10, 8.81e-11, 3.76e-11]    []
# Epoch 451311: early stopping
#
# Best model at step 449310:
#   train loss: 5.10e-10
#   test loss: 2.03e-10
#   test metric: []
#
# 'train' took 153.971651 s
#
# Compiling model...
# 'compile' took 8.617521 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 451311    [5.07e-10, 2.12e-10, 1.22e-09]    [1.83e-10, 2.12e-10, 1.22e-09]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 3
#   Number of functions evaluations: 21
# 451332    [5.05e-10, 6.33e-13, 7.81e-12]    [1.81e-10, 6.33e-13, 7.81e-12]    []
#
# Best model at step 449310:
#   train loss: 5.10e-10
#   test loss: 2.03e-10
#   test metric: []
#
# 'train' took 142.339759 s
#
# Mean residual: 9.062e-06
# Adding new point: [  0.14623931 110.351135  ]
#
# Compiling model...
# 'compile' took 6.221753 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 451332    [5.14e-10, 6.33e-13, 7.81e-12]    [1.81e-10, 6.33e-13, 7.81e-12]    []
# 452000    [2.14e-09, 1.15e-11, 6.64e-11]    [1.02e-09, 1.15e-11, 6.64e-11]    []
# 453000    [4.17e-09, 1.20e-07, 1.13e-06]    [3.66e-09, 1.20e-07, 1.13e-06]    []
# Epoch 453333: early stopping
#
# Best model at step 451332:
#   train loss: 5.22e-10
#   test loss: 1.90e-10
#   test metric: []
#
# 'train' took 163.117383 s
#
# Compiling model...
# 'compile' took 9.442743 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 453333    [8.14e-10, 5.16e-11, 5.98e-11]    [3.57e-10, 5.16e-11, 5.98e-11]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 4
#   Number of functions evaluations: 28
# 453361    [8.15e-10, 8.84e-13, 1.32e-11]    [3.57e-10, 8.84e-13, 1.32e-11]    []
#
# Best model at step 451332:
#   train loss: 5.22e-10
#   test loss: 1.90e-10
#   test metric: []
#
# 'train' took 149.816718 s
#
# Mean residual: 1.254e-05
# Adding new point: [9.6753326e+01 3.4723792e-03]
#
# Compiling model...
# 'compile' took 4.411730 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 453361    [8.29e-10, 8.84e-13, 1.32e-11]    [3.57e-10, 8.84e-13, 1.32e-11]    []
# 454000    [7.34e-10, 1.35e-10, 8.90e-11]    [3.71e-10, 1.35e-10, 8.90e-11]    []
# 455000    [6.55e-10, 8.52e-09, 4.12e-08]    [2.72e-10, 8.52e-09, 4.12e-08]    []
# Epoch 455362: early stopping
#
# Best model at step 453361:
#   train loss: 8.43e-10
#   test loss: 3.71e-10
#   test metric: []
#
# 'train' took 142.569882 s
#
# Compiling model...
# 'compile' took 5.075494 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 455362    [6.72e-10, 2.05e-08, 1.75e-08]    [3.21e-10, 2.05e-08, 1.75e-08]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 12
#   Number of functions evaluations: 27
# 455389    [5.95e-10, 7.08e-13, 2.49e-12]    [2.33e-10, 7.08e-13, 2.49e-12]    []
#
# Best model at step 455389:
#   train loss: 5.98e-10
#   test loss: 2.36e-10
#   test metric: []
#
# 'train' took 140.731983 s
#
# Mean residual: 1.102e-05
# Adding new point: [  0.14623931 110.351135  ]
#
# Compiling model...
# 'compile' took 10.544297 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 455389    [6.04e-10, 7.08e-13, 2.49e-12]    [2.33e-10, 7.08e-13, 2.49e-12]    []
# 456000    [6.60e-10, 5.65e-12, 2.88e-11]    [3.15e-10, 5.65e-12, 2.88e-11]    []
# 457000    [5.51e-10, 4.33e-11, 4.94e-10]    [2.30e-10, 4.33e-11, 4.94e-10]    []
# Epoch 457390: early stopping
#
# Best model at step 455389:
#   train loss: 6.07e-10
#   test loss: 2.36e-10
#   test metric: []
#
# 'train' took 166.978633 s
#
# Compiling model...
# 'compile' took 10.327811 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 457390    [5.77e-10, 7.52e-10, 4.16e-09]    [2.62e-10, 7.52e-10, 4.16e-09]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 13
#   Number of functions evaluations: 40
# 457430    [5.36e-10, 2.57e-12, 4.45e-12]    [2.13e-10, 2.57e-12, 4.45e-12]    []
#
# Best model at step 457430:
#   train loss: 5.43e-10
#   test loss: 2.20e-10
#   test metric: []
#
# 'train' took 139.270614 s
#
# Mean residual: 1.147e-05
# Adding new point: [  0.14623931 110.351135  ]
#
# Compiling model...
# 'compile' took 11.627919 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 457430    [5.44e-10, 2.57e-12, 4.45e-12]    [2.13e-10, 2.57e-12, 4.45e-12]    []
# 458000    [6.53e-10, 4.59e-12, 3.17e-11]    [2.80e-10, 4.59e-12, 3.17e-11]    []
# 459000    [8.55e-10, 4.58e-08, 1.63e-07]    [4.51e-10, 4.58e-08, 1.63e-07]    []
# Epoch 459431: early stopping
#
# Best model at step 457430:
#   train loss: 5.51e-10
#   test loss: 2.20e-10
#   test metric: []
#
# 'train' took 168.820562 s
#
# Compiling model...
# 'compile' took 11.256085 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 459431    [2.49e-09, 4.33e-07, 4.44e-08]    [2.11e-09, 4.33e-07, 4.44e-08]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 11
#   Number of functions evaluations: 25
# 459456    [6.53e-10, 9.29e-12, 2.33e-11]    [2.71e-10, 9.29e-12, 2.33e-11]    []
#
# Best model at step 457430:
#   train loss: 5.51e-10
#   test loss: 2.20e-10
#   test metric: []
#
# 'train' took 148.321562 s
#
# Mean residual: 1.195e-05
# Adding new point: [9.6753326e+01 3.4723792e-03]
#
# Compiling model...
# 'compile' took 10.829298 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 459456    [6.63e-10, 9.29e-12, 2.33e-11]    [2.71e-10, 9.29e-12, 2.33e-11]    []
# 460000    [1.46e-09, 2.12e-11, 6.06e-11]    [3.22e-10, 2.12e-11, 6.06e-11]    []
# 461000    [2.17e-09, 1.03e-05, 2.82e-08]    [1.75e-09, 1.03e-05, 2.82e-08]    []
# Epoch 461457: early stopping
#
# Best model at step 459456:
#   train loss: 6.96e-10
#   test loss: 3.04e-10
#   test metric: []
#
# 'train' took 164.238430 s
#
# Compiling model...
# 'compile' took 10.803286 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 461457    [5.61e-10, 6.24e-08, 5.64e-09]    [1.69e-10, 6.24e-08, 5.64e-09]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 6
#   Number of functions evaluations: 24
# 461481    [5.56e-10, 6.41e-13, 1.48e-12]    [1.64e-10, 6.41e-13, 1.48e-12]    []
#
# Best model at step 461481:
#   train loss: 5.58e-10
#   test loss: 1.66e-10
#   test metric: []
#
# 'train' took 180.414626 s
#
# Saving loss history to /Users/zhangtianjie/Documents/GitHub/P-rheologynet/first-try/RAR/lineplot/lambda/NN+PINN/loss.dat ...
# Saving training data to /Users/zhangtianjie/Documents/GitHub/P-rheologynet/first-try/RAR/lineplot/lambda/NN+PINN/train.dat ...
# Saving test data to /Users/zhangtianjie/Documents/GitHub/P-rheologynet/first-try/RAR/lineplot/lambda/NN+PINN/test.dat ...

# %%
import pandas as pd
test1=np.loadtxt('test.dat', unpack = True)
df = pd.DataFrame(test1.T, columns = ['x','t','exact','predict'])
df
# Out:
#                x           t     exact   predict
# 0       0.000000   60.730354  1.000000  1.000000
# 1       0.000000   89.285187  1.000000  1.000000
# 2       0.000000  156.538147  1.000000  1.000000
# 3       0.000000   97.121094  1.000000  1.000000
# 4       0.000000   12.401024  1.000000  0.999999
# ...          ...         ...       ...       ...
# 4845  169.966812  156.172424  0.029086  0.028765
# 4846   67.827797  149.111282  0.051417  0.051466
# 4847  160.855377   25.025579  0.568969  0.569107
# 4848   32.572655   63.153656  0.356454  0.356907
# 4849  140.324875  171.568558  0.022095  0.021897
#
# [4850 rows x 4 columns]

# %%
import pandas as pd
train1=np.loadtxt('train.dat', unpack = True)
train1 = pd.DataFrame(train1.T)
test1=np.loadtxt('test.dat', unpack = True)
df = pd.DataFrame(test1.T, columns = ['x','y','u','s'])
x = df['x']
y = df['y']
ext = df['u']
pre = df['s']
from scipy.interpolate import griddata
N = 1000; 
#npts = 2000*2000

# grid_x,grid_y = np.meshgrid(np.linspace(x.min(),x.max(),N),np.linspace(y.min(),y.max(),N))
grid_x,grid_y = np.meshgrid(np.linspace(0,200,N),np.linspace(0,200,N))
# grid_x1,grid_y1 = np.meshgrid(np.linspace(0,1,500),np.linspace(0,1,500))

#px, py = np.random.choice(x, npts), np.random.choice(y, npts)
grid_ext = griddata((x,y) ,ext, (grid_x, grid_y), method='linear')
grid_pre = griddata((x,y) ,pre, (grid_x, grid_y), method='linear')

grid_err = grid_pre-grid_ext

rng = np.random.default_rng()
# points = rng.random((1000, 2))

# a=np.zeros(1000)
# a[:]=np.nan
# grid_z2 = griddata(points ,  a , (grid_x1, grid_y1), method='cubic')
#grid_z1[999:2000,999:2000]=0
#scipy.interpolate.griddata(X,Y,X**2+Y**2,XI,YI)
plt.contourf(grid_x,grid_y, grid_pre,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.scatter(train1[0],train1[1],c='black',s=1)
# plt.scatter(test1[0],test1[1],c='yellow',s=1)
# plt.axis('equal')
plt.tight_layout()
# plt.axis('off')
plt.xlabel('time')
plt.xlim(0,200)
plt.ylabel('shear rate')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:32: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
# Text(23.875, 0.5, 'shear rate')

# %%
fig, ax = plt.subplots()
h=ax.contourf(grid_x,grid_y, grid_ext,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.xlabel('Time')
plt.ylabel('Shear Rate')

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('solution.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'

# %%
fig, ax = plt.subplots()
h=ax.contourf(grid_x,grid_y, grid_pre,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.xlabel('Time')
plt.ylabel('Shear Rate')

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('prediction.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'

# %%
fig, ax = plt.subplots()
h=ax.contourf(grid_x,grid_y, grid_err,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.xlabel('Time')
plt.ylabel('Shear Rate')

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('error.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'

# %% [markdown]
# # Test

# %%
x = np.linspace(0, 200, 200)
t = np.linspace(0, 200, 200)
X, T = np.meshgrid(x, t)

X_star = np.hstack((X.flatten()[:, None], T.flatten()[:, None]))
prediction = model.predict(X_star, operator=None)

pre = griddata(X_star, prediction[:, 0], (X, T), method="cubic")

fig, ax = plt.subplots()
h=ax.contourf(X,T, pre,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title('$\mathbf{\lambda _{RheologyNet}}$ ',fontproperties = 'Times New Roman', size = 14)


from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('pinn_of_λ.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:11: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# # exact solution

# %%
train1=np.loadtxt('train.dat', unpack = True)
train1 = pd.DataFrame(train1.T)
ext = griddata(X_star, solution1(X_star[:,0],X_star[:,1]), (X, T), method="cubic")
fig, ax = plt.subplots()
h=ax.contourf(X,T, ext,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title('$\mathbf{\lambda _{FEA}}$ ',fontproperties = 'Times New Roman', size = 14)
plt.scatter(train1[0],train1[1],c='black',s=1)


from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('solution_of_λ.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
#   """

# %%
err=abs(pre-ext)
fig, ax = plt.subplots()
h=ax.contourf(X,T, err,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )

plt.title(r'$\mathbf{\varepsilon_{\lambda ,RheologyNet} }$ ',fontproperties = 'Times New Roman', size = 14 )

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('pinn_err_λ.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
train=np.loadtxt('train.dat', unpack = True)
df = pd.DataFrame(train.T)
df
# Out:
#                0           1         2
# 0       0.000000   60.730354  1.000000
# 1       0.000000   89.285187  1.000000
# 2       0.000000  156.538147  1.000000
# 3       0.000000   97.121094  1.000000
# 4       0.000000   12.401024  1.000000
# ...          ...         ...       ...
# 5045  169.966812  156.172424  0.029086
# 5046   67.827797  149.111282  0.051417
# 5047  160.855377   25.025579  0.568969
# 5048   32.572655   63.153656  0.356454
# 5049  140.324875  171.568558  0.022095
#
# [5050 rows x 3 columns]

# %%
import pandas as pd
train=np.loadtxt('train.dat', unpack = True)
# train= pd.DataFrame(train.T)
# test1=np.loadtxt('test.dat', unpack = True)
df = pd.DataFrame(train.T, columns = ['x','y','u'])
x = df['x']
y = df['y']
z = df['u']
from scipy.interpolate import griddata
N = 1000; 
#npts = 2000*2000

grid_x,grid_y = np.meshgrid(np.linspace(x.min(),x.max(),N),np.linspace(y.min(),y.max(),N))
# grid_x1,grid_y1 = np.meshgrid(np.linspace(0,1,500),np.linspace(0,1,500))

#px, py = np.random.choice(x, npts), np.random.choice(y, npts)
grid_z1 = griddata((x,y) ,z, (grid_x, grid_y), method='linear')

rng = np.random.default_rng()
# points = rng.random((1000, 2))

# a=np.zeros(1000)
# a[:]=np.nan
# grid_z2 = griddata(points ,  a , (grid_x1, grid_y1), method='cubic')
#grid_z1[999:2000,999:2000]=0
#scipy.interpolate.griddata(X,Y,X**2+Y**2,XI,YI)
plt.contourf(grid_x,grid_y, grid_z1,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
# plt.scatter(train1[0],train1[1],c='red',s=1)
# plt.scatter(test1[0],test1[1],c='black',s=1)
# plt.axis('equal')
plt.tight_layout()
# plt.axis('off')
plt.xlabel('time')
plt.xlim(0,200)
plt.ylabel('shear rate')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
# Text(23.875, 0.5, 'shear rate')

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_absolute_error

train=np.loadtxt('train.dat', unpack = True)
x_train = train[[0,1]].T
y_train = train[2]

clf = MLPRegressor(hidden_layer_sizes=(50,50,50),max_iter=50000)

clf.fit(x_train, y_train)
# Out:
# MLPRegressor(hidden_layer_sizes=(50, 50, 50), max_iter=50000)

# %%
x = np.linspace(0, 200, 200)
t = np.linspace(0, 200, 200)
X, T = np.meshgrid(x, t)

X_star = np.hstack((X.flatten()[:, None], T.flatten()[:, None]))

prediction = clf.predict(X_star)

pre_nn = griddata(X_star, prediction, (X, T), method="cubic")

fig, ax = plt.subplots()
h=ax.contourf(X,T, pre_nn,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title('$\mathbf{\lambda _{FNN}}$ ',fontproperties = 'Times New Roman', size = 14)

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('FNN_pre.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
#   if sys.path[0] == '':

# %%
err_nn = abs(pre_nn-ext)
fig, ax = plt.subplots()
h=ax.contourf(X,T, err_nn,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title(r'$\mathbf{\varepsilon_{\lambda ,FNN} }$ ',fontproperties = 'Times New Roman', size = 14)

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('FNN_err.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(pre,ext)
# Out:
# 5.8371101925897736e-05

# %%
mean_squared_error(pre_nn,ext)
# Out:
# 0.0022430281190722813

# %%
d={'RheologyNet of lambda':[0.0003,0.0021,0.0005],'FNN of lambda':[0.0023,0.0034,0.0041],'RheologyNet of shear':[0.0003,0.0021,0.0005],'FNN of shear':[0.0023,0.0034,0.0041]}
data=pd.DataFrame(data=d)
plt.boxplot(data)
plt.xticks([1,2,3,4],['RheologyNet','FNN','Rhe','N'])
# plt.yscale('log')
# plt.ylim(0,1)
# Out:
# ([<matplotlib.axis.XTick at 0x7fb52f987dd0>,
#   <matplotlib.axis.XTick at 0x7fb53e6b7590>,
#   <matplotlib.axis.XTick at 0x7fb53ff49190>,
#   <matplotlib.axis.XTick at 0x7fb53ff49410>],
#  [Text(1, 0, 'RheologyNet'),
#   Text(2, 0, 'FNN'),
#   Text(3, 0, 'Rhe'),
#   Text(4, 0, 'N')])
