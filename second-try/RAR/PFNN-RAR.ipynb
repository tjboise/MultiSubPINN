# %%
import deepxde as dde
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy.interpolate import griddata
import scipy.io
import tensorflow as tf
from PIL import Image
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import torch
# Out:
# Using backend: tensorflow.compat.v1
# WARNING:tensorflow:From /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/deepxde/nn/initializers.py:118: The name tf.keras.initializers.he_normal is deprecated. Please use tf.compat.v1.keras.initializers.he_normal instead.

# %%
def solution(x1,x2):
    y_f = 12.1
    A_0 = 43.6
    
    A_1 =131.2
    
    C = 56.1
    a=2100
    b=9.45
    y = y_f+(A_0+(A_1-A_0)*np.exp(-x2*x1/(a+b*x2)))*(np.arcsinh(x2/C))
    
    return y

# %%
def PDE(x,y):
    
    x1,x2=x[:,0:1],x[:,1:2]#, t,shear rate

    y_f = 12.1
    A_0 = 43.6
    
    A_1 =131.2
    
    C = 56.1
    a=2100
    b=9.45
   
    eq1 = y_f+(A_0+(A_1-A_0)*tf.exp(-x2*x1/(a+b*x2)))*(tf.math.asinh(x2/C))-y
  
    return eq1

def func(x):
    
    return solution(x[:,0:1],x[:,1:2])

geom = dde.geometry.Rectangle([0, 0], [200, 200])

#geom = dde.geometry.TimeDomain(0, 200)
data = dde.data.PDE(geom, PDE, [], 3500, 1000,train_distribution='pseudo',solution=func)

layer_size = [2] + [50] * 3 + [1]
activation = "tanh"
initializer = "Glorot uniform"
net = dde.maps.PFNN(layer_size, activation, initializer)

model = dde.Model(data, net)
model.compile("adam", lr=0.001)
model.train(iterations=15000)
model.compile("L-BFGS")
model.train()
# losshistory, train_state = model.train(epochs=1000)

# dde.saveplot(losshistory, train_state, issave=True, isplot=True)


X = geom.random_points(10000)
err = 1
# itr = 0

# for itr in range(5):
#     if err > 0.005:
new_points = []
for i in range(200):
    f = model.predict(X, operator=PDE)
    err_eq = np.absolute(f)
    err = np.mean(err_eq)
    print("Mean residual: %.3e" % (err))

    x_id = np.argmax(err_eq)
    print("Adding new point:", X[x_id], "\n")
    new_points.append(X[x_id])
    data.add_anchors(X[x_id])
    early_stopping = dde.callbacks.EarlyStopping(min_delta=1e-4, patience=2000)
    model.compile("adam", lr=1e-3)
    model.train(iterations=10000, disregard_previous_best=True, callbacks=[early_stopping])
    model.compile("L-BFGS")
    losshistory, train_state = model.train()
#     itr = itr+1
#     print('itr:',itr)
        
dde.saveplot(losshistory, train_state, issave=True, isplot=True)

# X, y_true = gen_testdata()
# y_pred = model.predict(X)
# print("L2 relative error:", dde.metrics.l2_relative_error(y_true, y_pred))
# np.savetxt("test.dat", np.hstack((X, y_true, y_pred)))
# Out:
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.040064 s
#
# 'compile' took 0.153229 s
#
# Initializing variables...
# Training model...
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/deepxde/nn/tensorflow_compat_v1/fnn.py:110: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   kernel_constraint=self.kernel_constraint,
# 2023-09-05 22:00:04.259039: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-05 22:00:04.376043: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# Step      Train loss    Test loss     Test metric
# 0         [9.56e+03]    [9.56e+03]    []
# 1000      [3.08e+03]    [3.08e+03]    []
# 2000      [1.49e+03]    [1.49e+03]    []
# 3000      [9.02e+02]    [9.02e+02]    []
# 4000      [5.46e+02]    [5.46e+02]    []
# 5000      [3.09e+02]    [3.09e+02]    []
# 6000      [1.62e+02]    [1.62e+02]    []
# 7000      [7.84e+01]    [7.84e+01]    []
# 8000      [3.58e+01]    [3.58e+01]    []
# 9000      [1.39e+01]    [1.39e+01]    []
# 10000     [4.75e+00]    [4.75e+00]    []
# 11000     [1.52e+00]    [1.52e+00]    []
# 12000     [5.92e-01]    [5.92e-01]    []
# 13000     [5.84e-01]    [5.84e-01]    []
# 14000     [8.21e-02]    [8.21e-02]    []
# 15000     [3.82e-02]    [3.82e-02]    []
#
# Best model at step 15000:
#   train loss: 3.82e-02
#   test loss: 3.82e-02
#   test metric: []
#
# 'train' took 53.534904 s
#
# Compiling model...
# 'compile' took 0.068997 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 15000     [3.82e-02]    [3.82e-02]    []
# 16000     [5.76e-03]    [5.76e-03]
# 17000     [2.30e-03]    [2.30e-03]
# 18000     [1.42e-03]    [1.42e-03]
# 19000     [8.64e-04]    [8.64e-04]
# 20000     [6.38e-04]    [6.38e-04]
# 21000     [4.29e-04]    [4.29e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000395
#   Number of iterations: 6266
#   Number of functions evaluations: 6540
# 21540     [3.95e-04]    [3.95e-04]    []
#
# Best model at step 21540:
#   train loss: 3.95e-04
#   test loss: 3.95e-04
#   test metric: []
#
# 'train' took 51.028160 s
#
# Mean residual: 1.416e-02
# Adding new point: [3.7009268 4.5848923]
#
# Compiling model...
# 'compile' took 0.152652 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 21540     [4.67e-04]    [3.95e-04]    []
# 22000     [1.74e-03]    [1.69e-03]    []
# 23000     [1.17e-03]    [1.13e-03]    []
# Epoch 23541: early stopping
#
# Best model at step 21540:
#   train loss: 4.67e-04
#   test loss: 3.95e-04
#   test metric: []
#
# 'train' took 7.792589 s
#
# Compiling model...
# 'compile' took 0.088620 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 23541     [1.72e-03]    [1.68e-03]    []
# 24000     [6.45e-04]    [6.45e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000481
#   Number of iterations: 790
#   Number of functions evaluations: 847
# 24388     [4.81e-04]    [4.52e-04]    []
#
# Best model at step 21540:
#   train loss: 4.67e-04
#   test loss: 3.95e-04
#   test metric: []
#
# 'train' took 7.163527 s
#
# Mean residual: 1.531e-02
# Adding new point: [4.783122  3.1807642]
#
# Compiling model...
# 'compile' took 0.120840 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 24388     [5.19e-04]    [4.52e-04]    []
# 25000     [7.74e-04]    [7.01e-04]    []
# 26000     [2.56e-03]    [2.52e-03]    []
# Epoch 26389: early stopping
#
# Best model at step 24388:
#   train loss: 5.19e-04
#   test loss: 4.52e-04
#   test metric: []
#
# 'train' took 7.632319 s
#
# Compiling model...
# 'compile' took 0.090931 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 26389     [1.31e-03]    [1.26e-03]    []
# 27000     [5.86e-04]    [5.86e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000405
#   Number of iterations: 1210
#   Number of functions evaluations: 1301
# 27690     [4.05e-04]    [3.72e-04]    []
#
# Best model at step 27690:
#   train loss: 4.05e-04
#   test loss: 3.72e-04
#   test metric: []
#
# 'train' took 10.443027 s
#
# Mean residual: 1.315e-02
# Adding new point: [4.970337 3.533727]
#
# Compiling model...
# 'compile' took 0.134655 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 27690     [4.32e-04]    [3.72e-04]    []
# 28000     [1.84e-03]    [1.79e-03]    []
# 29000     [7.12e-04]    [6.71e-04]    []
# Epoch 29691: early stopping
#
# Best model at step 27690:
#   train loss: 4.32e-04
#   test loss: 3.72e-04
#   test metric: []
#
# 'train' took 7.455135 s
#
# Compiling model...
# 'compile' took 0.070501 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 29691     [9.17e-04]    [8.78e-04]    []
# 30000     [5.75e-04]    [5.75e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000528
#   Number of iterations: 399
#   Number of functions evaluations: 430
# 30121     [5.28e-04]    [4.94e-04]    []
#
# Best model at step 27690:
#   train loss: 4.32e-04
#   test loss: 3.72e-04
#   test metric: []
#
# 'train' took 3.449142 s
#
# Mean residual: 1.508e-02
# Adding new point: [ 11.9455595 198.54538  ]
#
# Compiling model...
# 'compile' took 0.146831 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 30121     [5.46e-04]    [4.94e-04]    []
# 31000     [7.64e-04]    [7.15e-04]    []
# 32000     [1.08e-03]    [1.04e-03]    []
# Epoch 32122: early stopping
#
# Best model at step 30121:
#   train loss: 5.46e-04
#   test loss: 4.94e-04
#   test metric: []
#
# 'train' took 7.530909 s
#
# Compiling model...
# 'compile' took 0.068817 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 32122     [1.42e-03]    [1.38e-03]    []
# 33000     [4.31e-04]    [4.31e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000359
#   Number of iterations: 1147
#   Number of functions evaluations: 1279
# 33401     [3.59e-04]    [3.39e-04]    []
#
# Best model at step 33401:
#   train loss: 3.59e-04
#   test loss: 3.39e-04
#   test metric: []
#
# 'train' took 9.777056 s
#
# Mean residual: 1.248e-02
# Adding new point: [4.870718 2.969908]
#
# Compiling model...
# 'compile' took 0.115501 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 33401     [3.69e-04]    [3.39e-04]    []
# 34000     [8.49e-04]    [8.02e-04]    []
# 35000     [4.53e-04]    [4.25e-04]    []
# Epoch 35402: early stopping
#
# Best model at step 33401:
#   train loss: 3.69e-04
#   test loss: 3.39e-04
#   test metric: []
#
# 'train' took 7.539639 s
#
# Compiling model...
# 'compile' took 0.076765 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 35402     [1.64e-03]    [1.61e-03]    []
# 36000     [4.02e-04]    [4.02e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000392
#   Number of iterations: 594
#   Number of functions evaluations: 641
# 36043     [3.92e-04]    [3.68e-04]    []
#
# Best model at step 33401:
#   train loss: 3.69e-04
#   test loss: 3.39e-04
#   test metric: []
#
# 'train' took 5.076861 s
#
# Mean residual: 1.377e-02
# Adding new point: [2.3679602 8.083872 ]
#
# Compiling model...
# 'compile' took 0.120598 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 36043     [4.03e-04]    [3.68e-04]    []
# 37000     [1.87e-03]    [1.84e-03]    []
# 38000     [8.20e-04]    [7.83e-04]    []
# Epoch 38044: early stopping
#
# Best model at step 36043:
#   train loss: 4.03e-04
#   test loss: 3.68e-04
#   test metric: []
#
# 'train' took 7.524819 s
#
# Compiling model...
# 'compile' took 0.076723 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 38044     [7.87e-04]    [7.51e-04]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000402
#   Number of iterations: 699
#   Number of functions evaluations: 743
# 38787     [4.02e-04]    [3.73e-04]    []
#
# Best model at step 38787:
#   train loss: 4.02e-04
#   test loss: 3.73e-04
#   test metric: []
#
# 'train' took 6.027517 s
#
# Mean residual: 1.374e-02
# Adding new point: [4.870718 2.969908]
#
# Compiling model...
# 'compile' took 0.119034 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 38787     [4.10e-04]    [3.73e-04]    []
# 39000     [4.30e-03]    [4.26e-03]    []
# 40000     [5.05e-04]    [4.71e-04]    []
# Epoch 40788: early stopping
#
# Best model at step 38787:
#   train loss: 4.10e-04
#   test loss: 3.73e-04
#   test metric: []
#
# 'train' took 7.672050 s
# Compiling model...
# 'compile' took 0.074381 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 40788     [3.21e-02]    [3.21e-02]    []
# 41000     [6.82e-04]    [6.82e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000416
#   Number of iterations: 668
#   Number of functions evaluations: 721
# 41509     [4.16e-04]    [3.83e-04]    []
#
# Best model at step 38787:
#   train loss: 4.10e-04
#   test loss: 3.73e-04
#   test metric: []
#
# 'train' took 6.310264 s
#
# Mean residual: 1.425e-02
# Adding new point: [2.9382558 6.422633 ]
#
# Compiling model...
# 'compile' took 0.150029 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 41509     [4.25e-04]    [3.83e-04]    []
# 42000     [6.59e-04]    [6.33e-04]    []
# 43000     [9.38e-04]    [9.09e-04]    []
# Epoch 43510: early stopping
#
# Best model at step 41509:
#   train loss: 4.25e-04
#   test loss: 3.83e-04
#   test metric: []
#
# 'train' took 7.998728 s
#
# Compiling model...
# 'compile' took 0.093695 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 43510     [3.69e-02]    [3.69e-02]    []
# 44000     [5.91e-04]    [5.91e-04]
# 45000     [2.93e-04]    [2.93e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000279
#   Number of iterations: 1540
#   Number of functions evaluations: 1607
# 45117     [2.79e-04]    [2.69e-04]    []
#
# Best model at step 45117:
#   train loss: 2.79e-04
#   test loss: 2.69e-04
#   test metric: []
#
# 'train' took 13.579242 s
#
# Mean residual: 1.137e-02
# Adding new point: [11.800545    0.04671847]
#
# Compiling model...
# 'compile' took 0.142203 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 45117     [2.86e-04]    [2.69e-04]    []
# 46000     [4.31e-04]    [4.11e-04]    []
# 47000     [5.96e-04]    [5.76e-04]    []
# Epoch 47118: early stopping
#
# Best model at step 45117:
#   train loss: 2.86e-04
#   test loss: 2.69e-04
#   test metric: []
#
# 'train' took 7.907629 s
#
# Compiling model...
# 'compile' took 0.095133 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 47118     [4.55e-04]    [4.35e-04]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000314
#   Number of iterations: 483
#   Number of functions evaluations: 551
# 47669     [3.14e-04]    [2.96e-04]    []
#
# Best model at step 45117:
#   train loss: 2.86e-04
#   test loss: 2.69e-04
#   test metric: []
#
# 'train' took 4.884446 s
#
# Mean residual: 1.256e-02
# Adding new point: [27.183512  2.610637]
#
# Compiling model...
# 'compile' took 0.158263 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 47669     [3.20e-04]    [2.96e-04]    []
# 48000     [1.59e-03]    [1.57e-03]    []
# 49000     [9.37e-04]    [9.20e-04]    []
# Epoch 49670: early stopping
#
# Best model at step 47669:
#   train loss: 3.20e-04
#   test loss: 2.96e-04
#   test metric: []
#
# 'train' took 7.983352 s
#
# Compiling model...
# 'compile' took 0.081076 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 49670     [7.58e-04]    [7.39e-04]    []
# 50000     [5.20e-04]    [5.20e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000304
#   Number of iterations: 1085
#   Number of functions evaluations: 1147
# 50817     [3.04e-04]    [2.85e-04]    []
#
# Best model at step 50817:
#   train loss: 3.04e-04
#   test loss: 2.85e-04
#   test metric: []
#
# 'train' took 9.362019 s
#
# Mean residual: 1.230e-02
# Adding new point: [28.276396   2.0598152]
#
# Compiling model...
# 'compile' took 0.123372 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 50817     [3.10e-04]    [2.85e-04]    []
# 51000     [2.75e-03]    [2.73e-03]    []
# 52000     [5.10e-04]    [4.94e-04]    []
# Epoch 52818: early stopping
#
# Best model at step 50817:
#   train loss: 3.10e-04
#   test loss: 2.85e-04
#   test metric: []
#
# 'train' took 7.794218 s
#
# Compiling model...
# 'compile' took 0.106269 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 52818     [1.75e-03]    [1.73e-03]    []
# 53000     [5.68e-04]    [5.68e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000327
#   Number of iterations: 852
#   Number of functions evaluations: 893
# 53711     [3.27e-04]    [3.09e-04]    []
#
# Best model at step 50817:
#   train loss: 3.10e-04
#   test loss: 2.85e-04
#   test metric: []
#
# 'train' took 7.908751 s
#
# Mean residual: 1.274e-02
# Adding new point: [9.081224 3.871598]
#
# Compiling model...
# 'compile' took 0.133986 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 53711     [3.31e-04]    [3.09e-04]    []
# 54000     [7.47e-04]    [7.21e-04]    []
# 55000     [2.87e-02]    [2.87e-02]    []
# Epoch 55712: early stopping
#
# Best model at step 53711:
#   train loss: 3.31e-04
#   test loss: 3.09e-04
#   test metric: []
#
# 'train' took 7.986632 s
#
# Compiling model...
# 'compile' took 0.085512 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 55712     [2.06e-02]    [2.06e-02]    []
# 56000     [5.06e-04]    [5.06e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000299
#   Number of iterations: 1078
#   Number of functions evaluations: 1186
# 56898     [2.99e-04]    [2.82e-04]    []
#
# Best model at step 56898:
#   train loss: 2.99e-04
#   test loss: 2.82e-04
#   test metric: []
#
# 'train' took 9.837649 s
#
# Mean residual: 1.237e-02
# Adding new point: [2.036599  3.6303017]
#
# Compiling model...
# 'compile' took 0.127721 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 56898     [3.05e-04]    [2.82e-04]    []
# 57000     [2.37e-03]    [2.30e-03]    []
# 58000     [2.88e-03]    [2.87e-03]    []
# Epoch 58899: early stopping
#
# Best model at step 56898:
#   train loss: 3.05e-04
#   test loss: 2.82e-04
#   test metric: []
#
# 'train' took 7.947514 s
#
# Compiling model...
# 'compile' took 0.085765 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 58899     [6.21e-04]    [6.05e-04]    []
# 59000     [5.45e-04]    [5.45e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000362
#   Number of iterations: 649
#   Number of functions evaluations: 695
# 59594     [3.62e-04]    [3.46e-04]    []
#
# Best model at step 56898:
#   train loss: 3.05e-04
#   test loss: 2.82e-04
#   test metric: []
#
# 'train' took 6.014372 s
#
# Mean residual: 1.362e-02
# Adding new point: [7.5965919e-02 1.9513449e+02]
#
# Compiling model...
# 'compile' took 0.126387 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 59594     [3.65e-04]    [3.46e-04]    []
# 60000     [4.70e-04]    [4.53e-04]    []
# 61000     [1.47e-03]    [1.45e-03]    []
# Epoch 61595: early stopping
#
# Best model at step 59594:
#   train loss: 3.65e-04
#   test loss: 3.46e-04
#   test metric: []
#
# 'train' took 8.094786 s
#
# Compiling model...
# 'compile' took 0.085741 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 61595     [1.20e-03]    [1.18e-03]    []
# 62000     [4.92e-04]    [4.92e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000419
#   Number of iterations: 629
#   Number of functions evaluations: 673
# 62268     [4.19e-04]    [4.02e-04]    []
#
# Best model at step 59594:
#   train loss: 3.65e-04
#   test loss: 3.46e-04
#   test metric: []
#
# 'train' took 5.946778 s
#
# Mean residual: 1.470e-02
# Adding new point: [17.263538   3.9934034]
#
# Compiling model...
# 'compile' took 0.127304 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 62268     [4.24e-04]    [4.02e-04]    []
# 63000     [4.97e-04]    [4.78e-04]    []
# 64000     [8.22e-04]    [8.07e-04]    []
# Epoch 64269: early stopping
#
# Best model at step 62268:
#   train loss: 4.24e-04
#   test loss: 4.02e-04
#   test metric: []
#
# 'train' took 8.134339 s
# Compiling model...
# 'compile' took 0.087936 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 64269     [6.79e-04]    [6.61e-04]    []
# 65000     [4.20e-04]    [4.20e-04]
# 66000     [2.86e-04]    [2.86e-04]
# 67000     [2.08e-04]    [2.08e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000173
#   Number of iterations: 3362
#   Number of functions evaluations: 3567
# 67836     [1.73e-04]    [1.63e-04]    []
#
# Best model at step 67836:
#   train loss: 1.73e-04
#   test loss: 1.63e-04
#   test metric: []
#
# 'train' took 28.862800 s
#
# Mean residual: 9.445e-03
# Adding new point: [0.9202414 9.624722 ]
#
# Compiling model...
# 'compile' took 0.139507 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 67836     [1.77e-04]    [1.63e-04]    []
# 68000     [2.19e-03]    [2.18e-03]    []
# 69000     [1.86e-04]    [1.74e-04]    []
# Epoch 69837: early stopping
#
# Best model at step 67836:
#   train loss: 1.77e-04
#   test loss: 1.63e-04
#   test metric: []
#
# 'train' took 8.138174 s
#
# Compiling model...
# 'compile' took 0.096488 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 69837     [3.36e-04]    [3.24e-04]    []
# 70000     [2.52e-04]    [2.52e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000185
#   Number of iterations: 642
#   Number of functions evaluations: 699
# 70536     [1.85e-04]    [1.74e-04]    []
#
# Best model at step 67836:
#   train loss: 1.77e-04
#   test loss: 1.63e-04
#   test metric: []
#
# 'train' took 6.555042 s
#
# Mean residual: 9.869e-03
# Adding new point: [ 5.299521 36.85669 ]
#
# Compiling model...
# 'compile' took 0.129989 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 70536     [1.87e-04]    [1.74e-04]    []
# 71000     [3.27e-04]    [3.15e-04]    []
# 72000     [5.98e-04]    [5.85e-04]    []
# Epoch 72537: early stopping
#
# Best model at step 70536:
#   train loss: 1.87e-04
#   test loss: 1.74e-04
#   test metric: []
#
# 'train' took 8.472903 s
#
# Compiling model...
# 'compile' took 0.119748 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 72537     [6.67e-04]    [6.52e-04]    []
# 73000     [2.82e-04]    [2.82e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000213
#   Number of iterations: 1194
#   Number of functions evaluations: 1281
# 73818     [2.13e-04]    [2.01e-04]    []
#
# Best model at step 70536:
#   train loss: 1.87e-04
#   test loss: 1.74e-04
#   test metric: []
#
# 'train' took 11.750317 s
#
# Mean residual: 1.083e-02
# Adding new point: [ 4.9418683 68.24495  ]
#
# Compiling model...
# 'compile' took 0.163126 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 73818     [2.15e-04]    [2.01e-04]    []
# 74000     [3.47e-03]    [3.45e-03]    []
# 75000     [8.01e-04]    [7.84e-04]    []
# Epoch 75819: early stopping
#
# Best model at step 73818:
#   train loss: 2.15e-04
#   test loss: 2.01e-04
#   test metric: []
#
# 'train' took 8.762347 s
#
# Compiling model...
# 'compile' took 0.100550 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 75819     [3.71e-04]    [3.56e-04]    []
# 76000     [3.23e-04]    [3.23e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000240
#   Number of iterations: 893
#   Number of functions evaluations: 984
# 76803     [2.40e-04]    [2.27e-04]    []
#
# Best model at step 73818:
#   train loss: 2.15e-04
#   test loss: 2.01e-04
#   test metric: []
#
# 'train' took 9.149705 s
#
# Mean residual: 1.147e-02
# Adding new point: [ 0.687189 48.64642 ]
#
# Compiling model...
# 'compile' took 0.164412 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 76803     [2.42e-04]    [2.27e-04]    []
# 77000     [9.28e-04]    [9.00e-04]    []
# 78000     [2.95e-04]    [2.80e-04]    []
# Epoch 78804: early stopping
#
# Best model at step 76803:
#   train loss: 2.42e-04
#   test loss: 2.27e-04
#   test metric: []
#
# 'train' took 8.687694 s
#
# Compiling model...
# 'compile' took 0.115187 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 78804     [4.27e-04]    [4.12e-04]    []
# 79000     [3.80e-04]    [3.80e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000285
#   Number of iterations: 608
#   Number of functions evaluations: 668
# 79472     [2.85e-04]    [2.73e-04]    []
#
# Best model at step 76803:
#   train loss: 2.42e-04
#   test loss: 2.27e-04
#   test metric: []
#
# 'train' took 6.797693 s
#
# Mean residual: 1.237e-02
# Adding new point: [ 1.986124 38.25698 ]
#
# Compiling model...
# 'compile' took 0.155275 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 79472     [2.88e-04]    [2.73e-04]    []
# 80000     [4.98e-04]    [4.79e-04]    []
# 81000     [4.31e-04]    [4.14e-04]    []
# Epoch 81473: early stopping
#
# Best model at step 79472:
#   train loss: 2.88e-04
#   test loss: 2.73e-04
#   test metric: []
#
# 'train' took 9.053900 s
#
# Compiling model...
# 'compile' took 0.118163 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 81473     [4.16e-04]    [4.00e-04]    []
# 82000     [3.10e-04]    [3.10e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000310
#   Number of iterations: 509
#   Number of functions evaluations: 550
# 82023     [3.10e-04]    [2.97e-04]    []
#
# Best model at step 79472:
#   train loss: 2.88e-04
#   test loss: 2.73e-04
#   test metric: []
#
# 'train' took 6.108610 s
#
# Mean residual: 1.299e-02
# Adding new point: [ 12.763587 199.78543 ]
#
# Compiling model...
# 'compile' took 0.177158 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 82023     [3.12e-04]    [2.97e-04]    []
# 83000     [1.13e-03]    [1.11e-03]    []
# 84000     [1.22e-02]    [1.22e-02]    []
# Epoch 84024: early stopping
#
# Best model at step 82023:
#   train loss: 3.12e-04
#   test loss: 2.97e-04
#   test metric: []
#
# 'train' took 9.082268 s
#
# Compiling model...
# 'compile' took 0.144290 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 84024     [2.00e-03]    [1.99e-03]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000328
#   Number of iterations: 814
#   Number of functions evaluations: 876
# 84900     [3.28e-04]    [3.12e-04]    []
#
# Best model at step 82023:
#   train loss: 3.12e-04
#   test loss: 2.97e-04
#   test metric: []
#
# 'train' took 8.676738 s
#
# Mean residual: 1.380e-02
# Adding new point: [ 3.2590356 64.3246   ]
#
# Compiling model...
# 'compile' took 0.140084 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 84900     [3.32e-04]    [3.12e-04]    []
# 85000     [2.93e-03]    [2.92e-03]    []
# 86000     [3.34e-04]    [3.17e-04]    []
# Epoch 86901: early stopping
#
# Best model at step 84900:
#   train loss: 3.32e-04
#   test loss: 3.12e-04
#   test metric: []
#
# 'train' took 8.958306 s
#
# Compiling model...
# 'compile' took 0.234739 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 86901     [1.94e-01]    [1.94e-01]    []
# 87000     [4.10e-04]    [4.10e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000307
#   Number of iterations: 781
#   Number of functions evaluations: 835
# 87736     [3.07e-04]    [2.92e-04]    []
#
# Best model at step 87736:
#   train loss: 3.07e-04
#   test loss: 2.92e-04
#   test metric: []
#
# 'train' took 8.686960 s
#
# Mean residual: 1.337e-02
# Adding new point: [ 0.687189 48.64642 ]
#
# Compiling model...
# 'compile' took 0.188757 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 87736     [3.09e-04]    [2.92e-04]    []
# 88000     [5.70e-04]    [5.51e-04]    []
# 89000     [7.23e-04]    [7.02e-04]    []
# Epoch 89737: early stopping
#
# Best model at step 87736:
#   train loss: 3.09e-04
#   test loss: 2.92e-04
#   test metric: []
#
# 'train' took 9.155612 s
# Compiling model...
# 'compile' took 0.115799 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 89737     [3.12e-03]    [3.10e-03]    []
# 90000     [5.10e-04]    [5.10e-04]
# 91000     [3.09e-04]    [3.09e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000233
#   Number of iterations: 2000
#   Number of functions evaluations: 2123
# 91860     [2.33e-04]    [2.26e-04]    []
#
# Best model at step 91860:
#   train loss: 2.33e-04
#   test loss: 2.26e-04
#   test metric: []
#
# 'train' took 18.796134 s
#
# Mean residual: 1.174e-02
# Adding new point: [5.0762987 7.794723 ]
#
# Compiling model...
# 'compile' took 0.174062 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 91860     [2.36e-04]    [2.26e-04]    []
# 92000     [1.94e-03]    [1.92e-03]    []
# 93000     [3.72e-04]    [3.60e-04]    []
# Epoch 93861: early stopping
#
# Best model at step 91860:
#   train loss: 2.36e-04
#   test loss: 2.26e-04
#   test metric: []
#
# 'train' took 9.319418 s
#
# Compiling model...
# 'compile' took 0.143139 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 93861     [2.38e-01]    [2.38e-01]    []
# 94000     [4.13e-04]    [4.13e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000270
#   Number of iterations: 840
#   Number of functions evaluations: 924
# 94785     [2.70e-04]    [2.58e-04]    []
#
# Best model at step 91860:
#   train loss: 2.36e-04
#   test loss: 2.26e-04
#   test metric: []
#
# 'train' took 9.509965 s
#
# Mean residual: 1.238e-02
# Adding new point: [  5.2361608 194.95526  ]
#
# Compiling model...
# 'compile' took 0.177694 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 94785     [2.74e-04]    [2.58e-04]    []
# 95000     [7.19e-04]    [6.98e-04]    []
# 96000     [9.28e-02]    [9.29e-02]    []
# Epoch 96786: early stopping
#
# Best model at step 94785:
#   train loss: 2.74e-04
#   test loss: 2.58e-04
#   test metric: []
#
# 'train' took 9.737816 s
#
# Compiling model...
# 'compile' took 0.112076 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 96786     [7.40e-02]    [7.39e-02]    []
# 97000     [4.62e-04]    [4.62e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000274
#   Number of iterations: 1057
#   Number of functions evaluations: 1157
# 97943     [2.74e-04]    [2.59e-04]    []
#
# Best model at step 97943:
#   train loss: 2.74e-04
#   test loss: 2.59e-04
#   test metric: []
#
# 'train' took 12.048287 s
#
# Mean residual: 1.228e-02
# Adding new point: [ 3.2590356 64.3246   ]
#
# Compiling model...
# 'compile' took 0.177945 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 97943     [2.77e-04]    [2.59e-04]    []
# 98000     [1.61e-02]    [1.60e-02]    []
# 99000     [3.42e-03]    [3.40e-03]    []
# Epoch 99944: early stopping
#
# Best model at step 97943:
#   train loss: 2.77e-04
#   test loss: 2.59e-04
#   test metric: []
#
# 'train' took 9.671043 s
#
# Compiling model...
# 'compile' took 0.138447 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 99944     [6.35e-01]    [6.36e-01]    []
# 100000    [6.68e-04]    [6.68e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000336
#   Number of iterations: 495
#   Number of functions evaluations: 525
# 100469    [3.36e-04]    [3.21e-04]    []
#
# Best model at step 97943:
#   train loss: 2.77e-04
#   test loss: 2.59e-04
#   test metric: []
#
# 'train' took 7.109560 s
#
# Mean residual: 1.361e-02
# Adding new point: [ 3.6948376 35.09258  ]
#
# Compiling model...
# 'compile' took 0.239804 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 100469    [3.40e-04]    [3.21e-04]    []
# 101000    [1.88e-02]    [1.88e-02]    []
# 102000    [2.58e-02]    [2.58e-02]    []
# Epoch 102470: early stopping
#
# Best model at step 100469:
#   train loss: 3.40e-04
#   test loss: 3.21e-04
#   test metric: []
#
# 'train' took 9.873804 s
#
# Compiling model...
# 'compile' took 0.136490 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 102470    [2.74e-03]    [2.72e-03]    []
# 103000    [4.05e-04]    [4.05e-04]
# 104000    [2.80e-04]    [2.80e-04]
# 105000    [2.13e-04]    [2.13e-04]
# 106000    [1.65e-04]    [1.65e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000139
#   Number of iterations: 3997
#   Number of functions evaluations: 4232
# 106702    [1.39e-04]    [1.34e-04]    []
#
# Best model at step 106702:
#   train loss: 1.39e-04
#   test loss: 1.34e-04
#   test metric: []
#
# 'train' took 37.677166 s
#
# Mean residual: 8.805e-03
# Adding new point: [  1.6637931 144.04237  ]
#
# Compiling model...
# 'compile' took 0.148194 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 106702    [1.41e-04]    [1.34e-04]    []
# 107000    [4.50e-04]    [4.46e-04]    []
# 108000    [1.47e-02]    [1.46e-02]    []
# Epoch 108703: early stopping
#
# Best model at step 106702:
#   train loss: 1.41e-04
#   test loss: 1.34e-04
#   test metric: []
#
# 'train' took 9.647359 s
#
# Compiling model...
# 'compile' took 0.115803 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 108703    [2.79e-04]    [2.73e-04]    []
# 109000    [2.05e-04]    [2.05e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000164
#   Number of iterations: 466
#   Number of functions evaluations: 509
# 109212    [1.64e-04]    [1.58e-04]    []
#
# Best model at step 106702:
#   train loss: 1.41e-04
#   test loss: 1.34e-04
#   test metric: []
#
# 'train' took 6.995015 s
#
# Mean residual: 9.415e-03
# Adding new point: [ 1.8768194 28.998554 ]
#
# Compiling model...
# 'compile' took 0.192917 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 109212    [1.65e-04]    [1.58e-04]    []
# 110000    [9.75e-03]    [9.73e-03]    []
# 111000    [3.82e-04]    [3.74e-04]    []
# Epoch 111213: early stopping
#
# Best model at step 109212:
#   train loss: 1.65e-04
#   test loss: 1.58e-04
#   test metric: []
#
# 'train' took 10.157211 s
#
# Compiling model...
# 'compile' took 0.143358 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 111213    [1.06e-03]    [1.05e-03]    []
# 112000    [2.02e-04]    [2.02e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000183
#   Number of iterations: 1112
#   Number of functions evaluations: 1205
# 112418    [1.83e-04]    [1.75e-04]    []
#
# Best model at step 109212:
#   train loss: 1.65e-04
#   test loss: 1.58e-04
#   test metric: []
#
# 'train' took 12.930183 s
#
# Mean residual: 9.915e-03
# Adding new point: [  1.6637931 144.04237  ]
#
# Compiling model...
# 'compile' took 0.195077 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 112418    [1.85e-04]    [1.75e-04]    []
# 113000    [1.30e-03]    [1.29e-03]    []
# 114000    [3.03e-02]    [3.04e-02]    []
# Epoch 114419: early stopping
#
# Best model at step 112418:
#   train loss: 1.85e-04
#   test loss: 1.75e-04
#   test metric: []
#
# 'train' took 10.075754 s
#
# Compiling model...
# 'compile' took 0.128131 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 114419    [3.70e-04]    [3.61e-04]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000248
#   Number of iterations: 449
#   Number of functions evaluations: 495
# 114914    [2.48e-04]    [2.38e-04]    []
#
# Best model at step 112418:
#   train loss: 1.85e-04
#   test loss: 1.75e-04
#   test metric: []
#
# 'train' took 6.754827 s
#
# Mean residual: 1.177e-02
# Adding new point: [5.2736816  0.34459403]
#
# Compiling model...
# 'compile' took 0.162613 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 114914    [2.50e-04]    [2.38e-04]    []
# 115000    [7.40e-03]    [7.38e-03]    []
# 116000    [3.71e-04]    [3.60e-04]    []
# Epoch 116915: early stopping
#
# Best model at step 114914:
#   train loss: 2.50e-04
#   test loss: 2.38e-04
#   test metric: []
#
# 'train' took 10.198541 s
#
# Compiling model...
# 'compile' took 0.127190 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 116915    [3.12e-02]    [3.12e-02]    []
# 117000    [5.77e-04]    [5.77e-04]
# 118000    [2.49e-04]    [2.49e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000213
#   Number of iterations: 1584
#   Number of functions evaluations: 1699
# 118614    [2.13e-04]    [2.00e-04]    []
#
# Best model at step 118614:
#   train loss: 2.13e-04
#   test loss: 2.00e-04
#   test metric: []
#
# 'train' took 16.426672 s
#
# Mean residual: 1.097e-02
# Adding new point: [ 9.453789 93.881584]
#
# Compiling model...
# 'compile' took 0.222818 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 118614    [2.16e-04]    [2.00e-04]    []
# 119000    [4.48e-04]    [4.35e-04]    []
# 120000    [2.24e-04]    [2.12e-04]    []
# Epoch 120615: early stopping
#
# Best model at step 118614:
#   train loss: 2.16e-04
#   test loss: 2.00e-04
#   test metric: []
#
# 'train' took 10.334302 s
#
# Compiling model...
# 'compile' took 0.156484 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 120615    [5.06e-02]    [5.07e-02]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000255
#   Number of iterations: 330
#   Number of functions evaluations: 360
# 120975    [2.55e-04]    [2.44e-04]    []
#
# Best model at step 118614:
#   train loss: 2.16e-04
#   test loss: 2.00e-04
#   test metric: []
#
# 'train' took 6.162766 s
#
# Mean residual: 1.172e-02
# Adding new point: [ 9.453789 93.881584]
#
# Compiling model...
# 'compile' took 0.178276 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 120975    [2.57e-04]    [2.44e-04]    []
# 121000    [3.36e-01]    [3.36e-01]    []
# 122000    [3.97e-04]    [3.84e-04]    []
# Epoch 122976: early stopping
#
# Best model at step 120975:
#   train loss: 2.57e-04
#   test loss: 2.44e-04
#   test metric: []
#
# 'train' took 10.116715 s
#
# Compiling model...
# 'compile' took 0.131520 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 122976    [5.20e-04]    [5.09e-04]    []
# 123000    [5.09e-04]    [5.09e-04]
# 124000    [2.62e-04]    [2.62e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000261
#   Number of iterations: 972
#   Number of functions evaluations: 1052
# 124028    [2.61e-04]    [2.47e-04]    []
#
# Best model at step 120975:
#   train loss: 2.57e-04
#   test loss: 2.44e-04
#   test metric: []
#
# 'train' took 11.401375 s
#
# Mean residual: 1.246e-02
# Adding new point: [ 0.8245326 40.938282 ]
#
# Compiling model...
# 'compile' took 0.208501 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 124028    [2.64e-04]    [2.47e-04]    []
# 125000    [2.82e-04]    [2.68e-04]    []
# 126000    [3.75e-04]    [3.61e-04]    []
# Epoch 126029: early stopping
#
# Best model at step 124028:
#   train loss: 2.64e-04
#   test loss: 2.47e-04
#   test metric: []
#
# 'train' took 10.618514 s
#
# Compiling model...
# 'compile' took 0.151706 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 126029    [3.64e-04]    [3.49e-04]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000285
#   Number of iterations: 504
#   Number of functions evaluations: 589
# 126618    [2.85e-04]    [2.70e-04]    []
#
# Best model at step 124028:
#   train loss: 2.64e-04
#   test loss: 2.47e-04
#   test metric: []
#
# 'train' took 8.357504 s
#
# Mean residual: 1.298e-02
# Adding new point: [  0.8218608 116.09435  ]
#
# Compiling model...
# 'compile' took 0.194068 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 126618    [2.87e-04]    [2.70e-04]    []
# 127000    [7.41e-03]    [7.44e-03]    []
# 128000    [2.62e-01]    [2.61e-01]    []
# Epoch 128619: early stopping
#
# Best model at step 126618:
#   train loss: 2.87e-04
#   test loss: 2.70e-04
#   test metric: []
#
# 'train' took 10.437784 s
#
# Compiling model...
# 'compile' took 0.137052 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 128619    [1.34e-03]    [1.33e-03]    []
# 129000    [4.05e-04]    [4.05e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000275
#   Number of iterations: 1056
#   Number of functions evaluations: 1134
# 129753    [2.75e-04]    [2.59e-04]    []
#
# Best model at step 129753:
#   train loss: 2.75e-04
#   test loss: 2.59e-04
#   test metric: []
#
# 'train' took 12.701968 s
#
# Mean residual: 1.293e-02
# Adding new point: [ 0.6582631 67.5253   ]
#
# Compiling model...
# 'compile' took 0.211233 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 129753    [2.77e-04]    [2.59e-04]    []
# 130000    [8.02e-04]    [7.86e-04]    []
# 131000    [5.40e-04]    [5.24e-04]    []
# Epoch 131754: early stopping
#
# Best model at step 129753:
#   train loss: 2.77e-04
#   test loss: 2.59e-04
#   test metric: []
#
# 'train' took 11.092685 s
#
# Compiling model...
# 'compile' took 0.123985 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 131754    [4.48e-03]    [4.48e-03]    []
# 132000    [4.59e-04]    [4.59e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000344
#   Number of iterations: 612
#   Number of functions evaluations: 658
# 132412    [3.44e-04]    [3.28e-04]    []
#
# Best model at step 129753:
#   train loss: 2.77e-04
#   test loss: 2.59e-04
#   test metric: []
#
# 'train' took 9.063704 s
#
# Mean residual: 1.434e-02
# Adding new point: [9.829042  0.4663304]
#
# Compiling model...
# 'compile' took 0.211699 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 132412    [3.46e-04]    [3.28e-04]    []
# 133000    [2.60e-01]    [2.60e-01]    []
# 134000    [7.62e-03]    [7.57e-03]    []
# Epoch 134413: early stopping
#
# Best model at step 132412:
#   train loss: 3.46e-04
#   test loss: 3.28e-04
#   test metric: []
#
# 'train' took 11.288369 s
#
# Compiling model...
# 'compile' took 0.155183 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 134413    [2.45e-02]    [2.46e-02]    []
# 135000    [4.00e-04]    [4.00e-04]
# 136000    [2.69e-04]    [2.69e-04]
# 137000    [2.06e-04]    [2.06e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000186
#   Number of iterations: 2844
#   Number of functions evaluations: 3020
# 137433    [1.86e-04]    [1.72e-04]    []
#
# Best model at step 137433:
#   train loss: 1.86e-04
#   test loss: 1.72e-04
#   test metric: []
#
# 'train' took 28.273222 s
#
# Mean residual: 9.920e-03
# Adding new point: [ 7.83104  28.966478]
#
# Compiling model...
# 'compile' took 0.190427 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 137433    [1.89e-04]    [1.72e-04]    []
# 138000    [4.00e-04]    [3.89e-04]    []
# 139000    [2.98e-04]    [2.87e-04]    []
# Epoch 139434: early stopping
#
# Best model at step 137433:
#   train loss: 1.89e-04
#   test loss: 1.72e-04
#   test metric: []
#
# 'train' took 11.201197 s
#
# Compiling model...
# 'compile' took 0.159569 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 139434    [3.38e-04]    [3.27e-04]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000233
#   Number of iterations: 448
#   Number of functions evaluations: 485
# 139919    [2.33e-04]    [2.22e-04]    []
#
# Best model at step 137433:
#   train loss: 1.89e-04
#   test loss: 1.72e-04
#   test metric: []
#
# 'train' took 7.924275 s
#
# Mean residual: 1.134e-02
# Adding new point: [ 13.556191 182.87975 ]
#
# Compiling model...
# 'compile' took 0.168252 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 139919    [2.35e-04]    [2.22e-04]    []
# 140000    [3.29e-03]    [3.20e-03]    []
# 141000    [3.81e-04]    [3.68e-04]    []
# Epoch 141920: early stopping
#
# Best model at step 139919:
#   train loss: 2.35e-04
#   test loss: 2.22e-04
#   test metric: []
#
# 'train' took 10.972738 s
#
# Compiling model...
# 'compile' took 0.165704 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 141920    [3.66e-04]    [3.52e-04]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000365
#   Number of iterations: 2
#   Number of functions evaluations: 20
# 141940    [3.65e-04]    [3.52e-04]    []
#
# Best model at step 139919:
#   train loss: 2.35e-04
#   test loss: 2.22e-04
#   test metric: []
#
# 'train' took 5.431274 s
#
# Mean residual: 1.418e-02
# Adding new point: [ 13.284348 174.96852 ]
#
# Compiling model...
# 'compile' took 0.201845 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 141940    [3.69e-04]    [3.52e-04]    []
# 142000    [1.01e-02]    [9.89e-03]    []
# 143000    [8.96e-03]    [8.95e-03]    []
# Epoch 143941: early stopping
#
# Best model at step 141940:
#   train loss: 3.69e-04
#   test loss: 3.52e-04
#   test metric: []
#
# 'train' took 10.823207 s
#
# Compiling model...
# 'compile' took 0.153631 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 143941    [4.15e-04]    [3.99e-04]    []
# 144000    [4.06e-04]    [4.06e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000273
#   Number of iterations: 812
#   Number of functions evaluations: 870
# 144811    [2.73e-04]    [2.58e-04]    []
#
# Best model at step 144811:
#   train loss: 2.73e-04
#   test loss: 2.58e-04
#   test metric: []
#
# 'train' took 10.619849 s
#
# Mean residual: 1.287e-02
# Adding new point: [ 13.284348 174.96852 ]
#
# Compiling model...
# 'compile' took 0.173350 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 144811    [2.75e-04]    [2.58e-04]    []
# 145000    [9.18e-04]    [8.89e-04]    []
# 146000    [9.63e-04]    [9.46e-04]    []
# Epoch 146812: early stopping
#
# Best model at step 144811:
#   train loss: 2.75e-04
#   test loss: 2.58e-04
#   test metric: []
#
# 'train' took 10.895284 s
#
# Compiling model...
# 'compile' took 0.144795 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 146812    [2.71e-02]    [2.71e-02]    []
# 147000    [4.04e-04]    [4.04e-04]
# 148000    [2.54e-04]    [2.54e-04]
# 149000    [2.02e-04]    [2.02e-04]
# 150000    [1.66e-04]    [1.66e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000161
#   Number of iterations: 3130
#   Number of functions evaluations: 3323
# 150135    [1.61e-04]    [1.48e-04]    []
#
# Best model at step 150135:
#   train loss: 1.61e-04
#   test loss: 1.48e-04
#   test metric: []
#
# 'train' took 29.505481 s
#
# Mean residual: 9.294e-03
# Adding new point: [2.1866815 0.2059879]
#
# Compiling model...
# 'compile' took 0.169621 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 150135    [1.63e-04]    [1.48e-04]    []
# 151000    [2.58e-04]    [2.44e-04]    []
# 152000    [2.63e-03]    [2.62e-03]    []
# Epoch 152136: early stopping
#
# Best model at step 150135:
#   train loss: 1.63e-04
#   test loss: 1.48e-04
#   test metric: []
#
# 'train' took 11.003746 s
#
# Compiling model...
# 'compile' took 0.147701 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 152136    [2.81e-04]    [2.67e-04]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000186
#   Number of iterations: 572
#   Number of functions evaluations: 636
# 152772    [1.86e-04]    [1.74e-04]    []
#
# Best model at step 150135:
#   train loss: 1.63e-04
#   test loss: 1.48e-04
#   test metric: []
#
# 'train' took 8.995833 s
#
# Mean residual: 1.010e-02
# Adding new point: [ 5.533013 38.257366]
#
# Compiling model...
# 'compile' took 0.173797 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 152772    [1.88e-04]    [1.74e-04]    []
# 153000    [4.62e-04]    [4.45e-04]    []
# 154000    [3.39e-04]    [3.27e-04]    []
# Epoch 154773: early stopping
#
# Best model at step 152772:
#   train loss: 1.88e-04
#   test loss: 1.74e-04
#   test metric: []
#
# 'train' took 11.263442 s
#
# Compiling model...
# 'compile' took 0.143252 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 154773    [2.47e-02]    [2.47e-02]    []
# 155000    [2.69e-04]    [2.69e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000203
#   Number of iterations: 727
#   Number of functions evaluations: 790
# 155563    [2.03e-04]    [1.90e-04]    []
#
# Best model at step 152772:
#   train loss: 1.88e-04
#   test loss: 1.74e-04
#   test metric: []
#
# 'train' took 10.710780 s
#
# Mean residual: 1.072e-02
# Adding new point: [192.17609     1.1918613]
#
# Compiling model...
# 'compile' took 0.179417 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 155563    [2.05e-04]    [1.90e-04]    []
# 156000    [3.67e-04]    [3.55e-04]    []
# 157000    [3.21e-04]    [3.09e-04]    []
# Epoch 157564: early stopping
#
# Best model at step 155563:
#   train loss: 2.05e-04
#   test loss: 1.90e-04
#   test metric: []
#
# 'train' took 11.430202 s
#
# Compiling model...
# 'compile' took 0.139382 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 157564    [9.23e-04]    [9.08e-04]    []
# 158000    [2.50e-04]    [2.50e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000231
#   Number of iterations: 624
#   Number of functions evaluations: 686
# 158250    [2.31e-04]    [2.17e-04]    []
#
# Best model at step 155563:
#   train loss: 2.05e-04
#   test loss: 1.90e-04
#   test metric: []
#
# 'train' took 9.820467 s
#
# ...
#
# Step      Train loss    Test loss     Test metric
# 551319    [2.10e-03]    [2.03e-03]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000237
#   Number of iterations: 295
#   Number of functions evaluations: 320
# 551639    [2.37e-04]    [2.17e-04]    []
#
# Best model at step 549318:
#   train loss: 2.22e-04
#   test loss: 2.02e-04
#   test metric: []
#
# 'train' took 109.292468 s
#
# Mean residual: 1.239e-02
# Adding new point: [199.9972    25.929085]
#
# Compiling model...
# 'compile' took 3.116405 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 551639    [2.38e-04]    [2.17e-04]    []
# 552000    [2.66e-04]    [2.44e-04]    []
# 553000    [2.84e-03]    [2.81e-03]    []
# Epoch 553640: early stopping
#
# Best model at step 551639:
#   train loss: 2.38e-04
#   test loss: 2.17e-04
#   test metric: []
#
# 'train' took 110.677682 s
#
# Compiling model...
# 'compile' took 2.321340 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 553640    [1.80e-03]    [1.75e-03]    []
# 554000    [2.39e-04]    [2.39e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000225
#   Number of iterations: 623
#   Number of functions evaluations: 675
# 554315    [2.25e-04]    [2.06e-04]    []
#
# Best model at step 554315:
#   train loss: 2.25e-04
#   test loss: 2.06e-04
#   test metric: []
#
# 'train' took 113.002690 s
#
# Mean residual: 1.247e-02
# Adding new point: [  8.36799 188.79904]
#
# Compiling model...
# 'compile' took 4.011078 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 554315    [2.25e-04]    [2.06e-04]    []
# 555000    [1.04e-03]    [1.01e-03]    []
# 556000    [5.14e-02]    [5.05e-02]    []
# Epoch 556316: early stopping
#
# Best model at step 554315:
#   train loss: 2.25e-04
#   test loss: 2.06e-04
#   test metric: []
#
# 'train' took 118.622259 s
#
# Compiling model...
# 'compile' took 4.194915 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 556316    [2.73e-02]    [2.68e-02]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000241
#   Number of iterations: 354
#   Number of functions evaluations: 407
# 556723    [2.41e-04]    [2.21e-04]    []
#
# Best model at step 554315:
#   train loss: 2.25e-04
#   test loss: 2.06e-04
#   test metric: []
#
# 'train' took 147.548275 s
#
# Mean residual: 1.260e-02
# Adding new point: [ 4.3379416 42.755886 ]
#
# Compiling model...
# 'compile' took 6.660252 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 556723    [2.42e-04]    [2.21e-04]    []
# 557000    [3.04e-04]    [2.80e-04]    []
# 558000    [2.79e-04]    [2.55e-04]    []
# Epoch 558724: early stopping
#
# Best model at step 556723:
#   train loss: 2.42e-04
#   test loss: 2.21e-04
#   test metric: []
#
# 'train' took 119.481819 s
#
# Compiling model...
# 'compile' took 1.744357 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 558724    [3.26e-02]    [3.22e-02]    []
# 559000    [2.56e-04]    [2.56e-04]
# 560000    [2.09e-04]    [2.09e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000202
#   Number of iterations: 1521
#   Number of functions evaluations: 1661
# 560385    [2.02e-04]    [1.86e-04]    []
#
# Best model at step 560385:
#   train loss: 2.02e-04
#   test loss: 1.86e-04
#   test metric: []
#
# 'train' took 134.019786 s
#
# Mean residual: 1.192e-02
# Adding new point: [  0.3810238 196.75432  ]
#
# Compiling model...
# 'compile' took 5.849999 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 560385    [2.03e-04]    [1.86e-04]    []
# 561000    [2.09e-04]    [1.90e-04]    []
# 562000    [2.22e-04]    [2.04e-04]    []
# Epoch 562386: early stopping
#
# Best model at step 560385:
#   train loss: 2.03e-04
#   test loss: 1.86e-04
#   test metric: []
#
# 'train' took 121.693505 s
#
# Compiling model...
# 'compile' took 1.497974 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 562386    [2.73e-02]    [2.69e-02]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000207
#   Number of iterations: 479
#   Number of functions evaluations: 512
# 562898    [2.07e-04]    [1.89e-04]    []
#
# Best model at step 560385:
#   train loss: 2.03e-04
#   test loss: 1.86e-04
#   test metric: []
#
# 'train' took 138.304942 s
#
# Mean residual: 1.193e-02
# Adding new point: [ 2.8883774 99.999275 ]
#
# Compiling model...
# 'compile' took 5.861526 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 562898    [2.08e-04]    [1.89e-04]    []
# 563000    [8.29e-04]    [7.98e-04]    []
# 564000    [2.72e-04]    [2.52e-04]    []
# Epoch 564899: early stopping
#
# Best model at step 562898:
#   train loss: 2.08e-04
#   test loss: 1.89e-04
#   test metric: []
#
# 'train' took 125.944167 s
#
# Compiling model...
# 'compile' took 3.491259 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 564899    [6.06e-02]    [6.00e-02]    []
# 565000    [2.37e-04]    [2.37e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000210
#   Number of iterations: 509
#   Number of functions evaluations: 554
# 565453    [2.10e-04]    [1.92e-04]    []
#
# Best model at step 562898:
#   train loss: 2.08e-04
#   test loss: 1.89e-04
#   test metric: []
#
# 'train' took 130.217724 s
#
# Mean residual: 1.201e-02
# Adding new point: [ 3.7713952 71.368004 ]
#
# Compiling model...
# 'compile' took 4.932517 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 565453    [2.10e-04]    [1.92e-04]    []
# 566000    [2.67e-04]    [2.48e-04]    []
# 567000    [2.55e-04]    [2.39e-04]    []
# Epoch 567454: early stopping
#
# Best model at step 565453:
#   train loss: 2.10e-04
#   test loss: 1.92e-04
#   test metric: []
#
# 'train' took 114.852494 s
#
# Compiling model...
# 'compile' took 1.953532 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 567454    [2.23e-04]    [2.06e-04]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000208
#   Number of iterations: 311
#   Number of functions evaluations: 345
# 567799    [2.08e-04]    [1.90e-04]    []
#
# Best model at step 567799:
#   train loss: 2.08e-04
#   test loss: 1.90e-04
#   test metric: []
#
# 'train' took 151.326296 s
#
# Mean residual: 1.199e-02
# Adding new point: [ 3.7713952 71.368004 ]
#
# Compiling model...
# 'compile' took 6.658668 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 567799    [2.09e-04]    [1.90e-04]    []
# 568000    [3.12e-04]    [2.92e-04]    []
# 569000    [2.11e-04]    [1.94e-04]    []
# Epoch 569800: early stopping
#
# Best model at step 567799:
#   train loss: 2.09e-04
#   test loss: 1.90e-04
#   test metric: []
#
# 'train' took 117.557448 s
#
# Compiling model...
# 'compile' took 3.256079 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 569800    [2.59e-04]    [2.42e-04]    []
# 570000    [2.20e-04]    [2.20e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000214
#   Number of iterations: 336
#   Number of functions evaluations: 362
# 570162    [2.14e-04]    [1.96e-04]    []
#
# Best model at step 567799:
#   train loss: 2.09e-04
#   test loss: 1.90e-04
#   test metric: []
#
# 'train' took 165.017836 s
#
# Mean residual: 1.203e-02
# Adding new point: [62.832226  5.559076]
#
# Compiling model...
# 'compile' took 6.455059 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 570162    [2.15e-04]    [1.96e-04]    []
# 571000    [2.64e-03]    [2.54e-03]    []
# 572000    [2.57e-04]    [2.41e-04]    []
# Epoch 572163: early stopping
#
# Best model at step 570162:
#   train loss: 2.15e-04
#   test loss: 1.96e-04
#   test metric: []
#
# 'train' took 131.294015 s
#
# Compiling model...
# 'compile' took 3.028084 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 572163    [2.37e-02]    [2.32e-02]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000219
#   Number of iterations: 365
#   Number of functions evaluations: 443
# 572606    [2.19e-04]    [2.01e-04]    []
#
# Best model at step 570162:
#   train loss: 2.15e-04
#   test loss: 1.96e-04
#   test metric: []
#
# 'train' took 136.622131 s
#
# Mean residual: 1.242e-02
# Adding new point: [199.9972    25.929085]
#
# Compiling model...
# 'compile' took 2.466373 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 572606    [2.20e-04]    [2.01e-04]    []
# 573000    [2.50e-04]    [2.30e-04]    []
# 574000    [5.39e-04]    [5.11e-04]    []
# Epoch 574607: early stopping
#
# Best model at step 572606:
#   train loss: 2.20e-04
#   test loss: 2.01e-04
#   test metric: []
#
# 'train' took 128.074336 s
#
# Compiling model...
# 'compile' took 1.712881 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 574607    [1.79e-03]    [1.75e-03]    []
# 575000    [2.22e-04]    [2.22e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000209
#   Number of iterations: 724
#   Number of functions evaluations: 817
# 575424    [2.09e-04]    [1.92e-04]    []
#
# Best model at step 575424:
#   train loss: 2.09e-04
#   test loss: 1.92e-04
#   test metric: []
#
# 'train' took 137.764748 s
#
# Mean residual: 1.218e-02
# Adding new point: [ 3.060781 98.55352 ]
#
# Compiling model...
# 'compile' took 2.246866 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 575424    [2.10e-04]    [1.92e-04]    []
# 576000    [2.26e-04]    [2.06e-04]    []
# 577000    [2.66e-04]    [2.49e-04]    []
# Epoch 577425: early stopping
#
# Best model at step 575424:
#   train loss: 2.10e-04
#   test loss: 1.92e-04
#   test metric: []
#
# 'train' took 134.854842 s
#
# Compiling model...
# 'compile' took 2.070312 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 577425    [1.68e-01]    [1.65e-01]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000218
#   Number of iterations: 398
#   Number of functions evaluations: 430
# 577855    [2.18e-04]    [2.04e-04]    []
#
# Best model at step 575424:
#   train loss: 2.10e-04
#   test loss: 1.92e-04
#   test metric: []
#
# 'train' took 143.375527 s
#
# Mean residual: 1.235e-02
# Adding new point: [  6.4248905 191.14372  ]
#
# Compiling model...
# 'compile' took 5.314016 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 577855    [2.19e-04]    [2.04e-04]    []
# 578000    [8.71e-04]    [8.55e-04]    []
# 579000    [5.89e-03]    [5.85e-03]    []
# Epoch 579856: early stopping
#
# Best model at step 577855:
#   train loss: 2.19e-04
#   test loss: 2.04e-04
#   test metric: []
#
# 'train' took 134.035945 s
#
# Compiling model...
# 'compile' took 2.923451 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 579856    [1.01e-03]    [9.96e-04]    []
# 580000    [2.25e-04]    [2.25e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000214
#   Number of iterations: 370
#   Number of functions evaluations: 411
# 580267    [2.14e-04]    [1.98e-04]    []
#
# Best model at step 580267:
#   train loss: 2.14e-04
#   test loss: 1.98e-04
#   test metric: []
#
# 'train' took 142.468954 s
#
# Mean residual: 1.216e-02
# Adding new point: [14.047858 78.334854]
#
# Compiling model...
# 'compile' took 5.678397 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 580267    [2.14e-04]    [1.98e-04]    []
# 581000    [2.28e-04]    [2.12e-04]    []
# 582000    [5.17e-03]    [5.06e-03]    []
# Epoch 582268: early stopping
#
# Best model at step 580267:
#   train loss: 2.14e-04
#   test loss: 1.98e-04
#   test metric: []
#
# 'train' took 154.204885 s
#
# Compiling model...
# 'compile' took 6.599420 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 582268    [7.95e-04]    [7.59e-04]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000228
#   Number of iterations: 326
#   Number of functions evaluations: 386
# 582654    [2.28e-04]    [2.11e-04]    []
#
# Best model at step 580267:
#   train loss: 2.14e-04
#   test loss: 1.98e-04
#   test metric: []
#
# 'train' took 285.689026 s
#
# Mean residual: 1.244e-02
# Adding new point: [131.09439 192.27936]
#
# Compiling model...
# 'compile' took 5.938824 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 582654    [2.28e-04]    [2.11e-04]    []
# 583000    [2.61e-04]    [2.40e-04]    []
# 584000    [1.75e-02]    [1.72e-02]    []
# Epoch 584655: early stopping
#
# Best model at step 582654:
#   train loss: 2.28e-04
#   test loss: 2.11e-04
#   test metric: []
#
# 'train' took 144.727544 s
#
# Compiling model...
# 'compile' took 5.986699 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 584655    [3.35e-04]    [3.19e-04]    []
# 585000    [2.17e-04]    [2.17e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000211
#   Number of iterations: 494
#   Number of functions evaluations: 547
# 585202    [2.11e-04]    [1.95e-04]    []
#
# Best model at step 585202:
#   train loss: 2.11e-04
#   test loss: 1.95e-04
#   test metric: []
#
# 'train' took 131.142514 s
#
# Mean residual: 1.219e-02
# Adding new point: [11.449853 74.7419  ]
#
# Compiling model...
# 'compile' took 2.689404 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 585202    [2.12e-04]    [1.95e-04]    []
# 586000    [2.33e-04]    [2.15e-04]    []
# 587000    [6.82e-02]    [6.73e-02]    []
# Epoch 587203: early stopping
#
# Best model at step 585202:
#   train loss: 2.12e-04
#   test loss: 1.95e-04
#   test metric: []
#
# 'train' took 130.046512 s
#
# Compiling model...
# 'compile' took 1.874061 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 587203    [5.00e-04]    [4.75e-04]    []
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000227
#   Number of iterations: 339
#   Number of functions evaluations: 362
# 587565    [2.27e-04]    [2.10e-04]    []
#
# Best model at step 585202:
#   train loss: 2.12e-04
#   test loss: 1.95e-04
#   test metric: []
#
# 'train' took 159.193969 s
#
# Mean residual: 1.227e-02
# Adding new point: [ 16.619284 112.101616]
#
# Compiling model...
# 'compile' took 4.900099 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 587565    [2.28e-04]    [2.10e-04]    []
# 588000    [1.62e-02]    [1.33e-02]    []
# 589000    [4.65e-04]    [4.33e-04]    []
# Epoch 589566: early stopping
#
# Best model at step 587565:
#   train loss: 2.28e-04
#   test loss: 2.10e-04
#   test metric: []
#
# 'train' took 147.814568 s
#
# Compiling model...
# 'compile' took 5.945843 s
#
# Training model...
#
# Step      Train loss    Test loss     Test metric
# 589566    [3.24e-04]    [2.99e-04]    []
# 590000    [2.18e-04]    [2.18e-04]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000216
#   Number of iterations: 492
#   Number of functions evaluations: 532
# 590098    [2.16e-04]    [1.97e-04]    []
#
# Best model at step 590098:
#   train loss: 2.16e-04
#   test loss: 1.97e-04
#   test metric: []
#
# 'train' took 149.759937 s
#
# Saving loss history to /Users/zhangtianjie/Documents/GitHub/P-rheologynet/first-try/RAR/loss.dat ...
# Saving training data to /Users/zhangtianjie/Documents/GitHub/P-rheologynet/first-try/RAR/train.dat ...
# Saving test data to /Users/zhangtianjie/Documents/GitHub/P-rheologynet/first-try/RAR/test.dat ...

# %% [markdown]
# # FNN training

# %%
import pandas as pd
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_absolute_error

train=np.loadtxt('train.dat', unpack = True)

x_train = train[[0,1]].T
y_train = train[2]

clf = MLPRegressor(hidden_layer_sizes=(50,50,50),max_iter=50000)

clf.fit(x_train, y_train)
# Out:
# MLPRegressor(hidden_layer_sizes=(50, 50, 50), max_iter=50000)

# %%
train1=np.loadtxt('train.dat', unpack = True)
pd.DataFrame(train1.T,columns=['x','t','shear stress'])
# Out:
#                x           t  shear stress
# 0      16.619284  112.101616    145.093414
# 1      11.449853   74.741898    130.875427
# 2     131.094391  192.279358     97.201263
# 3      14.047858   78.334854    129.163574
# 4       6.424891  191.143723    220.773849
# ...          ...         ...           ...
# 4695  104.876961   79.194916     67.441559
# 4696   19.474476  179.833969    159.703888
# 4697   20.133314   50.069092     94.681908
# 4698   27.508348   91.112831    114.517540
# 4699    2.190138  169.442856    236.271973
#
# [4700 rows x 3 columns]

# %%
x = np.linspace(0, 200, 200)
t = np.linspace(0, 200, 200)
X, T = np.meshgrid(x, t)

X_star = np.hstack((X.flatten()[:, None], T.flatten()[:, None]))

# %% [markdown]
# # solution

# %%
new_points = pd.DataFrame(new_points, columns=['x', 'y'])
new_points
# Out:
#               x           y
# 0      3.700927    4.584892
# 1      4.783122    3.180764
# 2      4.970337    3.533727
# 3     11.945560  198.545380
# 4      4.870718    2.969908
# ..          ...         ...
# 195    6.424891  191.143723
# 196   14.047858   78.334854
# 197  131.094391  192.279358
# 198   11.449853   74.741898
# 199   16.619284  112.101616
#
# [200 rows x 2 columns]

# %%
# tau
import pandas as pd
train_lambda=np.loadtxt('train.dat', unpack = True)
train_lambda = pd.DataFrame(train_lambda.T)

ext = griddata(X_star, solution(X_star[:,0],X_star[:,1]), (X, T), method="cubic")
fig, ax = plt.subplots()
h=ax.contourf(X,T, ext,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title(r'$\mathbf{\tau_{P-RheologyNet+R} }$',fontproperties = 'Times New Roman', size = 14)
# plt.yticks(fontproperties = 'Times New Roman', size = 14)
# plt.xticks(fontproperties = 'Times New Roman', size = 14)

plt.scatter(train_lambda[0],train_lambda[1],c='black',s=1)

# plt.scatter(train_lambda[4499:-1][0],train_lambda[4499:-1][1],c='red',s=1)

plt.scatter(new_points['x'],new_points['y'],c='red',s=1,marker='+')

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('tau-solution.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:8: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'

# %%
train_lambda=np.loadtxt('train.dat', unpack = True)
train_lambda = pd.DataFrame(train_lambda.T)
ext = griddata(X_star, solution(X_star[:,0],X_star[:,1]), (X, T), method="cubic")
fig, ax = plt.subplots()
h=ax.contourf(X,T, ext/T,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title(r'$\mathbf{\eta _{FEA}}$',fontproperties = 'Times New Roman', size = 14)
plt.scatter(train_lambda[0],train_lambda[1],c='black',s=1)
# plt.yticks(fontproperties = 'Times New Roman', size = 14)
# plt.xticks(fontproperties = 'Times New Roman', size = 14)

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)

plt.savefig('viscosity-solution.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
#   """

# %% [markdown]
# # pinn prediction part: tau, lambda, eta, error.

# %%
x = np.linspace(0, 200, 200)
t = np.linspace(0, 200, 200)
X, T = np.meshgrid(x, t)

X_star = np.hstack((X.flatten()[:, None], T.flatten()[:, None]))

import time
start=time.time()
prediction = model.predict(X_star, operator=None)
end=time.time()
time_pinn = end-start
print(time_pinn)

pinn_pre = griddata(X_star, prediction[:, 0], (X, T), method="cubic")

fig, ax = plt.subplots()
h=ax.contourf(X,T, pinn_pre,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title(r'$\mathbf{\tau _{P-RheologyNet+R} }$',fontproperties = 'Times New Roman', size = 14)
# plt.yticks(fontproperties = 'Times New Roman', size = 14)
# plt.xticks(fontproperties = 'Times New Roman', size = 14)


from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('tau-pinn.png',dpi=600,bbox_inches = 'tight')
# Out:
# 0.027478933334350586
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'

# %% [markdown]
# # eta

# %%
from matplotlib import ticker, cm
x = np.linspace(0, 200, 200)
t = np.linspace(0, 200, 200)
X, T = np.meshgrid(x, t)

X_star = np.hstack((X.flatten()[:, None], T.flatten()[:, None]))
prediction = model.predict(X_star, operator=None)

pinn_pre = griddata(X_star, prediction[:, 0], (X, T), method="cubic")

fig, ax = plt.subplots()
# norm = matplotlib.colors.Normalize(vmin=0, vmax=100)
h=ax.contourf(X,T, pinn_pre/T,cmap="viridis",origin='lower',aspect='auto',interpolation='nearest')
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title(r'$\mathbf{\eta _{P-RheologyNet+R} }$',fontproperties = 'Times New Roman', size = 14)


from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('eta-pinn.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in true_divide
#   del sys.path[0]
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
#   del sys.path[0]

# %% [markdown]
# # nn pre

# %%
x = np.linspace(0, 200, 200)
t = np.linspace(0, 200, 200)
X, T = np.meshgrid(x, t)

X_star = np.hstack((X.flatten()[:, None], T.flatten()[:, None]))

start_fnn=time.time()
prediction = clf.predict(X_star)
end_fnn=time.time()
time_fnn = end_fnn-start_fnn
print(time_fnn)

pre_nn = griddata(X_star, prediction, (X, T), method="cubic")

fig, ax = plt.subplots()
h=ax.contourf(X,T, pre_nn,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title(r'$\mathbf{\tau _{FNN} }$ ',fontproperties = 'Times New Roman', size = 14)

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('tau-FNN.png',dpi=600,bbox_inches = 'tight')
# Out:
# 0.022511005401611328
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
#   app.launch_new_instance()

# %%
x = np.linspace(0, 200, 200)
t = np.linspace(0, 200, 200)
X, T = np.meshgrid(x, t)

X_star = np.hstack((X.flatten()[:, None], T.flatten()[:, None]))

prediction = clf.predict(X_star)

pre_nn = griddata(X_star, prediction, (X, T), method="cubic")

fig, ax = plt.subplots()
h=ax.contourf(X,T, pre_nn/T,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title(r'$\mathbf{\eta _{FNN} }$ ',fontproperties = 'Times New Roman', size = 14)

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('FNN_pre.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in true_divide
#   if sys.path[0] == '':
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
#   if sys.path[0] == '':

# %% [markdown]
# # nn err

# %%
err_nn = abs(pre_nn-ext)
fig, ax = plt.subplots()
h=ax.contourf(X,T, err_nn,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title(r'$\mathbf{\varepsilon _{\tau ,FNN}   } $ ',fontproperties = 'Times New Roman', size = 14)

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('err_tau-FNN.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
err_nn = abs(pre_nn/T-ext/T)
fig, ax = plt.subplots()
h=ax.contourf(X,T, err_nn,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest',locator=ticker.LogLocator())
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title(r'$\mathbf{\varepsilon _{\eta ,FNN}   } $ ',fontproperties = 'Times New Roman', size = 14)

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('err-FNN-eta.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in subtract
#   """Entry point for launching an IPython kernel.
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # pinn error

# %%
from matplotlib import ticker, cm
err_pinn_tau = abs(pinn_pre-ext)
fig, ax = plt.subplots()
h=ax.contourf(X,T, err_pinn_tau,cmap="viridis",origin='lower', aspect='auto',interpolation='nearest')
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title(r'$\mathbf{\varepsilon _{\tau ,P-RheologyNet+R}  } $ ',fontproperties = 'Times New Roman', size = 14)

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('err-rn-tau.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
#   after removing the cwd from sys.path.

# %%
err_pinn_eta = abs(pinn_pre/T-ext/T)
fig, ax = plt.subplots()
h=ax.contourf(X,T, err_pinn_eta,cmap="viridis",origin='lower',aspect='auto',interpolation='nearest',locator=ticker.LogLocator())
plt.xlabel('$t(s)$',fontproperties = 'Times New Roman', size = 14)
plt.ylabel('$\dot{\gamma } ( s^{-1}) $ ',fontproperties = 'Times New Roman', size = 14 )
plt.title(r'$\mathbf{\varepsilon _{\eta ,P-RheologyNet+R}  } $ ',fontproperties = 'Times New Roman', size = 14)

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(h, cax=cax)
plt.savefig('err-rn-eta.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in subtract
#   """Entry point for launching an IPython kernel.
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: The following kwargs were not used by contour: 'aspect', 'interpolation'
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # PINN MSE

# %%
from sklearn.metrics import mean_squared_error
eta_pre= pinn_pre/T
eta_pre[eta_pre>1e308]=0

eta_ext=ext/T
eta_ext[eta_ext>1e308]=0
eta_nn = pre_nn/T

eta_nn[eta_nn>1e308]=0

print('tau-mse-pinn',mean_squared_error(pinn_pre,ext))
print('eta-mse-pinn',mean_squared_error(eta_pre,eta_ext))
print('tau-mse-fnn',mean_squared_error(pre_nn,ext))
print('eta-mse-fnn',mean_squared_error(eta_nn,eta_ext))

print('pinn_time',time_pinn)
print('fnn_time',time_fnn)
# Out:
# tau-mse-pinn 0.000242464021710145
# eta-mse-pinn 4.4349869911194755e-06
# tau-mse-fnn 1.2240409976533844
# eta-mse-fnn 0.0014718152109895264
# pinn_time 5.191021919250488
# fnn_time 0.022511005401611328
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
#
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in true_divide
#   import sys
